# %% [markdown]
# # XML to Dictionary
# - @Lucas Müller
# - Conversion of the Rest15/16 Dataset in xml to python dictonary with predefined schema, in order to be transformed into xml using the code provided by @Nils Hellwig

# %%
import xmltodict
import json
from pprint import pprint

# %%
from dataclasses import dataclass, asdict, field
from typing import List, Dict, Union

# %%
@dataclass
class Review:
    """
    This dataclass is used as a schema which will be casted into a dictionary after populating it

    - str: Annotated text
    - tags: tags and found in the xml-file containing
        - spans (start, end)
        - polarity 
        - label (aspect category)
        - type

    """
    # Fields
    text: str
    tags: List[Dict[str, Union[str, int]]]  # Allowing integers for span numbers

# %% [markdown]
# Loading trial Rest15/16 dataset and convert to dictionary

# %%
xml_file_path = "Data\\restaurants_trial_english_sl.xml"

# Read the XML file
with open(xml_file_path, "r", encoding="utf-8") as file:
    xml_content = file.read()

# Convert XML to Python dictionary
xml_dict = xmltodict.parse(xml_content)

# %%
print(xml_dict)
# Out:
# {'Reviews': {'Review': [{'@rid': '1090587', 'sentences': {'sentence': [{'@id': '1090587:0', 'text': 'Just went here for my girlfriends 23rd bday.'}, {'@id': '1090587:1', 'text': "If you've ever been along the river in Weehawken you have an idea of the top of view the chart house has to offer.", 'Opinions': {'Opinion': {'@target': 'view', '@category': 'LOCATION#GENERAL', '@polarity': 'positive', '@from': '80', '@to': '84'}}}, {'@id': '1090587:2', 'text': 'Add to that great service and great food at a reasonable price and you have yourself the beginning of a great evening.', 'Opinions': {'Opinion': [{'@target': 'service', '@category': 'SERVICE#GENERAL', '@polarity': 'positive', '@from': '18', '@to': '25'}, {'@target': 'food', '@category': 'FOOD#QUALITY', '@polarity': 'positive', '@from': '36', '@to': '40'}, {'@target': 'food', '@category': 'FOOD#PRICES', '@polarity': 'positive', '@from': '36', '@to': '40'}]}}, {'@id': '1090587:3', 'text': 'The lava cake dessert was incredible and I recommend it.', 'Opinions': {'Opinion': {'@target': 'lava cake dessert', '@category': 'FOOD#QUALITY', '@polarity': 'positive', '@from': '4', '@to': '21'}}}]}}, {'@rid': '1661043', 'sentences': {'sentence': [{'@id': '1661043:0', 'text': 'Pizza here is consistently good.', 'Opinions': {'Opinion': {'@target': 'Pizza', '@category': 'FOOD#QUALITY', '@polarity': 'positive', '@from': '0', '@to': '5'}}}, {'@id': '1661043:1', 'text': 'Salads are a delicious way to begin the meal.', 'Opinions': {'Opinion': {'@target': 'Salads', '@category': 'FOOD#QUALITY', '@polarity': 'positive', '@from': '0', '@to': '6'}}}, {'@id': '1661043:2', 'text': 'You should pass on the calamari.', 'Opinions': {'Opinion': {'@target': 'calamari', '@category': 'FOOD#QUALITY', '@polarity': 'negative', '@from': '23', '@to': '31'}}}, {'@id': '1661043:3', 'text': 'It is thick and slightly soggy.', 'Opinions': {'Opinion': {'@target': 'NULL', '@category': 'FOOD#QUALITY', '@polarity': 'negative', '@from': '0', '@to': '0'}}}, {'@id': '1661043:4', 'text': 'Decor is charming.', 'Opinions': {'Opinion': {'@target': 'Decor', '@category': 'AMBIENCE#GENERAL', '@polarity': 'positive', '@from': '0', '@to': '5'}}}, {'@id': '1661043:5', 'text': 'Service is average.', 'Opinions': {'Opinion': {'@target': 'Service', '@category': 'SERVICE#GENERAL', '@polarity': 'neutral', '@from': '0', '@to': '7'}}}]}}, {'@rid': '1349391', 'sentences': {'sentence': [{'@id': '1349391:0', 'text': 'sometimes i get good food and ok service.', 'Opinions': {'Opinion': [{'@target': 'food', '@category': 'FOOD#QUALITY', '@polarity': 'positive', '@from': '21', '@to': '25'}, {'@target': 'service', '@category': 'SERVICE#GENERAL', '@polarity': 'neutral', '@from': '33', '@to': '40'}]}}, {'@id': '1349391:1', 'text': 'sometimes i get bad food and bad service, sometimes i get good good and bad service.', 'Opinions': {'Opinion': [{'@target': 'food', '@category': 'FOOD#QUALITY', '@polarity': 'negative', '@from': '20', '@to': '24'}, {'@target': 'service', '@category': 'SERVICE#GENERAL', '@polarity': 'negative', '@from': '33', '@to': '40'}, {'@target': 'service', '@category': 'SERVICE#GENERAL', '@polarity': 'negative', '@from': '76', '@to': '83'}, {'@target': 'good', '@category': 'FOOD#QUALITY', '@polarity': 'positive', '@from': '63', '@to': '67'}]}}, {'@id': '1349391:2', 'text': 'it is not consistent.', 'Opinions': {'Opinion': {'@target': 'NULL', '@category': 'RESTAURANT#GENERAL', '@polarity': 'negative', '@from': '0', '@to': '0'}}}, {'@id': '1349391:3', 'text': 'really depends on your luck!'}]}}, {'@rid': '1357554', 'sentences': {'sentence': [{'@id': '1357554:0', 'text': 'I started out with a Bombay beer which was big enough for two.', 'Opinions': {'Opinion': {'@target': 'Bombay beer', '@category': 'DRINKS#STYLE_OPTIONS', '@polarity': 'positive', '@from': '21', '@to': '32'}}}, {'@id': '1357554:1', 'text': 'For dinner I had the chicken tikka-masala and some garlic naan.'}, {'@id': '1357554:2', 'text': 'MMmmm... it was delicious.', 'Opinions': {'Op ...

# %%
def xml_dict_transformation(xml_dict):

    """
    Transforms dictionary into the following schema (populated with example):

    transformed_dict = {"text": "Der Burger hat gut geschmeckt", 
            "tags": [
                {"start": 0, "end": 0, "label": "food", "polarity": "positive", "type": "label-explicit"},
            ]}

    - The aspect labels will be adjusted according to the labels used in the GERestaurant paper
    - Explicit and implicit label types are added as Rest15/16 datasets do not provide these labels
    - The dictionaries will passed to the XML-Tagger which will turn the dictionaries into xml-format for the TASD-Task 
    
    """

    # Mappig of the labels 
    # Rest15/16 : GERestaurant

    label_map = {
        "PRICES": "PRICE",
        "RESTAURANT" : "GENERAL-IMPRESSION",
        "LOCATION" : "AMBIENCE",
        "DRINKS" : "FOOD",
        "SERVICE" : "SERVICE",
        "AMBIENCE": "AMBIENCE",
        "FOOD" : "FOOD"
    }

    # List of transformed dictionaries
    reviews_list = []

    # Get reviews
    reviews = xml_dict['Reviews']['Review']


    for review in reviews:
        
        # Get every sentence from review
        review_sentences = review['sentences']['sentence']
        for sent in review_sentences:
            
            # Check if sentence has opinion tags, otherwise dismiss
            if type(sent) == str:
                continue
            try:
                sent["Opinions"]
            except KeyError:
                continue

            text = sent["text"]
            
            # Check if opinion tags are in a list or dict
            if type(sent['Opinions']['Opinion']) == dict:
                opinion = sent['Opinions']['Opinion']

                # Check if explicit or implicit
                aspect_type = opinion['@target']
                if aspect_type != 'NULL':
                    aspect_type = "label-explicit"
                else:
                    aspect_type = "label-implicit"

                label = opinion['@category']

                # map label to GERestaurant labels
                label = label.split('#')[0]
                label = label_map[label]
                
                polarity = opinion['@polarity']
                start = int(opinion['@from']) # start, cast into integer
                to = int(opinion['@to']) # end, cast into integer

                # create Review
                review_class = Review(text, tags=[{"start": start, "end": to, "label": label, "polarity": polarity, "type": aspect_type}])

                reviews_list.append(asdict(review_class))

            else:

                opinions = sent['Opinions']['Opinion']

                tags_list = []

                for opinion in opinions:

                    # Check if explicit or implicit
                    aspect_type = opinion['@target']
                    if aspect_type != 'NULL':
                        aspect_type = "label-explicit"
                    else:
                        aspect_type = "label-implicit"


                    label = opinion['@category']

                    # map label to GERestaurant labels
                    label = label.split('#')[0]
                    label = label_map[label]

                    polarity = opinion['@polarity']
                    start = int(opinion['@from']) # start, cast into integer
                    to = int(opinion['@to']) # end, cast into integer

                    tags = {"start": start, "end": to, "label": label, "polarity": polarity, "type": aspect_type}
                    tags_list.append(tags)

                # create Review instance
                review_class = Review(text, tags=tags_list)

                reviews_list.append(asdict(review_class))

    return reviews_list

# %%
xml_dict_transformation(xml_dict)
# Out:
# [{'text': "If you've ever been along the river in Weehawken you have an idea of the top of view the chart house has to offer.",
#   'tags': [{'start': 80,
#     'end': 84,
#     'label': 'AMBIENCE',
#     'polarity': 'positive',
#     'type': 'label-explicit'}]},
#  {'text': 'Add to that great service and great food at a reasonable price and you have yourself the beginning of a great evening.',
#   'tags': [{'start': 18,
#     'end': 25,
#     'label': 'SERVICE',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 36,
#     'end': 40,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 36,
#     'end': 40,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'}]},
#  {'text': 'The lava cake dessert was incredible and I recommend it.',
#   'tags': [{'start': 4,
#     'end': 21,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'}]},
#  {'text': 'Pizza here is consistently good.',
#   'tags': [{'start': 0,
#     'end': 5,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'}]},
#  {'text': 'Salads are a delicious way to begin the meal.',
#   'tags': [{'start': 0,
#     'end': 6,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'}]},
#  {'text': 'You should pass on the calamari.',
#   'tags': [{'start': 23,
#     'end': 31,
#     'label': 'FOOD',
#     'polarity': 'negative',
#     'type': 'label-explicit'}]},
#  {'text': 'It is thick and slightly soggy.',
#   'tags': [{'start': 0,
#     'end': 0,
#     'label': 'FOOD',
#     'polarity': 'negative',
#     'type': 'label-implicit'}]},
#  {'text': 'Decor is charming.',
#   'tags': [{'start': 0,
#     'end': 5,
#     'label': 'AMBIENCE',
#     'polarity': 'positive',
#     'type': 'label-explicit'}]},
#  {'text': 'Service is average.',
#   'tags': [{'start': 0,
#     'end': 7,
#     'label': 'SERVICE',
#     'polarity': 'neutral',
#     'type': 'label-explicit'}]},
#  {'text': 'sometimes i get good food and ok service.',
#   'tags': [{'start': 21,
#     'end': 25,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 33,
#     'end': 40,
#     'label': 'SERVICE',
#     'polarity': 'neutral',
#     'type': 'label-explicit'}]},
#  {'text': 'sometimes i get bad food and bad service, sometimes i get good good and bad service.',
#   'tags': [{'start': 20,
#     'end': 24,
#     'label': 'FOOD',
#     'polarity': 'negative',
#     'type': 'label-explicit'},
#    {'start': 33,
#     'end': 40,
#     'label': 'SERVICE',
#     'polarity': 'negative',
#     'type': 'label-explicit'},
#    {'start': 76,
#     'end': 83,
#     'label': 'SERVICE',
#     'polarity': 'negative',
#     'type': 'label-explicit'},
#    {'start': 63,
#     'end': 67,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'}]},
#  {'text': 'it is not consistent.',
#   'tags': [{'start': 0,
#     'end': 0,
#     'label': 'GENERAL-IMPRESSION',
#     'polarity': 'negative',
#     'type': 'label-implicit'}]},
#  {'text': 'I started out with a Bombay beer which was big enough for two.',
#   'tags': [{'start': 21,
#     'end': 32,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'}]},
#  {'text': 'MMmmm... it was delicious.',
#   'tags': [{'start': 0,
#     'end': 0,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-implicit'}]},
#  {'text': 'Service was slow, but the people were friendly.',
#   'tags': [{'start': 0,
#     'end': 7,
#     'label': 'SERVICE',
#     'polarity': 'negative',
#     'type': 'label-explicit'},
#    {'start': 26,
#     'end': 32,
#     'label': 'SERVICE',
#     'polarity': 'positive',
#     'type': 'label-explicit'}]},
#  {'text': "It's a nice place to relax and have conversation.",
#   'tags': [{'start': 12,
#     'end': 17,
#     'label': 'AMBIENCE',
#     'polarity': 'positive',
#     'type': 'label-explicit'}]},
#  {'text': "I can't wait to go back.",
#   'tags': [{'start': 0,
#     'end': 0,
#     'label': 'GENERAL-IMPRESSION',
#     'polarity': 'positive',
#     'type': 'label-implicit'}]},
#  {'text': 'Service here was great, food was fantastic.',
#   'tags': [{'start': 0,
#     'end': 7,
#     'label': 'SERVICE',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 24,
#     'end': 28,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'}]},
#  {'text': "Guacamole+shrimp appetizer was really great, we both had the filet, very good, didn't much like the frites that came with, but the filet was so good, neither of us cared.",
#   'tags': [{'start': 0,
#     'end': 26,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 61,
#     'end': 66,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 100,
#     'end': 106,
#     'label': 'FOOD',
#     'polarity': 'negative',
#     'type': 'label-explicit'}]},
#  {'text': 'Will absolutely visit again.',
#   'tags': [{'start': 0,
#     'end': 0,
#     'label': 'GENERAL-IMPRESSION',
#     'polarity': 'positive',
#     'type': 'label-implicit'}]},
#  {'text': 'This quaint and romantic trattoria is at the top of my Manhattan restaurant list.',
#   'tags': [{'start': 25,
#     'end': 34,
#     'label': 'AMBIENCE',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 25,
#     'end': 34,
#     'label': 'GENERAL-IMPRESSION',
#     'polarity': 'positive',
#     'type': 'label-explicit'}]},
#  {'text': 'The food is delicious - from the specials to the regular menu-fare, the dishes are never a disappointment.',
#   'tags': [{'start': 4,
#     'end': 8,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 72,
#     'end': 78,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 33,
#     'end': 41,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 49,
#     'end': 66,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'}]},
#  {'text': "Whether it's the parmesean porcini souffle or the lamb glazed with balsamic vinegar, you will surely be transported to Northern Italy with one bite.",
#   'tags': [{'start': 17,
#     'end': 42,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 50,
#     'end': 83,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'}]},
#  {'text': 'Although the tables may be closely situated, the candle-light, food-quality and service overcompensate.',
#   'tags': [{'start': 49,
#     'end': 61,
#     'label': 'AMBIENCE',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 63,
#     'end': 67,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 80,
#     'end': 87,
#     'label': 'SERVICE',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 13,
#     'end': 19,
#     'label': 'AMBIENCE',
#     'polarity': 'negative',
#     'type': 'label-explicit'}]},
#  {'text': 'A guaranteeed delight!',
#   'tags': [{'start': 0,
#     'end': 0,
#     'label': 'GENERAL-IMPRESSION',
#     'polarity': 'positive',
#     'type': 'label-implicit'}]},
#  {'text': 'this little place has a cute interior decor and affordable city prices.',
#   'tags': [{'start': 29,
#     'end': 43,
#     'label': 'AMBIENCE',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 12,
#     'end': 17,
#     'label': 'GENERAL-IMPRESSION',
#     'polarity': 'positive',
#     'type': 'label-explicit'}]},
#  {'text': 'the pad se ew chicken was delicious, however the pad thai was far too oily.',
#   'tags': [{'start': 4,
#     'end': 21,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 49,
#     'end': 57,
#     'label': 'FOOD',
#     'polarity': 'negative',
#     'type': 'label-explicit'}]},
#  {'text': 'I was very disappointed with this restaurant.',
#   'tags': [{'start': 34,
#     'end': 44,
#     'label': 'GENERAL-IMPRESSION',
#     'polarity': 'negative',
#     'type': 'label-explicit'}]},
#  {'text': 'Ive asked a cart attendant for a lotus leaf wrapped rice and she replied back rice and just walked away.',
#   'tags': [{'start': 12,
#     'end': 26,
#     'label': 'SERVICE',
#     'polarity': 'negative',
#     'type': 'label-explicit'}]},
#  {'text': 'I had to ask her three times before she finally came back with the dish Ive requested.',
#   'tags': [{'start': 0,
#     'end': 0,
#     'label': 'SERVICE',
#     'polarity': 'negative',
#     'type': 'label-implicit'}]},
#  {'text': 'Food was okay, nothing great.',
#   'tags': [{'start': 0,
#     'end': 4,
#     'label': 'FOOD',
#     'polarity': 'neutral',
#     'type': 'label-explicit'}]},
#  {'text': 'Chow fun was dry; pork shu mai was more than usually greasy and had to share a table with loud and rude family.',
#   'tags': [{'start': 0,
#     'end': 8,
#     'label': 'FOOD',
#     'polarity': 'negative',
#     'type': 'label-explicit'},
#    {'start': 18,
#     'end': 30,
#     'label': 'FOOD',
#     'polarity': 'negative',
#     'type': 'label-explicit'},
#    {'start': 0,
#     'end': 0,
#     'label': 'GENERAL-IMPRESSION',
#     'polarity': 'negative',
#     'type': 'label-implicit'}]},
#  {'text': 'I/we will never go back to this place again.',
#   'tags': [{'start': 32,
#     'end': 37,
#     'label': 'GENERAL-IMPRESSION',
#     'polarity': 'negative',
#     'type': 'label-explicit'}]},
#  {'text': 'Excellent food, although the interior could use some help.',
#   'tags': [{'start': 10,
#     'end': 14,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 29,
#     'end': 37,
#     'label': 'AMBIENCE',
#     'polarity': 'negative',
#     'type': 'label-explicit'}]},
#  {'text': 'The space kind of feels like an Alice in Wonderland setting, without it trying to be that.',
#   'tags': [{'start': 4,
#     'end': 9,
#     'label': 'AMBIENCE',
#     'polarity': 'negative',
#     'type': 'label-explicit'}]},
#  {'text': 'I paid just about $60 for a good meal, though :)',
#   'tags': [{'start': 33,
#     'end': 37,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'},
#    {'start': 33,
#     'end': 37,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'}]},
#  {'text': 'Great sake!',
#   'tags': [{'start': 6,
#     'end': 10,
#     'label': 'FOOD',
#     'polarity': 'positive',
#     'type': 'label-explicit'}]},
#  {'text': 'Way below average',
#   'tags': [{'start': 0,
#     'end': 0,
#     'label': 'GENERAL-IMPRESSION',
#     'polarity': 'negative',
#     'type': 'label-implicit'}]},
#  {'text': 'I think the pizza is so overrated and was under cooked.',
#   'tags': [{'start': 12,
#     'end': 17,
#     'label': 'FOOD',
#     'polarity': 'negative',
#     'type': 'label-explicit'}]},
#  {'text': 'Had no flavor and the staff is rude and not attentive.',
#   'tags': [{'start': 22,
#     'end': 27,
#     'label': 'SERVICE',
#     'polarity': 'negative',
#     'type': 'label-explicit'},
#    {'start': 0,
#     'end': 0,
#     'label': 'FOOD',
#     'polarity': 'negative',
#     'type': 'label-implicit'}]},
#  {'text': 'Would NEVER go back',
#   'tags': [{'start': 0,
#     'end': 0,
#     'label': 'GENERAL-IMPRESSION',
#     'polarity': 'negative',
#     'type': 'label-implicit'}]}]

# %% [markdown]
# # XML Tagger
# - @Nils Hellwig

# %%
from collections import Counter
import uuid
import re


def convert_ner_to_xml(ner_dict):
    text = ner_dict['text']
    tags = ner_dict['tags']
    tag_positions = []

    for tag in tags:
        start = tag['start']
        end = tag['end']
        label = tag['label']
        polarity = tag['polarity']
        tag_type = tag['type']

        if tag_type == 'label-explicit':
            tag_positions.append(
                (start, f'<aspect-term aspect="{label}" polarity="{polarity}">'))
            tag_positions.append((end, '</aspect-term>'))

    tag_positions.sort(reverse=True, key=lambda x: x[0])

    xml_text = list(text)
    for position, tag in tag_positions:
        xml_text.insert(position, tag)

    return ''.join(xml_text)


def remove_xml_tags_from_string(str):
    return re.sub(r'<.*?>', '', str)


def remove_xml_tags(input_string):
    return re.sub(r'<[^>]+>', '', input_string)


def extract_aspect_polarity(xml_string):
    aspect_match = re.search(r'aspect="([^"]+)"', xml_string)
    polarity_match = re.search(r'polarity="([^"]+)"', xml_string)

    aspect = aspect_match.group(1) if aspect_match else None
    polarity = polarity_match.group(1) if polarity_match else None

    return aspect, polarity


def get_explicit_aspects(tags, predicted_text):

    # 1. match position
    pattern = r"<aspect-term(?!.*<aspect-term).*?<\/aspect-term>"
    matches = list(re.finditer(pattern, predicted_text))
    if len(matches) == 0:
        return tags, predicted_text  # Return tags and the updated text

    match = matches[0]

    # 2. position in text with tags
    tag_xml = match.group()
    tag_xml_start = match.start()
    tag_xml_end = match.end()

    # 3. identify aspect and polarity
    aspect, polarity = extract_aspect_polarity(tag_xml)

    # 4. position in text without tags
    tag_text = remove_xml_tags(tag_xml)
    tag_start = len(remove_xml_tags(predicted_text[0:match.start()]))
    tag_end = tag_start + len(tag_text)

    # 5. remove tag from text
    predicted_text = predicted_text[0:tag_xml_start] + \
        tag_text + predicted_text[tag_xml_end:]

    # 6. add tags to list
    tags.append({"text": tag_text, "start": tag_start, "end": tag_end, "tag_with_polarity": aspect+"-"+polarity,
                "tag_with_polarity_and_type": aspect+"-"+polarity+"-explicit", "type": "label-explicit", "label": aspect, "polarity": polarity})

    # Recursive call
    return get_explicit_aspects(tags, predicted_text)


def check_difference_between_tags_in_synth_text_and_label(label, tags_synth):
    """
    This function identifies the differences between aspect-polarity pairs in the label and the synthesised text.

    Args:
    label (list of tuples): The aspect-polarity pairs in the label.
    tags_synth (list of tuples): The aspect-polarity pairs in the synthesised text.

    Returns:
    tuple: A tuple containing two lists:
        - List of aspect-polarity pairs present in the label but not in the synthesised text.
        - List of aspect-polarity pairs present in the synthesised text but not in the label.
    """
    
    # Count the occurrences of aspect-polarity pairs in the label and synthesised text
    label_count = Counter(label)
    tags_synth_count = Counter(tags_synth)
    
    # Find aspect-polarity pairs in the label but not in the synthesised text
    not_in_tags_synth_count = [tup for tup, count in label_count.items() for _ in range(max(0, count - tags_synth_count.get(tup, 0)))]
    
    # Find aspect-polarity pairs in the synthesised text but not in the label
    not_in_label = [tup for tup, count in tags_synth_count.items() if count > label_count.get(tup, 0)]
    
    return not_in_tags_synth_count, not_in_label

# %%
# Convert dictionary to xml
ner_dict = xml_dict_transformation(xml_dict)
example = ner_dict[0]
xml = convert_ner_to_xml(example)

print(xml)
# Out:
# 41
# If you've ever been along the river in Weehawken you have an idea of the top of <aspect-term aspect="AMBIENCE" polarity="positive">view</aspect-term> the chart house has to offer.

# %% [markdown]
# # Translations
# - 1. Locally run gemma 7b
# - 2. GoogleTranslate

# %%
# PromptLoader

class PromptLoader():

    """This loads different prompts in order to compare different them and prevent hallucinations e.g. unwanted characters"""

    def __init__(self, prompt_example):
        self.prompt_example = prompt_example

    def load_basic_prompt(self):

        return f"""Translate the following restaurant review to german. Maintain aspect and sentiment annotations. Text in english: {self.prompt_example}
        Text in german: 
        """

    def load_guard_rail_prompt(self):
        return f"""Translate the following restaurant review to German. The string contains xml-Tags that need to be maintained after the translation. Return only the translated string. Here is the following review in english: {self.prompt_example} \\ Translated review in german: """

# %%
ollama_prompt = f"""Translate the following restaurant review to German. The string contains xml-Tags that need to be maintained after the translation.
Text English: {xml} Text German:"""

print(ollama_prompt)
# Out:
# Translate the following restaurant review to German. The string contains xml-Tags that need to be maintained after the translation.
# Text English: If you've ever been along the river in Weehawken you have an idea of the top of <aspect-term aspect="AMBIENCE" polarity="positive">view</aspect-term> the chart house has to offer. Text German:

# %%
pl = PromptLoader(prompt_example=xml)
ollama_prompt = pl.load_guard_rail_prompt()
print(ollama_prompt)
# Out:
# Translate the following restaurant review to German. The string contains xml-Tags that need to be maintained after the translation. Return only the translated string. Here is the following review in english: If you've ever been along the river in Weehawken you have an idea of the top of <aspect-term aspect="AMBIENCE" polarity="positive">view</aspect-term> the chart house has to offer. \ Translated review in german:

# %%
from ollama import chat
from ollama import ChatResponse



response: ChatResponse = chat(model='gemma:7b', messages=[
  {
    'role': 'user',
    'content': ollama_prompt,
  },
])
# print(response['message']['content'])
# or access fields directly from the response object
print(response.message.content)
# Out:
# Wenn Sie jemals entlang des Flusses in Weehawken waren, wissen Sie, was die Chart House zu bieten hat: die beste <aspect-term aspect="AMBIENCE" polarity="positive">Ansicht</aspect-term> an der ganzen Reihe.

# %%
from deep_translator import GoogleTranslator

google_translated = GoogleTranslator(source='en', target='de').translate(text=xml)
print(google_translated)
# Out:
# Wenn Sie schon einmal am Fluss in Weehawken waren, haben Sie eine Vorstellung von der besten <aspect-term aspect="AMBIENCE" polarity="positive">Aussicht</aspect-term>, die das Kartenhaus zu bieten hat.

# %%
# Notizen:
# gemma:7b macht grammatikalische Fehler, teilweise wird die Prompt Anleitung "Text German" als Antwort mit übernommen (Halluzination)

# %% [markdown]
# # Dataset - Full TASD Tagging with Google Translator
# - Translation of the Training Dataset Rest16 and Rest15

# %%
xml_file_path16 = "data\\ABSA16_Restaurants_Train_SB1_v2.xml"
xml_file_path15 = "data\\ABSA-15_Restaurants_Train_Final.xml"

# Read the XML file
with open(xml_file_path16, "r", encoding="utf-8") as file:
    xml_content = file.read()

# Convert XML to Python dictionary
xml_dict = xmltodict.parse(xml_content)

# %%
xml_dict
# Out:
# {'Reviews': {'Review': [{'@rid': '1004293',
#     'sentences': {'sentence': [{'@id': '1004293:0',
#        'text': 'Judging from previous posts this used to be a good place, but not any longer.',
#        'Opinions': {'Opinion': {'@target': 'place',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'negative',
#          '@from': '51',
#          '@to': '56'}}},
#       {'@id': '1004293:1',
#        'text': 'We, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude.',
#        'Opinions': {'Opinion': {'@target': 'staff',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '75',
#          '@to': '80'}}},
#       {'@id': '1004293:2',
#        'text': 'They never brought us complimentary noodles, ignored repeated requests for sugar, and threw our dishes on the table.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': '1004293:3',
#        'text': 'The food was lousy - too sweet or too salty and the portions tiny.',
#        'Opinions': {'Opinion': [{'@target': 'food',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '4',
#           '@to': '8'},
#          {'@target': 'portions',
#           '@category': 'FOOD#STYLE_OPTIONS',
#           '@polarity': 'negative',
#           '@from': '52',
#           '@to': '60'}]}},
#       {'@id': '1004293:4',
#        'text': 'After all that, they complained to me about the small tip.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': '1004293:5',
#        'text': 'Avoid this place!',
#        'Opinions': {'Opinion': {'@target': 'place',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'negative',
#          '@from': '11',
#          '@to': '16'}}}]}},
#    {'@rid': '1014458',
#     'sentences': {'sentence': [{'@id': '1014458:0',
#        'text': 'I have eaten at Saul, many times, the food is always consistently, outrageously good.',
#        'Opinions': {'Opinion': {'@target': 'food',
#          '@category': 'FOOD#QUALITY',
#          '@polarity': 'positive',
#          '@from': '38',
#          '@to': '42'}}},
#       {'@id': '1014458:1',
#        'text': 'Saul is the best restaurant on Smith Street and in Brooklyn.',
#        'Opinions': {'Opinion': {'@target': 'Saul',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '4'}}},
#       {'@id': '1014458:2',
#        'text': 'The duck confit is always amazing and the foie gras terrine with figs was out of this world.',
#        'Opinions': {'Opinion': [{'@target': 'foie gras terrine with figs',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '42',
#           '@to': '69'},
#          {'@target': 'duck confit',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '15'}]}},
#       {'@id': '1014458:3',
#        'text': 'The wine list is interesting and has many good values.',
#        'Opinions': {'Opinion': [{'@target': 'wine list',
#           '@category': 'DRINKS#STYLE_OPTIONS',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '13'},
#          {'@target': 'wine list',
#           '@category': 'DRINKS#PRICES',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '13'}]}},
#       {'@id': '1014458:4',
#        'text': 'For the price, you cannot eat this well in Manhattan.',
#        'Opinions': {'Opinion': [{'@target': 'NULL',
#           '@category': 'RESTAURANT#PRICES',
#           '@polarity': 'positive',
#           '@from': '0',
#           '@to': '0'},
#          {'@target': 'NULL',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '0',
#           '@to': '0'}]}}]}},
#    {'@rid': '1016296',
#     'sentences': {'sentence': [{'@id': '1016296:0',
#        'text': 'I was very disappointed with this restaurant.',
#        'Opinions': {'Opinion': {'@target': 'restaurant',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'negative',
#          '@from': '34',
#          '@to': '44'}}},
#       {'@id': '1016296:1',
#        'text': 'Ive asked a cart attendant for a lotus leaf wrapped rice and she replied back rice and just walked away.',
#        'Opinions': {'Opinion': {'@target': 'cart attendant',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '12',
#          '@to': '26'}}},
#       {'@id': '1016296:2',
#        'text': 'I had to ask her three times before she finally came back with the dish Ive requested.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': '1016296:3',
#        'text': 'Food was okay, nothing great.',
#        'Opinions': {'Opinion': {'@target': 'Food',
#          '@category': 'FOOD#QUALITY',
#          '@polarity': 'neutral',
#          '@from': '0',
#          '@to': '4'}}},
#       {'@id': '1016296:4',
#        'text': 'Chow fun was dry; pork shu mai was more than usually greasy and had to share a table with loud and rude family.',
#        'Opinions': {'Opinion': [{'@target': 'Chow fun',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '0',
#           '@to': '8'},
#          {'@target': 'pork shu mai',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '18',
#           '@to': '30'},
#          {'@target': 'NULL',
#           '@category': 'RESTAURANT#MISCELLANEOUS',
#           '@polarity': 'negative',
#           '@from': '0',
#           '@to': '0'}]}},
#       {'@id': '1016296:5',
#        'text': 'I/we will never go back to this place again.',
#        'Opinions': {'Opinion': {'@target': 'place',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'negative',
#          '@from': '32',
#          '@to': '37'}}}]}},
#    {'@rid': '1028246',
#     'sentences': {'sentence': [{'@id': '1028246:0',
#        'text': 'Went on a 3 day oyster binge, with Fish bringing up the closing, and I am so glad this was the place it O trip ended, because it was so great!',
#        'Opinions': {'Opinion': {'@target': 'Fish',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '35',
#          '@to': '39'}}},
#       {'@id': '1028246:1',
#        'text': "Service was devine, oysters where a sensual as they come, and the price can't be beat!!!",
#        'Opinions': {'Opinion': [{'@target': 'Service',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'positive',
#           '@from': '0',
#           '@to': '7'},
#          {'@target': 'oysters',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '20',
#           '@to': '27'},
#          {'@target': 'NULL',
#           '@category': 'RESTAURANT#PRICES',
#           '@polarity': 'positive',
#           '@from': '0',
#           '@to': '0'}]}},
#       {'@id': '1028246:2',
#        'text': "You can't go wrong here.",
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '0'}}}]}},
#    {'@rid': '1032695',
#     'sentences': {'sentence': [{'@id': '1032695:0',
#        'text': 'Every time in New York I make it a point to visit Restaurant Saul on Smith Street.',
#        'Opinions': {'Opinion': {'@target': 'Restaurant Saul',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '50',
#          '@to': '65'}}},
#       {'@id': '1032695:1',
#        'text': 'Everything is always cooked to perfection, the service is excellent, the decor cool and understated.',
#        'Opinions': {'Opinion': [{'@target': 'NULL',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '0',
#           '@to': '0'},
#          {'@target': 'service',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'positive',
#           '@from': '47',
#           '@to': '54'},
#          {'@target': 'decor',
#           '@category': 'AMBIENCE#GENERAL',
#           '@polarity': 'positive',
#           '@from': '73',
#           '@to': '78'}]}},
#       {'@id': '1032695:2',
#        'text': 'I had the duck breast special on my last visit and it was incredible.',
#        'Opinions': {'Opinion': {'@target': 'duck breast special',
#          '@category': 'FOOD#QUALITY',
#          '@polarity': 'positive',
#          '@from': '10',
#          '@to': '29'}}},
#       {'@id': '1032695:3',
#        'text': "Can't wait wait for my next visit.",
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '0'}}}]}},
#    {'@rid': '1041457',
#     'sentences': {'sentence': [{'@id': '1041457:0',
#        'text': "I had my eyes on this place, promising myself I will one day 'give it a try.'"},
#       {'@id': '1041457:1',
#        'text': "And I hate to say this but I doubt I'll ever go back.",
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': '1041457:2',
#        'text': 'The food is very average...the Thai fusion stuff is a bit too sweet, every thing they serve is too sweet here.',
#        'Opinions': {'Opinion': [{'@target': 'food',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '4',
#           '@to': '8'},
#          {'@target': 'Thai fusion stuff',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '31',
#           '@to': '48'},
#          {'@target': 'NULL',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '0',
#           '@to': '0'}]}},
#       {'@id': '1041457:3',
#        'text': 'The only thing I moderately enjoyed was their Grilled Chicken special with Edamame Puree.',
#        'Opinions': {'Opinion': {'@target': 'Grilled Chicken special with Edamame Puree',
#          '@category': 'FOOD#QUALITY',
#          '@polarity': 'positive',
#          '@from': '46',
#          '@to': '88'}}},
#       {'@id': '1041457:4',
#        'text': "I had never had Edamame pureed before but I thought it was innovative and tasty (could've used a bit more salt).",
#        'Opinions': {'Opinion': [{'@target': 'Edamame pureed',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '16',
#           '@to': '30'},
#          {'@target': 'Edamame pureed',
#           '@category': 'FOOD#STYLE_OPTIONS',
#           '@polarity': 'positive',
#           '@from': '16',
#           '@to': '30'}]}},
#       {'@id': '1041457:5',
#        '@OutOfScope': 'TRUE',
#        'text': "Anyways, if you're in the neighborhood to eat good food, I wouldn't waste my time trying to find something, rather go across the street to Tamari."},
#       {'@id': '1041457:6',
#        'text': 'The decor is night tho...but they REALLY need to clean that vent in the ceiling...its quite un-appetizing, and kills your effort to make this place look sleek and modern.',
#        'Opinions': {'Opinion': [{'@target': 'place',
#           '@category': 'AMBIENCE#GENERAL',
#           '@polarity': 'negative',
#           '@from': '142',
#           '@to': '147'},
#          {'@target': 'decor',
#           '@category': 'AMBIENCE#GENERAL',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '9'},
#          {'@target': 'vent',
#           '@category': 'AMBIENCE#GENERAL',
#           '@polarity': 'negative',
#           '@from': '60',
#           '@to': '64'}]}}]}},
#    {'@rid': '1053543',
#     'sentences': {'sentence': [{'@id': '1053543:0',
#        'text': "We ate outside at Haru's Sake bar because Haru's restaurant next door was overflowing."},
#       {'@id': '1053543:1', 'text': "What's the difference between the two?"},
#       {'@id': '1053543:2',
#        'text': "Their sake list was extensive, but we were looking for Purple Haze, which wasn't listed but made for us upon request!",
#        'Opinions': {'Opinion': [{'@target': 'sake list',
#           '@category': 'DRINKS#STYLE_OPTIONS',
#           '@polarity': 'positive',
#           '@from': '6',
#           '@to': '15'},
#          {'@target': 'NULL',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'positive',
#           '@from': '0',
#           '@to': '0'}]}},
#       {'@id': '1053543:3',
#        'text': 'The spicy tuna roll was unusually good and the rock shrimp tempura was awesome, great appetizer to share!',
#        'Opinions': {'Opinion': [{'@target': 'spicy tuna roll',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '19'},
#          {'@target': 'rock shrimp tempura',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '47',
#           '@to': '66'}]}},
#       {'@id': '1053543:4',
#        'text': 'We went around 9:30 on a Friday and it had died down a bit by then so the service was great!',
#        'Opinions': {'Opinion': {'@target': 'service',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'positive',
#          '@from': '74',
#          '@to': '81'}}}]}},
#    {'@rid': '1055910',
#     'sentences': {'sentence': [{'@id': '1055910:0',
#        'text': 'we love th pink pony.',
#        'Opinions': {'Opinion': {'@target': 'pink pony',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '11',
#          '@to': '20'}}},
#       {'@id': '1055910:1',
#        'text': 'THe perfect spot.',
#        'Opinions': {'Opinion': {'@target': 'spot',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '12',
#          '@to': '16'}}},
#       {'@id': '1055910:2',
#        'text': 'Food-awesome.',
#        'Opinions': {'Opinion': {'@target': 'Food',
#          '@category': 'FOOD#QUALITY',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '4'}}},
#       {'@id': '1055910:3',
#        'text': 'Service- friendly and attentive.',
#        'Opinions': {'Opinion': {'@target': 'Service',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '7'}}},
#       {'@id': '1055910:4',
#        'text': 'Ambiance- relaxed and stylish.',
#        'Opinions': {'Opinion': {'@target': 'Ambiance',
#          '@category': 'AMBIENCE#GENERAL',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '8'}}},
#       {'@id': '1055910:5',
#        'text': "Don't judge this place prima facie, you have to try it to believe it, a home away from home for the literate heart.",
#        'Opinions': {'Opinion': {'@target': 'place',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '17',
#          '@to': '22'}}}]}},
#    {'@rid': '1058221',
#     'sentences': {'sentence': [{'@id': '1058221:0',
#        'text': 'i have eaten here a handful of times, for no reason besides sheer convenience.'},
#       {'@id': '1058221:1',
#        'text': '(i hang out, and live, in the neighborhood..)'},
#       {'@id': '1058221:2',
#        'text': 'the food is decent.',
#        'Opinions': {'Opinion': {'@target': 'food',
#          '@category': 'FOOD#QUALITY',
#          '@polarity': 'neutral',
#          '@from': '4',
#          '@to': '8'}}},
#       {'@id': '1058221:3',
#        'text': "however, it's the service that leaves a bad taste in my mouth.",
#        'Opinions': {'Opinion': {'@target': 'service',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '18',
#          '@to': '25'}}},
#       {'@id': '1058221:4',
#        'text': 'i happen to have a policy that goes along with a little bit of self-respect, which includes not letting a waiter intimidate me, i.e. make me feel bad asking for trivialities like water, or the check.',
#        'Opinions': {'Opinion': {'@target': 'waiter',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '106',
#          '@to': '112'}}},
#       {'@id': '1058221:5',
#        'text': "i know, you were too busy showing off your vintage tee shirt and looking bored, but my agenda is i'm here to eat and enjoy the company of friends, seeking a pleasant experience.",
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': '1058221:6',
#        'text': "well, i didn't find it there, and trust, i have told everyone i can think of about my experience.",
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': '1058221:7',
#        'text': 'the last time i walked by it looked pretty empty. hmmm.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#MISCELLANEOUS',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}}]}},
#    {'@rid': '1062641',
#     'sentences': {'sentence': [{'@id': '1062641:0',
#        'text': 'This place has got to be the best japanese restaurant in the new york area.',
#        'Opinions': {'Opinion': {'@target': 'place',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '5',
#          '@to': '10'}}},
#       {'@id': '1062641:1',
#        'text': 'I had a great experience.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': '1062641:2',
#        'text': 'Food is great.',
#        'Opinions': {'Opinion': {'@target': 'Food',
#          '@category': 'FOOD#QUALITY',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '4'}}},
#       {'@id': '1062641:3',
#        'text': 'Service is top notch.',
#        'Opinions': {'Opinion': {'@target': 'Service',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '7'}}},
#       {'@id': '1062641:4',
#        'text': 'I have been going back again and again.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '0'}}}]}},
#    {'@rid': '1064477',
#     'sentences': {'sentence': [{'@id': '1064477:0',
#        'text': 'I tend to judge a sushi restaurant by its sea urchin, which was heavenly at sushi rose.',
#        'Opinions': {'Opinion': {'@target': 'sea urchin',
#          '@category': 'FOOD#QUALITY',
#          '@polarity': 'positive',
#          '@from': '42',
#          '@to': '52'}}},
#       {'@id': '1064477:1',
#        'text': 'It melted in my little mouth and the perfect consistency-not too fishy, creamy, and slightly buttery.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'FOOD#QUALITY',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': '1064477:2',
#        'text': 'The sushi seemed pretty fresh and was adequately proportioned.',
#        'Opinions': {'Opinion': [{'@target': 'sushi',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '9'},
#          {'@target': 'sushi',
#           '@category': 'FOOD#STYLE_OPTIONS',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '9'}]}},
#       {'@id': '1064477:3',
#        'text': "The rice to fish ration was also good--they didn't try to overpack the rice.",
#        'Opinions': {'Opinion': {'@target': 'rice to fish ration',
#          '@category': 'FOOD#STYLE_OPTIONS',
#          '@polarity': 'positive',
#          '@from': '4',
#          '@to': '23'}}},
#       {'@id': '1064477:4',
#        'text': 'We took advanatage of the half price sushi deal on saturday so it was well worth it.',
#        'Opinions': {'Opinion': [{'@target': 'half price sushi deal',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '26',
#           '@to': '47'},
#          {'@target': 'half price sushi deal',
#           '@category': 'FOOD#PRICES',
#           '@polarity': 'positive',
#           '@from': '26',
#           '@to': '47'}]}}]}},
#    {'@rid': '1074868',
#     'sentences': {'sentence': [{'@id': '1074868:0',
#        'text': 'I went to this restaurant with a woman that I met recently.'},
#       {'@id': '1074868:1',
#        'text': 'She lives nearby but had never gone to this establishment thinking that it might be too touristy.'},
#       {'@id': '1074868:2',
#        'text': 'Surprisingly nothing could be further from the truth.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#MISCELLANEOUS',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': '1074868:3',
#        'text': 'In the evening, this place attracted a well dressed, with it, NY crowd.',
#        'Opinions': {'Opinion': {'@target': 'crowd',
#          '@category': 'RESTAURANT#MISCELLANEOUS',
#          '@polarity': 'positive',
#          '@from': '65',
#          '@to': '70'}}},
#       {'@id': '1074868:4',
#        'text': 'The food was well prepared and the service impecable.',
#        'Opinions': {'Opinion': [{'@target': 'food',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '8'},
#          {'@target': 'service',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'positive',
#           '@from': '35',
#           '@to': '42'}]}},
#       {'@id': '1074868:5',
#        'text': "I'm going back.",
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '0'}}}]}},
#    {'@rid': '1084394',
#     'sentences': {'sentence': [{'@id': '1084394:0',
#        'text': 'Having hunted around for a quiet, romantic, yet not hideously expensive restaurant I stumbled across reviews for La Lanterna and gave it a shot.'},
#       {'@id': '1084394:1',
#        'text': "Quite simply it's like stepping out of Manhattan and into a haven of tranquility.",
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'AMBIENCE#GENERAL',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': '1084394:2',
#        '@OutOfScope': 'TRUE',
#        'text': 'The service was attentive, yet unimposing, the food was far better than many notorious restaurants in Midtown and the wine list is extensive and well priced.'},
#       {'@id': '1084394:3',
#        'text': 'The Prix Fixe menu is worth every penny and you get more than enough (both in quantity AND quality).',
#        'Opinions': {'Opinion': [{'@target': 'Prix Fixe menu',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '18'},
#          {'@target': 'Prix Fixe menu',
#           '@category': 'FOOD#STYLE_OPTIONS',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '18'},
#          {'@target': 'Prix Fixe menu',
#           '@category': 'FOOD#PRICES',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '18'}]}},
#       {'@id': '1084394:4',
#        'text': 'I will be going back and heartily recommend it!',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '0'}}}]}},
#    {'@rid': '1086415',
#     'sentences': {'sentence': [{'@id': '1086415:0',
#        'text': "I've had the lunch buffet at Chennai a couple of times, when I have been in the neighborhood."},
#       {'@id': '1086415:1',
#        'text': 'It is terrific, as is the value.',
#        'Opinions': {'Opinion': [{'@target': 'NULL',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '0',
#           '@to': '0'},
#          {'@target': 'NULL',
#           '@category': 'FOOD#PRICES',
#           '@polarity': 'positive',
#           '@from': '0',
#           '@to': '0'}]}},
#       {'@id': '1086415:2',
#        'text': '$6 and there is much tasty food, all of it fresh and continually refilled.',
#        'Opinions': {'Opinion': [{'@target': 'food',
#           '@category': 'FOOD#STYLE_OPTIONS',
#           '@polarity': 'positive',
#           '@from': '27',
#           '@to': '31'},
#          {'@target': 'food',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '27',
#           '@to': '31'},
#          {'@target': 'food',
#           '@category': 'FOOD#PRICES',
#           '@polarity': 'positive',
#           '@from': '27',
#           '@to': '31'}]}},
#       {'@id': '1086415:3',
#        'text': 'I am not a vegetarian but, almost all the dishes were great.',
#        'Opinions': {'Opinion': {'@target': 'dishes',
#          '@category': 'FOOD#QUALITY',
#          '@polarity': 'positive',
#          '@from': '42',
#          '@to': '48'}}},
#       {'@id': '1086415:4',
#        '@OutOfScope': 'TRUE',
#        'text': 'Frankly, when you compare what you can have here for lunch, versus McDs or so many other sandwich shops in the city, there is no comparison.'},
#       {'@id': '1086415:5',
#        'text': 'Go hungry and enjoy.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '0'}}}]}},
#    {'@rid': '1086478',
#     'sentences': {'sentence': [{'@id': '1086478:0',
#        'text': 'The food here is rather good, but only if you like to wait for it.',
#        'Opinions': {'Opinion': [{'@target': 'food',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '8'},
#          {'@target': 'NULL',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'negative',
#           '@from': '0',
#           '@to': '0'}]}},
#       {'@id': '1086478:1',
#        'text': 'I like the somosas, chai, and the chole, but the dhosas and dhal were kinda dissapointing.',
#        'Opinions': {'Opinion': [{'@target': 'somosas',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '11',
#           '@to': '18'},
#          {'@target': 'chai',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '20',
#           '@to': '24'},
#          {'@target': 'chole',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '34',
#           '@to': '39'},
#          {'@target': 'dhosas',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '49',
#           '@to': '55'},
#          {'@target': 'dhal',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '60',
#           '@to': '64'}]}},
#       {'@id': '1086478:2',
#        'text': "The service varys from day to day- sometimes they're very nice, and sometimes not.",
#        'Opinions': {'Opinion': {'@target': 'service',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '4',
#          '@to': '11'}}},
#       {'@id': '1086478:3',
#        'text': 'The kitchen however, is almost always slow.',
#        'Opinions': {'Opinion': {'@target': 'kitchen',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '4',
#          '@to': '11'}}},
#       {'@id': '1086478:4',
#        'text': "Also, specify if you like your food spicy- its rather bland if you don't.",
#        'Opinions': {'Opinion': {'@target': 'food',
#          '@category': 'FOOD#QUALITY',
#          '@polarity': 'negative',
#          '@from': '31',
#          '@to': '35'}}},
#       {'@id': '1086478:5',
#        'text': 'The ambience is pretty and nice for conversation, so a casual lunch here would probably be best.',
#        'Opinions': {'Opinion': [{'@target': 'ambience',
#           '@category': 'AMBIENCE#GENERAL',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '12'},
#          {'@target': 'NULL',
#           '@category': 'RESTAURANT#MISCELLANEOUS',
#           '@polarity': 'positive',
#           '@from': '0',
#           '@to': '0'}]}}]}},
#    {'@rid': '1090587',
#     'sentences': {'sentence': [{'@id': '1090587:0',
#        'text': 'Just went here for my girlfriends 23rd bday.'},
#       {'@id': '1090587:1',
#        'text': "If you've ever been along the river in Weehawken you have an idea of the top of view the chart house has to offer.",
#        'Opinions': {'Opinion': {'@target': 'view',
#          '@category': 'LOCATION#GENERAL',
#          '@polarity': 'positive',
#          '@from': '80',
#          '@to': '84'}}},
#       {'@id': '1090587:2',
#        'text': 'Add to that great service and great food at a reasonable price and you have yourself the beginning of a great evening.',
#        'Opinions': {'Opinion': [{'@target': 'service',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'positive',
#           '@from': '18',
#           '@to': '25'},
#          {'@target': 'food',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '36',
#           '@to': '40'},
#          {'@target': 'food',
#           '@category': 'FOOD#PRICES',
#           '@polarity': 'positive',
#           '@from': '36',
#           '@to': '40'}]}},
#       {'@id': '1090587:3',
#        'text': 'The lava cake dessert was incredible and I recommend it.',
#        'Opinions': {'Opinion': {'@target': 'lava cake dessert',
#          '@category': 'FOOD#QUALITY',
#          '@polarity': 'positive',
#          '@from': '4',
#          '@to': '21'}}}]}},
#    {'@rid': '1102681',
#     'sentences': {'sentence': [{'@id': '1102681:0',
#        'text': "Once you step into Cosette, you're miraculously in a small, off-the-beaten path Parisian bistro.",
#        'Opinions': {'Opinion': {'@target': 'Cosette',
#          '@category': 'AMBIENCE#GENERAL',
#          '@polarity': 'positive',
#          '@from': '19',
#          '@to': '26'}}},
#       {'@id': '1102681:1',
#        'text': 'This tiny restaurant is as cozy as it gets, with that certain Parisian flair.',
#        'Opinions': {'Opinion': {'@target': 'restaurant',
#          '@category': 'AMBIENCE#GENERAL',
#          '@polarity': 'positive',
#          '@from': '10',
#          '@to': '20'}}},
#       {'@id': '1102681:2',
#        'text': 'The food was average to above-average; the French Onion soup filling yet not overly impressive, and the desserts not brilliant in any way.',
#        'Opinions': {'Opinion': [{'@target': 'food',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '8'},
#          {'@target': 'French Onion soup',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '43',
#           '@to': '60'},
#          {'@target': 'French Onion soup',
#           '@category': 'FOOD#STYLE_OPTIONS',
#           '@polarity': 'positive',
#           '@from': '43',
#           '@to': '60'},
#          {'@target': 'desserts',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '104',
#           '@to': '112'}]}},
#       {'@id': '1102681:3',
#        'text': 'However, go for the ambience, and consider the food just a companion for a trip across the world!',
#        'Opinions': {'Opinion': [{'@target': 'ambience',
#           '@category': 'AMBIENCE#GENERAL',
#           '@polarity': 'positive',
#           '@from': '20',
#           '@to': '28'},
#          {'@target': 'food',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'neutral',
#           '@from': '47',
#           '@to': '51'}]}}]}},
#    {'@rid': '1118167',
#     'sentences': {'sentence': [{'@id': '1118167:0',
#        'text': 'I have never eaten in the restaurant, however, upon reading the reviews I got take out last week.'},
#       {'@id': '1118167:1',
#        'text': 'IT WAS HORRIBLE.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': '1118167:2',
#        'text': "The pizza was delivered cold and the cheese wasn't even fully melted!",
#        'Opinions': {'Opinion': [{'@target': 'pizza',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '4',
#           '@to': '9'},
#          {'@target': 'cheese',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '37',
#           '@to': '43'}]}},
#       {'@id': '1118167:3',
#        'text': 'It looked like shredded cheese partly done - still in strips.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'FOOD#STYLE_OPTIONS',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': '1118167:4',
#        '@OutOfScope': 'TRUE',
#        'text': 'I have eaten at many pizza places around NYC and this is hands down the worst.'}]}},
#    {'@rid': '1119578',
#     'sentences': {'sentence': [{'@id': '1119578:0',
#        'text': 'This has got to be one of the most overrated restaurants in Brooklyn.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': '1119578:1',
#        'text': 'The pizza is overpriced and soggy.',
#        'Opinions': {'Opinion': [{'@target': 'pizza',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '4',
#           '@to': '9'},
#          {'@target': 'pizza',
#           '@category': 'FOOD#PRICES',
#           '@polarity': 'negative',
#           '@from': '4',
#           '@to': '9'}]}},
#       {'@id': '1119578:2',
#        'text': "Yes, they use fancy ingredients, but even fancy ingredients don't make for good pizza unless someone knows how to get the crust right.",
#        'Opinions': {'Opinion': [{'@target': 'ingredients',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '20',
#           '@to': '31'},
#          {'@target': 'pizza',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '80',
#           '@to': '85'},
#          {'@target': 'crust',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '122',
#           '@to': '127'}]}},
#       {'@id': '1119578:3',
#        'text': 'A big disappointment, all around.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}}]}},
#    {'@rid': '1123262',
#     'sentences': {'sentence': [{'@id': '1123262:0',
#        'text': "I think I've had some the best meals of my life at minnow.",
#        'Opinions': {'Opinion': {'@target': 'meals',
#          '@category': 'FOOD#QUALITY',
#          '@polarity': 'positive',
#          '@from': '31',
#          '@to': '36'}}},
#       {'@id': '1123262:1',
#        'text': "The seafood is amazing, there's a good wine list, and the ever-changing menu always offers some great surprises.",
#        'Opinions': {'Opinion': [{'@target': 'seafood',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '11'},
#          {'@target': 'wine list',
#           '@category': 'DRINKS#STYLE_OPTIONS',
#           '@polarity': 'positive',
#           '@from': '39',
#           '@to': '48'},
#          {'@target': 'menu',
#           '@category': 'FOOD#STYLE_OPTIONS',
#           '@polarity': 'positive',
#           '@from': '72',
#           '@to': '76'}]}},
#       {'@id': '1123262:2',
#        'text': 'The combination of super-fresh ingredients in the dishes are unusual but really delicious.',
#        'Opinions': {'Opinion': {'@target': 'ingredients',
#          '@category': 'FOOD#QUALITY',
#          '@polarity': 'positive',
#          '@from': '31',
#          '@to': '42'}}},
#       {'@id': '1123262:3',
#        'text': 'Worth the trip from Manhattan.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '0'}}}]}},
#    {'@rid': '1125006',
#     'sentences': {'sentence': [{'@id': '1125006:0',
#        'text': 'Was there Friday night.'},
#       {'@id': '1125006:1',
#        'text': 'Best Pastrami I ever had and great portion without being ridiculous.',
#        'Opinions': {'Opinion': [{'@target': 'Pastrami',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '5',
#           '@to': '13'},
#          {'@target': 'portion',
#           '@category': 'FOOD#STYLE_OPTIONS',
#           '@polarity': 'positive',
#           '@from': '35',
#           '@to': '42'}]}},
#       {'@id': '1125006:2', 'text': "And I've been to many NYC delis."},
#       {'@id': '1125006:3',
#        'text': 'My wife had the fried shrimp which are huge and loved it.',
#        'Opinions': {'Opinion': [{'@target': 'fried shrimp',
#           '@category': 'FOOD#STYLE_OPTIONS',
#           '@polarity': 'positive',
#           '@from': '16',
#           '@to': '28'},
#          {'@target': 'fried shrimp',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '16',
#           '@to': '28'}]}},
#       {'@id': '1125006:4',
#        '@OutOfScope': 'TRUE',
#        'text': 'Price no more than a Jersey deli but way better.'}]}},
#    {'@rid': '1125284',
#     'sentences': {'sentence': [{'@id': '1125284:0',
#        'text': "As a Japanese native, I've lived in the Tristate area for over 8 years, but I was just so amazed at this place.",
#        'Opinions': {'Opinion': {'@target': 'place',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '105',
#          '@to': '110'}}},
#       {'@id': '1125284:1',
#        'text': 'This place is the most Japanese it can ever get.',
#        'Opinions': {'Opinion': {'@target': 'place',
#          '@category': 'RESTAURANT#MISCELLANEOUS',
#          '@polarity': 'positive',
#          '@from': '5',
#          '@to': '10'}}},
#       {'@id': '1125284:2',
#        'text': 'The signs, the specials menus, food, and even all the waitstaff are ALL TOTALLY Japanese.',
#        'Opinions': {'Opinion': [{'@target': 'signs',
#           '@category': 'RESTAURANT#MISCELLANEOUS',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '9'},
#          {'@target': 'specials menus',
#           '@category': 'FOOD#STYLE_OPTIONS',
#           '@polarity': 'positive',
#           '@from': '15',
#           '@to': '29'},
#          {'@target': 'food',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '31',
#           '@to': '35'},
#          {'@target': 'waitstaff',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'positive',
#           '@from': '54',
#           '@to': '63'}]}},
#       {'@id': '1125284:3',
#        'text': 'This place is worth an one-hour drive.',
#        'Opinions': {'Opinion': {'@target': 'place',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '5',
#          '@to': '10'}}},
#       {'@id': '1125284:4',
#        'text': 'I am so coming back here again, as much as I can.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '0'}}}]}},
#    {'@rid': '1126814',
#     'sentences': {'sentence': [{'@id': '1126814:0',
#        'text': 'Leon is an East Village gem: casual but hip, with well prepared basic French bistro fare, good specials, a warm and lively atmosphere.',
#        'Opinions': {'Opinion': [{'@target': 'Leon',
#           '@category': 'RESTAURANT#GENERAL',
#           '@polarity': 'positive',
#           '@from': '0',
#           '@to': '4'},
#          {'@target': 'Leon',
#           '@category': 'AMBIENCE#GENERAL',
#           '@polarity': 'positive',
#           '@from': '0',
#           '@to': '4'},
#          {'@target': 'specials',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '95',
#           '@to': '103'},
#          {'@target': 'atmosphere',
#           '@category': 'AMBIENCE#GENERAL',
#           '@polarity': 'positive',
#           '@from': '123',
#           '@to': '133'},
#          {'@target': 'French bistro fare',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '70',
#           '@to': '88'}]}},
#       {'@id': '1126814:1',
#        'text': 'My wife and I always enjoy the young, not always well trained but nevertheless friendly, staff, all of whom have a story.',
#        'Opinions': {'Opinion': {'@target': 'staff',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'positive',
#          '@from': '89',
#          '@to': '94'}}},
#       {'@id': '1126814:2',
#        'text': 'Sit outside in the warm weather; inside for cozy winter.'},
#       {'@id': '1126814:3',
#        'text': 'Decent wine at reasonable prices.',
#        'Opinions': {'Opinion': [{'@target': 'wine',
#           '@category': 'DRINKS#QUALITY',
#           '@polarity': 'neutral',
#           '@from': '7',
#           '@to': '11'},
#          {'@target': 'wine',
#           '@category': 'DRINKS#PRICES',
#           '@polarity': 'positive',
#           '@from': '7',
#           '@to': '11'}]}},
#       {'@id': '1126814:4',
#        'text': 'Have been dozens of times and never failed to enjoy the experience.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': '1126814:5',
#        'text': 'Our teenage kids love it, too.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '0',
#          '@to': '0'}}}]}},
#    {'@rid': '1126886',
#     'sentences': {'sentence': [{'@id': '1126886:0',
#        'text': "Everytime I decide to try another place on the UES, I get angry that I didn't just go to Zucchero Pomodori.",
#        'Opinions': {'Opinion': {'@target': 'Zucchero Pomodori',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '89',
#          '@to': '106'}}},
#       {'@id': '1126886:1',
#        'text': 'This is by far my favorite place in the neighborhood.',
#        'Opinions': {'Opinion': {'@target': 'place',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '27',
#          '@to': '32'}}},
#       {'@id': '1126886:2',
#        'text': 'The service is excellent, the decor is great, and the food is delicious and comes in large portions.',
#        'Opinions': {'Opinion': [{'@target': 'service',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '11'},
#          {'@target': 'decor',
#           '@category': 'AMBIENCE#GENERAL',
#           '@polarity': 'positive',
#           '@from': '30',
#           '@to': '35'},
#          {'@target': 'food',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '54',
#           '@to': '58'},
#          {'@target': 'portions',
#           '@category': 'FOOD#STYLE_OPTIONS',
#           '@polarity': 'positive',
#           '@from': '91',
#           '@to': '99'}]}},
#       {'@id': '1126886:3',
#        '@OutOfScope': 'TRUE',
#        'text': "You'll pay at least double at any other Italian restaurant in the city, and most still don't compare."},
#       {'@id': '1126886:4',
#        'text': "I'm partial to the Gnocchi.",
#        'Opinions': {'Opinion': {'@target': 'Gnocchi',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '19',
#          '@to': '26'}}}]}},
#    {'@rid': '1131595',
#     'sentences': {'sentence': [{'@id': '1131595:0',
#        'text': 'This place is incredibly tiny.',
#        'Opinions': {'Opinion': {'@target': 'place',
#          '@category': 'RESTAURANT#MISCELLANEOUS',
#          '@polarity': 'negative',
#          '@from': '5',
#          '@to': '10'}}},
#       {'@id': '1131595:1',
#        'text': 'They refuse to seat parties of 3 or more on weekends.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': '1131595:2',
#        'text': 'The hostess is rude to the point of being offensive.',
#        'Opinions': {'Opinion': {'@target': 'hostess',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '4',
#          '@to': '11'}}},
#       {'@id': '1131595:3',
#        'text': 'The food was bland oily.',
#        'Opinions': {'Opinion': {'@target': 'food',
#          '@category': 'FOOD#QUALITY',
#          '@polarity': 'negative',
#          '@from': '4',
#          '@to': '8'}}},
#       {'@id': '1131595:4',
#        'text': "I just don't understand all the hype...",
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}}]}},
#    {'@rid': '1138996',
#     'sentences': {'sentence': [{'@id': '1138996:0',
#        'text': 'We went to Ino for Valentines.'},
#       {'@id': '1138996:1',
#        'text': 'We have been to this place many times, and always have great food, wine, and service.',
#        'Opinions': {'Opinion': [{'@target': 'food',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '61',
#           '@to': '65'},
#          {'@target': 'wine',
#           '@category': 'DRINKS#QUALITY',
#           '@polarity': 'positive',
#           '@from': '67',
#           '@to': '71'},
#          {'@target': 'service',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'positive',
#           '@from': '77',
#           '@to': '84'}]}},
#       {'@id': '1138996:2',
#        'text': 'We were worried we would have trouble getting in, but somehow managed to have a short wait.',
#        'Opinions': {'Opinion': {'@target': 'wait',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'positive',
#          '@from': '86',
#          '@to': '90'}}},
#       {'@id': '1138996:3',
#        'text': 'As always we had a great glass of wine while we waited.',
#        'Opinions': {'Opinion': {'@target': 'glass of wine',
#          '@category': 'DRINKS#QUALITY',
#          '@polarity': 'positive',
#          '@from': '25',
#          '@to': '38'}}},
#       {'@id': '1138996:4',
#        'text': 'When we sat, we got great and fast service.',
#        'Opinions': {'Opinion': {'@target': 'service',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'positive',
#          '@from': '35',
#          '@to': '42'}}},
#       {'@id': '1138996:5',
#        'text': 'The people that work there are always so friendly you forget you are in New York sometimes.',
#        'Opinions': {'Opinion': {'@target': 'people',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'positive',
#          '@from': '4',
#          '@to': '10'}}},
#       {'@id': '1138996:6',
#        'text': 'Make sure you try this place as often as you can.',
#        'Opinions': {'Opinion': {'@target': 'place',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '23',
#          '@to': '28'}}}]}},
#    {'@rid': '1145510',
#     'sentences': {'sentence': [{'@id': '1145510:0',
#        'text': 'This is a fun restaurant to go to.',
#        'Opinions': {'Opinion': {'@target': 'restaurant',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '14',
# ...
#           '@category': 'FOOD#STYLE_OPTIONS',
#           '@polarity': 'positive',
#           '@from': '9',
#           '@to': '16'}]}}]}},
#    {'@rid': 'P#3',
#     'sentences': {'sentence': [{'@id': 'P#3:0',
#        'text': 'Great Atmosphere',
#        'Opinions': {'Opinion': {'@target': 'Atmosphere',
#          '@category': 'AMBIENCE#GENERAL',
#          '@polarity': 'positive',
#          '@from': '6',
#          '@to': '16'}}},
#       {'@id': 'P#3:1',
#        'text': 'Went to this place this place on a real cold night and needed a quick meal.'},
#       {'@id': 'P#3:2',
#        'text': 'I highly recommend the fish tacos, everything else was ok.',
#        'Opinions': {'Opinion': [{'@target': 'fish tacos',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '23',
#           '@to': '33'},
#          {'@target': 'NULL',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'neutral',
#           '@from': '0',
#           '@to': '0'}]}},
#       {'@id': 'P#3:3',
#        'text': 'Cool atmosphere, the fire place in the back really ads to it but needs a bit more heat throughout on a cold night.',
#        'Opinions': {'Opinion': [{'@target': 'atmosphere',
#           '@category': 'AMBIENCE#GENERAL',
#           '@polarity': 'positive',
#           '@from': '5',
#           '@to': '15'},
#          {'@target': 'fire place',
#           '@category': 'AMBIENCE#GENERAL',
#           '@polarity': 'positive',
#           '@from': '21',
#           '@to': '31'},
#          {'@target': 'NULL',
#           '@category': 'AMBIENCE#GENERAL',
#           '@polarity': 'negative',
#           '@from': '0',
#           '@to': '0'}]}}]}},
#    {'@rid': 'CLF#8',
#     'sentences': {'sentence': [{'@id': 'CLF#8:0',
#        'text': 'Poor service and management',
#        'Opinions': {'Opinion': [{'@target': 'service',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'negative',
#           '@from': '5',
#           '@to': '12'},
#          {'@target': 'management',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'negative',
#           '@from': '17',
#           '@to': '27'}]}},
#       {'@id': 'CLF#8:1',
#        'text': 'Don’t go to this place!',
#        'Opinions': {'Opinion': {'@target': 'place',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'negative',
#          '@from': '17',
#          '@to': '22'}}},
#       {'@id': 'CLF#8:2',
#        'text': 'Had an awful experience at Casa la Femme on a Saturday dinner.',
#        'Opinions': {'Opinion': {'@target': 'Casa la Femme',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'negative',
#          '@from': '27',
#          '@to': '40'}}},
#       {'@id': 'CLF#8:3',
#        'text': 'Appetizers took nearly an hour.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': 'CLF#8:4',
#        'text': 'When the main course finally arrived (another 45mins) half of our order was missing.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': 'CLF#8:5',
#        'text': 'Never got an explanation as to what was going on.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': 'CLF#8:6',
#        'text': 'The manager was rude and handled the situation extremely poorly.',
#        'Opinions': {'Opinion': {'@target': 'manager',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '4',
#          '@to': '11'}}},
#       {'@id': 'CLF#8:7',
#        'text': 'When we threatened to leave, we were offered a meager discount even though half the order was missing.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': 'CLF#8:8',
#        'text': 'On the way out, we heard of other guests complaining about similar issues.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': 'CLF#8:9',
#        'text': 'Can’t believe how an expensive NYC restaurant can be so disrespectful to its clients.',
#        'Opinions': {'Opinion': [{'@target': 'restaurant',
#           '@category': 'RESTAURANT#PRICES',
#           '@polarity': 'negative',
#           '@from': '35',
#           '@to': '45'},
#          {'@target': 'NULL',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'negative',
#           '@from': '0',
#           '@to': '0'}]}}]}},
#    {'@rid': 'ADLT#11',
#     'sentences': {'sentence': [{'@id': 'ADLT#11:0',
#        'text': 'What a hassle!',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': 'ADLT#11:1',
#        'text': 'The food is very good, but not outstanding.',
#        'Opinions': {'Opinion': {'@target': 'food',
#          '@category': 'FOOD#QUALITY',
#          '@polarity': 'neutral',
#          '@from': '4',
#          '@to': '8'}}},
#       {'@id': 'ADLT#11:2',
#        'text': 'There is no way it justifies the accolades it receives, the attitude of the staff or the wait for a table.',
#        'Opinions': {'Opinion': [{'@target': 'staff',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'negative',
#           '@from': '76',
#           '@to': '81'},
#          {'@target': 'NULL',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '0',
#           '@to': '0'},
#          {'@target': 'wait',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'negative',
#           '@from': '89',
#           '@to': '93'}]}},
#       {'@id': 'ADLT#11:3',
#        'text': 'On our last visit, they skipped over our name on the list, leaving us waiting an extra hour for a table.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': 'ADLT#11:4',
#        'text': 'Mistakes happen, but they are usually accompanied by an apology, perhaps even a glass of wine...but not the grunt that we received from the Al Di La staff.',
#        'Opinions': {'Opinion': {'@target': 'staff',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '149',
#          '@to': '154'}}},
#       {'@id': 'ADLT#11:5',
#        '@OutOfScope': 'TRUE',
#        'text': "Without the wait or attitude, I would probably go back, but there are just too many other restaurants in Brooklyn that are as good or better and don't make me jump through hoops."}]}},
#    {'@rid': 'WE#1',
#     'sentences': {'sentence': [{'@id': 'WE#1:0',
#        'text': 'Expensive',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#PRICES',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': 'WE#1:1',
#        'text': 'I went there after hearing how great it was.'},
#       {'@id': 'WE#1:2', 'text': 'Wow.'},
#       {'@id': 'WE#1:3',
#        'text': 'The bread was stale, the salad was overpriced and empty.',
#        'Opinions': {'Opinion': [{'@target': 'bread',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '4',
#           '@to': '9'},
#          {'@target': 'salad',
#           '@category': 'FOOD#PRICES',
#           '@polarity': 'negative',
#           '@from': '25',
#           '@to': '30'},
#          {'@target': 'salad',
#           '@category': 'FOOD#STYLE_OPTIONS',
#           '@polarity': 'negative',
#           '@from': '25',
#           '@to': '30'}]}},
#       {'@id': 'WE#1:4',
#        'text': "The pasta was well cooked, didn't have enough sauce though or flavor.",
#        'Opinions': {'Opinion': [{'@target': 'pasta',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'positive',
#           '@from': '4',
#           '@to': '9'},
#          {'@target': 'pasta',
#           '@category': 'FOOD#QUALITY',
#           '@polarity': 'negative',
#           '@from': '4',
#           '@to': '9'},
#          {'@target': 'pasta',
#           '@category': 'FOOD#STYLE_OPTIONS',
#           '@polarity': 'negative',
#           '@from': '4',
#           '@to': '9'}]}},
#       {'@id': 'WE#1:5',
#        '@OutOfScope': 'TRUE',
#        'text': 'I though it was expensive and I prefer Bella Via just blocks away by far.'}]}},
#    {'@rid': 'FF#6',
#     'sentences': {'sentence': [{'@id': 'FF#6:0',
#        'text': 'So rude!!!',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': 'FF#6:1', 'text': 'I went with JWILS.'},
#       {'@id': 'FF#6:2', 'text': 'Her review is above.'},
#       {'@id': 'FF#6:3',
#        'text': 'I was one of the people that went for this horrible experience.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': 'FF#6:4',
#        'text': 'My friend is 100% right in the experience we had.'},
#       {'@id': 'FF#6:5',
#        'text': 'The hostess was rude and I got a distinct feeling that they did not want to serve us.',
#        'Opinions': {'Opinion': [{'@target': 'hostess',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'negative',
#           '@from': '4',
#           '@to': '11'},
#          {'@target': 'NULL',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'negative',
#           '@from': '0',
#           '@to': '0'}]}},
#       {'@id': 'FF#6:6',
#        'text': 'The only thing that my friend left out is that when we sat down at the bar the bartender disappeared.',
#        'Opinions': {'Opinion': {'@target': 'bartender',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '79',
#          '@to': '88'}}},
#       {'@id': 'FF#6:7',
#        'text': 'I asked for a menu and the same waitress looked at my like I was insane.',
#        'Opinions': {'Opinion': {'@target': 'waitress',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '32',
#          '@to': '40'}}},
#       {'@id': 'FF#6:8',
#        'text': 'I was shocked that my friends wanted to stay after the waitress said, "can I help you" and "how many are in your party."',
#        'Opinions': {'Opinion': {'@target': 'waitress',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '55',
#          '@to': '63'}}},
#       {'@id': 'FF#6:9', 'text': 'What?'},
#       {'@id': 'FF#6:10',
#        'text': 'The three of us standing in front of her should have been an indication of how many of us there were.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': 'FF#6:11',
#        'text': "We didn't look like the other patrons in there so unfortunately I think that may have been part of the problem.",
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'RESTAURANT#MISCELLANEOUS',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': 'FF#6:12',
#        'text': 'Shame on this place for the horrible rude staff and non-existent customer service.',
#        'Opinions': {'Opinion': [{'@target': 'staff',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'negative',
#           '@from': '42',
#           '@to': '47'},
#          {'@target': 'customer service',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'negative',
#           '@from': '65',
#           '@to': '81'}]}}]}},
#    {'@rid': 'FF#10',
#     'sentences': {'sentence': [{'@id': 'FF#10:0',
#        'text': 'bad staff',
#        'Opinions': {'Opinion': {'@target': 'staff',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '4',
#          '@to': '9'}}},
#       {'@id': 'FF#10:1',
#        'text': 'I generally like this place.',
#        'Opinions': {'Opinion': {'@target': 'place',
#          '@category': 'RESTAURANT#GENERAL',
#          '@polarity': 'positive',
#          '@from': '22',
#          '@to': '27'}}},
#       {'@id': 'FF#10:2',
#        'text': 'The food is good.',
#        'Opinions': {'Opinion': {'@target': 'food',
#          '@category': 'FOOD#QUALITY',
#          '@polarity': 'positive',
#          '@from': '4',
#          '@to': '8'}}},
#       {'@id': 'FF#10:3',
#        'text': 'The design of the space is good.',
#        'Opinions': {'Opinion': {'@target': 'space',
#          '@category': 'AMBIENCE#GENERAL',
#          '@polarity': 'positive',
#          '@from': '18',
#          '@to': '23'}}},
#       {'@id': 'FF#10:4',
#        'text': 'But the service is HORRID!',
#        'Opinions': {'Opinion': {'@target': 'service',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '8',
#          '@to': '15'}}},
#       {'@id': 'FF#10:5',
#        'text': 'I was there for brunch recently, and we were tag teamed by a waitress and a waiter.',
#        'Opinions': {'Opinion': [{'@target': 'waitress',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'negative',
#           '@from': '61',
#           '@to': '69'},
#          {'@target': 'waiter',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'negative',
#           '@from': '76',
#           '@to': '82'}]}},
#       {'@id': 'FF#10:6',
#        'text': 'The waiter delivered our food while holding what appeared to be a plastic bag of garbage in one hand.',
#        'Opinions': {'Opinion': {'@target': 'waiter',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '4',
#          '@to': '10'}}},
#       {'@id': 'FF#10:7',
#        'text': "I can't believe that it was, but please put the bag down before delivering food!",
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': 'FF#10:8',
#        'text': 'The waitress came to check in on us every few minutes, and began to clear the plates while half of us were still eating (a big pet peeve of mine that happens almost everywhere, so I try to ignore it).',
#        'Opinions': {'Opinion': {'@target': 'waitress',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '4',
#          '@to': '12'}}},
#       {'@id': 'FF#10:9',
#        'text': "I couldn't ignore the fact that she reach over the plate of one of my friends, who was in mid bite, to clear the table.",
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': 'FF#10:10',
#        'text': 'She then put the check down without asking if we were done, and came to check on the bill every two minutes, even though we were one of three occupied tables.',
#        'Opinions': {'Opinion': {'@target': 'NULL',
#          '@category': 'SERVICE#GENERAL',
#          '@polarity': 'negative',
#          '@from': '0',
#          '@to': '0'}}},
#       {'@id': 'FF#10:11',
#        'text': 'I wish I could like this place more, and I wish someone would retrain the staff.',
#        'Opinions': {'Opinion': [{'@target': 'place',
#           '@category': 'RESTAURANT#GENERAL',
#           '@polarity': 'negative',
#           '@from': '25',
#           '@to': '30'},
#          {'@target': 'staff',
#           '@category': 'SERVICE#GENERAL',
#           '@polarity': 'negative',
#           '@from': '74',
#           '@to': '79'}]}}]}}]}}

# %%
# Convert dictionary to xml
ner_dict = xml_dict_transformation(xml_dict)
example = ner_dict[0]
xml = convert_ner_to_xml(example)
xml
# Out:
# 'Judging from previous posts this used to be a good <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">place</aspect-term>, but not any longer.'

# %%
# Test new TASD tagged xml file
list_sent = []
for review in ner_dict:
    tasd_sent = convert_ner_to_xml(review)
    # check if implicit review - implicit review do not have any tags
    if '<' and '>' not in tasd_sent:
        continue
    else:
        list_sent.append(tasd_sent)

print(len(list_sent))
# Out:
# 1232

# %%
def sentence_xml_tagging(tasd_sentence: str) -> str:
    sentence_tag_start = '<sentence>'
    sentence_tag_end = '</sentence>'
    concat = sentence_tag_start + tasd_sentence + sentence_tag_end
    return concat

# %%
# tag filtered TASD sentences
final_list = []
for sent in list_sent:
    tagged = sentence_xml_tagging(sent)
    final_list.append(tagged)

xml_file_tasd = ''.join(final_list)

# %%
# add root
xml_file_tasd = '<Reviews>' + xml_file_tasd + '</Reviews>'

# %%
# to test file
import xml.etree.ElementTree as ET
tree = ET.ElementTree(ET.fromstring(xml_file_tasd))

# %%
tree.write('rest16_TASD.xml')

# %%
import json


with open("rest16.json", "w") as outf:
    json.dump(ner_dict, outf)
