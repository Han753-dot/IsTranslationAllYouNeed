# %%
from ollama import chat
from ollama import ChatResponse
import xml.etree.ElementTree as ET
import re

# %%
# Iterate

import xml.etree.ElementTree as ET

# Read XML file as a string
with open('..\\data\\tasd_data\\rest15_tasd.xml', 'r') as file:
    xml_string = file.read()

matches = re.findall(r'<sentence>(.*?)</sentence>', xml_string, re.DOTALL)

# Iterate through the matches and print each sentence
for idx, match in enumerate(matches, start=1):
    print(f"Sentence {idx}: {match}")
# Out:
# Sentence 1: Judging from previous posts this used to be a good <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">place</aspect-term>, but not any longer.
# Sentence 2: We, there were four of us, arrived at noon - the place was empty - and the <aspect-term aspect="SERVICE" polarity="negative">staff</aspect-term> acted like we were imposing on them and they were very rude.
# Sentence 3: The <aspect-term aspect="FOOD" polarity="negative">food</aspect-term> was lousy - too sweet or too salty and the <aspect-term aspect="FOOD" polarity="negative">portions</aspect-term> tiny.
# Sentence 4: Avoid this <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">place</aspect-term>!
# Sentence 5: I have eaten at Saul, many times, the <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> is always consistently, outrageously good.
# Sentence 6: <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Saul</aspect-term> is the best restaurant on Smith Street and in Brooklyn.
# Sentence 7: The <aspect-term aspect="FOOD" polarity="positive">duck confit</aspect-term> is always amazing and the <aspect-term aspect="FOOD" polarity="positive">foie gras terrine with figs</aspect-term> was out of this world.
# Sentence 8: The <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">wine list</aspect-term></aspect-term> is interesting and has many good values.
# Sentence 9: I was very disappointed with this <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">restaurant</aspect-term>.
# Sentence 10: Ive asked a <aspect-term aspect="SERVICE" polarity="negative">cart attendant</aspect-term> for a lotus leaf wrapped rice and she replied back rice and just walked away.
# Sentence 11: <aspect-term aspect="FOOD" polarity="neutral">Food</aspect-term> was okay, nothing great.
# Sentence 12: <aspect-term aspect="FOOD" polarity="negative">Chow fun</aspect-term> was dry; <aspect-term aspect="FOOD" polarity="negative">pork shu mai</aspect-term> was more than usually greasy and had to share a table with loud and rude family.
# Sentence 13: I/we will never go back to this <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">place</aspect-term> again.
# Sentence 14: Went on a 3 day oyster binge, with <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Fish</aspect-term> bringing up the closing, and I am so glad this was the place it O trip ended, because it was so great!
# Sentence 15: <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term> was devine, <aspect-term aspect="FOOD" polarity="positive">oysters</aspect-term> where a sensual as they come, and the price can't be beat!!!
# Sentence 16: Every time in New York I make it a point to visit <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Restaurant Saul</aspect-term> on Smith Street.
# Sentence 17: Everything is always cooked to perfection, the <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> is excellent, the <aspect-term aspect="AMBIENCE" polarity="positive">decor</aspect-term> cool and understated.
# Sentence 18: I had the <aspect-term aspect="FOOD" polarity="positive">duck breast special</aspect-term> on my last visit and it was incredible.
# Sentence 19: The <aspect-term aspect="FOOD" polarity="negative">food</aspect-term> is very average...the <aspect-term aspect="FOOD" polarity="negative">Thai fusion stuff</aspect-term> is a bit too sweet, every thing they serve is too sweet here.
# Sentence 20: The only thing I moderately enjoyed was their <aspect-term aspect="FOOD" polarity="positive">Grilled Chicken special with Edamame Puree</aspect-term>.
# Sentence 21: I had never had <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Edamame pureed</aspect-term></aspect-term> before but I thought it was innovative and tasty (could've used a bit more salt).
# Sentence 22: The <aspect-term aspect="AMBIENCE" polarity="positive">decor</aspect-term> is night tho...but they REALLY need to clean that <aspect-term aspect="AMBIENCE" polarity="negative">vent</aspect-term> in the ceiling...its quite un-appetizing, and kills your effort to make this <aspect-term aspect="AMBIENCE" polarity="negative">place</aspect-term> look sleek and modern.
# Sentence 23: Their <aspect-term aspect="FOOD" polarity="positive">sake list</aspect-term> was extensive, but we were looking for Purple Haze, which wasn't listed but made for us upon request!
# Sentence 24: The <aspect-term aspect="FOOD" polarity="positive">spicy tuna roll</aspect-term> was unusually good and the <aspect-term aspect="FOOD" polarity="positive">rock shrimp tempura</aspect-term> was awesome, great appetizer to share!
# Sentence 25: We went around 9:30 on a Friday and it had died down a bit by then so the <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> was great!
# Sentence 26: we love th <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">pink pony</aspect-term>.
# Sentence 27: THe perfect <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">spot</aspect-term>.
# Sentence 28: <aspect-term aspect="FOOD" polarity="positive">Food</aspect-term>-awesome.
# Sentence 29: <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term>- friendly and attentive.
# Sentence 30: <aspect-term aspect="AMBIENCE" polarity="positive">Ambiance</aspect-term>- relaxed and stylish.
# Sentence 31: Don't judge this <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term> prima facie, you have to try it to believe it, a home away from home for the literate heart.
# Sentence 32: the <aspect-term aspect="FOOD" polarity="neutral">food</aspect-term> is decent.
# Sentence 33: however, it's the <aspect-term aspect="SERVICE" polarity="negative">service</aspect-term> that leaves a bad taste in my mouth.
# Sentence 34: i happen to have a policy that goes along with a little bit of self-respect, which includes not letting a <aspect-term aspect="SERVICE" polarity="negative">waiter</aspect-term> intimidate me, i.e. make me feel bad asking for trivialities like water, or the check.
# Sentence 35: This <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term> has got to be the best japanese restaurant in the new york area.
# Sentence 36: <aspect-term aspect="FOOD" polarity="positive">Food</aspect-term> is great.
# Sentence 37: <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term> is top notch.
# Sentence 38: I tend to judge a sushi restaurant by its <aspect-term aspect="FOOD" polarity="positive">sea urchin</aspect-term>, which was heavenly at sushi rose.
# Sentence 39: The <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">sushi</aspect-term></aspect-term> seemed pretty fresh and was adequately proportioned.
# Sentence 40: The <aspect-term aspect="FOOD" polarity="positive">rice to fish ration</aspect-term> was also good--they didn't try to overpack the rice.
# Sentence 41: We took advanatage of the <aspect-term aspect="FOOD" polarity="positive">half price sushi deal</aspect-term> on saturday so it was well worth it.
# Sentence 42: In the evening, this place attracted a well dressed, with it, NY <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">crowd</aspect-term>.
# Sentence 43: The <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> was well prepared and the <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> impecable.
# Sentence 44: The <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Prix Fixe menu</aspect-term></aspect-term></aspect-term> is worth every penny and you get more than enough (both in quantity AND quality).
# Sentence 45: $6 and there is much tasty <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">food</aspect-term></aspect-term></aspect-term>, all of it fresh and continually refilled.
# Sentence 46: I am not a vegetarian but, almost all the <aspect-term aspect="FOOD" polarity="positive">dishes</aspect-term> were great.
# Sentence 47: The <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> here is rather good, but only if you like to wait for it.
# Sentence 48: I like the <aspect-term aspect="FOOD" polarity="positive">somosas</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">chai</aspect-term>, and the <aspect-term aspect="FOOD" polarity="positive">chole</aspect-term>, but the <aspect-term aspect="FOOD" polarity="negative">dhosas</aspect-term> and <aspect-term aspect="FOOD" polarity="negative">dhal</aspect-term> were kinda dissapointing.
# Sentence 49: The <aspect-term aspect="SERVICE" polarity="negative">service</aspect-term> varys from day to day- sometimes they're very nice, and sometimes not.
# Sentence 50: The <aspect-term aspect="SERVICE" polarity="negative">kitchen</aspect-term> however, is almost always slow.
# Sentence 51: Also, specify if you like your <aspect-term aspect="FOOD" polarity="negative">food</aspect-term> spicy- its rather bland if you don't.
# Sentence 52: The <aspect-term aspect="AMBIENCE" polarity="positive">ambience</aspect-term> is pretty and nice for conversation, so a casual lunch here would probably be best.
# Sentence 53: If you've ever been along the river in Weehawken you have an idea of the top of <aspect-term aspect="AMBIENCE" polarity="positive">view</aspect-term> the chart house has to offer.
# Sentence 54: Add to that great <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> and great <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">food</aspect-term></aspect-term> at a reasonable price and you have yourself the beginning of a great evening.
# Sentence 55: The <aspect-term aspect="FOOD" polarity="positive">lava cake dessert</aspect-term> was incredible and I recommend it.
# Sentence 56: Once you step into <aspect-term aspect="AMBIENCE" polarity="positive">Cosette</aspect-term>, you're miraculously in a small, off-the-beaten path Parisian bistro.
# Sentence 57: This tiny <aspect-term aspect="AMBIENCE" polarity="positive">restaurant</aspect-term> is as cozy as it gets, with that certain Parisian flair.
# Sentence 58: The <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> was average to above-average; the <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="negative">French Onion soup</aspect-term></aspect-term> filling yet not overly impressive, and the <aspect-term aspect="FOOD" polarity="negative">desserts</aspect-term> not brilliant in any way.
# Sentence 59: However, go for the <aspect-term aspect="AMBIENCE" polarity="positive">ambience</aspect-term>, and consider the <aspect-term aspect="FOOD" polarity="neutral">food</aspect-term> just a companion for a trip across the world!
# Sentence 60: The <aspect-term aspect="FOOD" polarity="negative">pizza</aspect-term> was delivered cold and the <aspect-term aspect="FOOD" polarity="negative">cheese</aspect-term> wasn't even fully melted!
# Sentence 61: The <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative">pizza</aspect-term></aspect-term> is overpriced and soggy.
# Sentence 62: Yes, they use fancy <aspect-term aspect="FOOD" polarity="positive">ingredients</aspect-term>, but even fancy ingredients don't make for good <aspect-term aspect="FOOD" polarity="negative">pizza</aspect-term> unless someone knows how to get the <aspect-term aspect="FOOD" polarity="negative">crust</aspect-term> right.
# Sentence 63: I think I've had some the best <aspect-term aspect="FOOD" polarity="positive">meals</aspect-term> of my life at minnow.
# Sentence 64: The <aspect-term aspect="FOOD" polarity="positive">seafood</aspect-term> is amazing, there's a good <aspect-term aspect="FOOD" polarity="positive">wine list</aspect-term>, and the ever-changing <aspect-term aspect="FOOD" polarity="positive">menu</aspect-term> always offers some great surprises.
# Sentence 65: The combination of super-fresh <aspect-term aspect="FOOD" polarity="positive">ingredients</aspect-term> in the dishes are unusual but really delicious.
# Sentence 66: Best <aspect-term aspect="FOOD" polarity="positive">Pastrami</aspect-term> I ever had and great <aspect-term aspect="FOOD" polarity="positive">portion</aspect-term> without being ridiculous.
# Sentence 67: My wife had the <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">fried shrimp</aspect-term></aspect-term> which are huge and loved it.
# Sentence 68: As a Japanese native, I've lived in the Tristate area for over 8 years, but I was just so amazed at this <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term>.
# Sentence 69: This <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term> is the most Japanese it can ever get.
# Sentence 70: The <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">signs</aspect-term>, the <aspect-term aspect="FOOD" polarity="positive">specials menus</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">food</aspect-term>, and even all the <aspect-term aspect="SERVICE" polarity="positive">waitstaff</aspect-term> are ALL TOTALLY Japanese.
# Sentence 71: This <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term> is worth an one-hour drive.
# Sentence 72: <aspect-term aspect="AMBIENCE" polarity="positive"><aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Leon</aspect-term></aspect-term> is an East Village gem: casual but hip, with well prepared basic <aspect-term aspect="FOOD" polarity="positive">French bistro fare</aspect-term>, good <aspect-term aspect="FOOD" polarity="positive">specials</aspect-term>, a warm and lively <aspect-term aspect="AMBIENCE" polarity="positive">atmosphere</aspect-term>.
# Sentence 73: My wife and I always enjoy the young, not always well trained but nevertheless friendly, <aspect-term aspect="SERVICE" polarity="positive">staff</aspect-term>, all of whom have a story.
# Sentence 74: Decent <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="neutral">wine</aspect-term></aspect-term> at reasonable prices.
# Sentence 75: Everytime I decide to try another place on the UES, I get angry that I didn't just go to <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Zucchero Pomodori</aspect-term>.
# Sentence 76: This is by far my favorite <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term> in the neighborhood.
# Sentence 77: The <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> is excellent, the <aspect-term aspect="AMBIENCE" polarity="positive">decor</aspect-term> is great, and the <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> is delicious and comes in large <aspect-term aspect="FOOD" polarity="positive">portions</aspect-term>.
# Sentence 78: I'm partial to the <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Gnocchi</aspect-term>.
# Sentence 79: This <aspect-term aspect="AMBIENCE" polarity="negative">place</aspect-term> is incredibly tiny.
# Sentence 80: The <aspect-term aspect="SERVICE" polarity="negative">hostess</aspect-term> is rude to the point of being offensive.
# Sentence 81: The <aspect-term aspect="FOOD" polarity="negative">food</aspect-term> was bland oily.
# Sentence 82: We have been to this place many times, and always have great <aspect-term aspect="FOOD" polarity="positive">food</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">wine</aspect-term>, and <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term>.
# Sentence 83: We were worried we would have trouble getting in, but somehow managed to have a short <aspect-term aspect="SERVICE" polarity="positive">wait</aspect-term>.
# Sentence 84: As always we had a great <aspect-term aspect="FOOD" polarity="positive">glass of wine</aspect-term> while we waited.
# Sentence 85: When we sat, we got great and fast <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term>.
# Sentence 86: The <aspect-term aspect="SERVICE" polarity="positive">people</aspect-term> that work there are always so friendly you forget you are in New York sometimes.
# Sentence 87: Make sure you try this <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term> as often as you can.
# Sentence 88: This is a fun <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">restaurant</aspect-term> to go to.
# Sentence 89: The <aspect-term aspect="FOOD" polarity="positive">pizza</aspect-term> is yummy and I like the <aspect-term aspect="AMBIENCE" polarity="positive">atmoshpere</aspect-term>.
# Sentence 90: But the <aspect-term aspect="FOOD" polarity="negative">pizza</aspect-term> is way to expensive.
# Sentence 91: I went there for <aspect-term aspect="FOOD" polarity="negative">lunch</aspect-term> and it was not as good as I expected from the reviews I read.
# Sentence 92: <aspect-term aspect="FOOD" polarity="negative">Sauce</aspect-term> was watery and the <aspect-term aspect="FOOD" polarity="negative">food</aspect-term> didn't have much flavor.
# Sentence 93: This <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term> is great.
# Sentence 94: The <aspect-term aspect="SERVICE" polarity="positive">waitress</aspect-term> was very patient with us and the <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> is phenomenal!
# Sentence 95: <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term> was prompt, friendly and great.
# Sentence 96: Great <aspect-term aspect="FOOD" polarity="positive">pizza</aspect-term> and fantastic <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term>.
# Sentence 97: There was a small <aspect-term aspect="SERVICE" polarity="positive">wait</aspect-term>, but shorter than I expected.
# Sentence 98: This is the best <aspect-term aspect="FOOD" polarity="positive">sushi</aspect-term> in new york city - hands down.
# Sentence 99: The <aspect-term aspect="AMBIENCE" polarity="negative">place</aspect-term> is small and cramped but the <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> is fantastic.
# Sentence 100: Get the <aspect-term aspect="FOOD" polarity="positive">tuna of gari</aspect-term>.
# Sentence 101: <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Planet Thailand</aspect-term> has always been a hit with me , I go there usually for the <aspect-term aspect="FOOD" polarity="positive">sushi</aspect-term>, which is great , the <aspect-term aspect="FOOD" polarity="positive">thai food</aspect-term> is excellent too .
# Sentence 102: With the great variety on the <aspect-term aspect="FOOD" polarity="positive">menu</aspect-term> , I eat here often and never get bored .
# Sentence 103: The <aspect-term aspect="AMBIENCE" polarity="negative">atmosphere</aspect-term> isn't the greatest , but I suppose that's how they keep the prices down .
# Sentence 104: It's all about the <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> !!
# Sentence 105: first it took us a long time to find the <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">place</aspect-term>.
# Sentence 106: but when we looked at the <aspect-term aspect="FOOD" polarity="negative">menu</aspect-term>, there weren't a lot of choices, most of them were dumplings in the appetizer section.
# Sentence 107: those <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="neutral">rolls</aspect-term></aspect-term> were big, but not good and <aspect-term aspect="FOOD" polarity="negative">sashimi</aspect-term> wasn't fresh.
# Sentence 108: Try the <aspect-term aspect="FOOD" polarity="positive">crunchy tuna</aspect-term>, it is to die for.
# Sentence 109: First went here to enjoy their <aspect-term aspect="AMBIENCE" polarity="positive">garden terrace</aspect-term>.
# Sentence 110: The <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> was amazing, and the <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> was prompt and helpful, but not over-bearing or rushed.
# Sentence 111: The <aspect-term aspect="FOOD" polarity="positive">Steak Tartare</aspect-term> is a great bet, they fix it for you at the table.
# Sentence 112: Admittedly some nights inside the <aspect-term aspect="AMBIENCE" polarity="negative">restaurant</aspect-term> were rather warm, but the <aspect-term aspect="AMBIENCE" polarity="positive">open kitchen</aspect-term> is part of the charm.
# Sentence 113: Great <aspect-term aspect="FOOD" polarity="positive">wine selection</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">Gigondas</aspect-term> is worth the price, and the <aspect-term aspect="FOOD" polarity="positive">house champagne</aspect-term> is a great value.
# Sentence 114: It may be a bit packed on weekends, but the <aspect-term aspect="AMBIENCE" polarity="positive">vibe</aspect-term> is good and it is the best <aspect-term aspect="FOOD" polarity="positive">French food</aspect-term> you will find in the area.
# Sentence 115: Have recommended the <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term> to friends, always gets good response.
# Sentence 116: Pizza - the only <aspect-term aspect="FOOD" polarity="positive">pizza</aspect-term> in NYC that should not have additional toppings - the <aspect-term aspect="FOOD" polarity="positive">crust</aspect-term> tastes like the best, freshly baked bread!
# Sentence 117: I take all my NYC guests to <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">VT's</aspect-term>.
# Sentence 118: Not sure where the previous reviewer, lonk, dined, but Saul is in a great <aspect-term aspect="AMBIENCE" polarity="positive">neighborhood</aspect-term> and has great <aspect-term aspect="FOOD" polarity="positive">food</aspect-term>!
# Sentence 119: I'd highly recommend it for a special occasion -- it provides and intimate <aspect-term aspect="AMBIENCE" polarity="positive">setting</aspect-term> and nice <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term>.
# Sentence 120: I'm not sure where the other reviewers ate but it seems as if we visited two different restaurants because my friends and I all enjoy <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Mizu</aspect-term> very much... and we're repeat customers.
# Sentence 121: Make sure you have the <aspect-term aspect="FOOD" polarity="positive">Spicy Scallop roll</aspect-term>.. .
# Sentence 122: <aspect-term aspect="FOOD" polarity="positive">Moules</aspect-term> were excellent, <aspect-term aspect="FOOD" polarity="negative">lobster ravioli</aspect-term> was VERY salty!
# Sentence 123: Took my mom for Mother's Day, and the <aspect-term aspect="SERVICE" polarity="negative">maitre d'</aspect-term> was pretty rude.
# Sentence 124: Tiny <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative">dessert</aspect-term></aspect-term></aspect-term> was $8.00...just plain overpriced for what it is.
# Sentence 125: The <aspect-term aspect="FOOD" polarity="positive">drinks</aspect-term> are always welll made and <aspect-term aspect="FOOD" polarity="positive">wine selection</aspect-term> is fairly priced.
# Sentence 126: Try their <aspect-term aspect="FOOD" polarity="positive">chef's specials</aspect-term>-- they are to die for.
# Sentence 127: <aspect-term aspect="SERVICE" polarity="neutral">Service</aspect-term> is not exactly five star, but thats not really a big deal.
# Sentence 128: <aspect-term aspect="AMBIENCE" polarity="positive">Downstairs lounge</aspect-term> is always a good attraction
# Sentence 129: <aspect-term aspect="AMBIENCE" polarity="positive">Raga's</aspect-term> is a romantic, cozy restaurant.
# Sentence 130: The <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">exotic food</aspect-term></aspect-term> is beautifully presented and is a delight in delicious combinations.
# Sentence 131: The <aspect-term aspect="SERVICE" polarity="positive">staff</aspect-term> is incredibly helpful and attentive.
# Sentence 132: The <aspect-term aspect="FOOD" polarity="positive">bar</aspect-term> is very well stocked with interesting <aspect-term aspect="FOOD" polarity="positive">beers</aspect-term> and well priced <aspect-term aspect="FOOD" polarity="positive">wines</aspect-term>.
# Sentence 133: When we stumbled on <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">Leon</aspect-term>, we thought that we had found quite the gem BUT, we were certainly wrong.
# Sentence 134: The <aspect-term aspect="SERVICE" polarity="negative">waitress</aspect-term> moved our table practically into the bathroom and when we asked to cancel our dinner orders because we did not want to eat sitting on the toilet, we were told no...
# Sentence 135: Rude <aspect-term aspect="SERVICE" polarity="negative">service</aspect-term>, medicore <aspect-term aspect="FOOD" polarity="neutral">food</aspect-term>...there are tons of restaurants in NY...stay away from this one
# Sentence 136: I had a grat time at <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Jekyll and Hyde</aspect-term>!
# Sentence 137: I loved everythig about it-especially the <aspect-term aspect="AMBIENCE" polarity="positive">shows</aspect-term> and <aspect-term aspect="AMBIENCE" polarity="positive">actors</aspect-term>.
# Sentence 138: Our <aspect-term aspect="SERVICE" polarity="positive">server</aspect-term> was very helpful and friendly.
# Sentence 139: The <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> was good too.
# Sentence 140: The <aspect-term aspect="FOOD" polarity="positive">tuna</aspect-term> and <aspect-term aspect="FOOD" polarity="positive">wasabe potatoes</aspect-term> are excellent.
# Sentence 141: The <aspect-term aspect="AMBIENCE" polarity="positive">outdoor atmosphere</aspect-term> of sitting on the sidewalk watching the world go by 50 feet away on 6th avenue on a cool evening was wonderful.
# Sentence 142: <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term> was prompt and courteous.
# Sentence 143: Great <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term>, great <aspect-term aspect="FOOD" polarity="positive">food</aspect-term>.
# Sentence 144: The <aspect-term aspect="FOOD" polarity="positive">pizza</aspect-term> is delicious - they use <aspect-term aspect="FOOD" polarity="positive">fresh mozzarella</aspect-term> instead of the cheap, frozen, shredded cheese common to most pizzaria's.
# Sentence 145: Two complaints- their <aspect-term aspect="FOOD" polarity="negative">appetizer selection</aspect-term> stinks, it would be nice to get some mozzarella sticks on the menu.
# Sentence 146: <aspect-term aspect="SERVICE" polarity="negative">Wait staff</aspect-term> is blantently unappreciative of your business but its the best <aspect-term aspect="FOOD" polarity="positive">pie</aspect-term> on the UWS!
# Sentence 147: By far the best <aspect-term aspect="FOOD" polarity="positive">salad</aspect-term> I have had in a fast food restaurant.
# Sentence 148: fine <aspect-term aspect="FOOD" polarity="positive">dining</aspect-term> restaurant quality.
# Sentence 149: On a recent Sunday afternoon, a friend and I accidently found this great <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">restaurant</aspect-term> on our way to see the pulitzer prize winning play DOUBT.
# Sentence 150: The <aspect-term aspect="FOOD" polarity="positive">chicken pot pie</aspect-term> is excpetiona, the <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">cheeseburger</aspect-term></aspect-term> huge and delictable, and the <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> professional wan warm.
# Sentence 151: The <aspect-term aspect="SERVICE" polarity="positive">staff</aspect-term> is no nonsense.
# Sentence 152: The <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> options rule.
# Sentence 153: When I lived upstate for a while I would buy freeze the <aspect-term aspect="FOOD" polarity="positive">bagels</aspect-term> and they would still be better than any else.
# Sentence 154: Worth visiting the <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">1st Ave spot</aspect-term> because it is the original store.
# Sentence 155: He served me an <aspect-term aspect="FOOD" polarity="positive">Uni Hand roll</aspect-term>, which I never had before, and let me tell you...IT WAS HEAVEN!
# Sentence 156: The <aspect-term aspect="FOOD" polarity="positive">sake menu</aspect-term> should not be overlooked!
# Sentence 157: Try the <aspect-term aspect="FOOD" polarity="positive">lobster teriyaki</aspect-term> and the <aspect-term aspect="FOOD" polarity="positive">rose special roll</aspect-term>.
# Sentence 158: <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term> was very good - prompt, attentive and non-intrusive.
# Sentence 159: <aspect-term aspect="FOOD" polarity="positive">Food</aspect-term> was very good as well, considering that we tried the budget selection (though I wish the <aspect-term aspect="FOOD" polarity="negative">pork belly</aspect-term> that I ordered was roasted a bit longer, so that fat was more of a melt-in-your-mouth experience).
# Sentence 160: <aspect-term aspect="FOOD" polarity="positive">Wine list selection</aspect-term> is good and <aspect-term aspect="FOOD" polarity="positive">wine-by-the-glass</aspect-term> was generously filled to the top.
# Sentence 161: <aspect-term aspect="AMBIENCE" polarity="positive">Traditional French decour</aspect-term> was pleasant though the <aspect-term aspect="AMBIENCE" polarity="negative">hall</aspect-term> was rather noisy - the restaurant was full and we had to raise our voices to be able to maintain a conversation.
# Sentence 162: I've been to at <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Cafe Spice</aspect-term> probably 5-8 times, it is probably still the best Indian restaurant around Union Square.
# Sentence 163: To sum it up: <aspect-term aspect="SERVICE" polarity="neutral">Service</aspect-term> varies from good to mediorce, depending on which waiter you get; generally it is just average Ok.
# Sentence 164: <aspect-term aspect="SERVICE" polarity="positive">Seating</aspect-term> is always prompt, though the restaurant does fill up in the evening.
# Sentence 165: <aspect-term aspect="FOOD" polarity="positive">Food</aspect-term> is usually very good, though ocasionally I wondered about freshmess of <aspect-term aspect="FOOD" polarity="negative">raw vegatables in side orders</aspect-term>.
# Sentence 166: The <aspect-term aspect="AMBIENCE" polarity="positive">decor</aspect-term> is vibrant and eye-pleasing with several <aspect-term aspect="AMBIENCE" polarity="positive">semi-private boths</aspect-term> on the right side of the dining hall, which are great for a date.
# Sentence 167: I have NEVER been disappointed in the <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Red Eye</aspect-term>.
# Sentence 168: The first time I went, and was completely taken by the <aspect-term aspect="AMBIENCE" polarity="positive">live jazz band</aspect-term> and <aspect-term aspect="AMBIENCE" polarity="positive">atmosphere</aspect-term>, I ordered the Lobster Cobb Salad.
# Sentence 169: It's simply the best <aspect-term aspect="FOOD" polarity="positive">meal</aspect-term> in NYC.
# Sentence 170: You cannot go wrong at the <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Red Eye Grill</aspect-term>.
# Sentence 171: If we were to move from the upper east side, we would genuinely miss this <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">restaurant</aspect-term>.
# Sentence 172: The <aspect-term aspect="GENERAL-IMPRESSION" polarity="neutral">restaurant</aspect-term> is cute but not upscale.
# Sentence 173: The <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> is a diamond in rough -- the food is delicious and homemade with the perfect <aspect-term aspect="FOOD" polarity="positive">balance of herbs and tomatoes</aspect-term>.
# Sentence 174: We had a great time at the <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Jekyll and hyde Pub</aspect-term> last night.
# Sentence 175: After really enjoying ourselves at the <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">bar</aspect-term> we sat down at a table and had dinner.
# Sentence 176: The <aspect-term aspect="SERVICE" polarity="positive">server</aspect-term> was really cool and served us our food and drinks with a smile.
# Sentence 177: The place's <aspect-term aspect="AMBIENCE" polarity="positive">decor</aspect-term> and <aspect-term aspect="AMBIENCE" polarity="positive">hidden bathrooms</aspect-term> made for a good laugh.
# Sentence 178: I highly recommend visiting this <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">restaurant</aspect-term> and having dinner and drinks!
# Sentence 179: If you are the type of person who likes being scared and entertained, this is a great <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term> to go and eat.
# Sentence 180: My husband and I thougt it would be great to go to the <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Jekyll and Hyde Pub</aspect-term> for our anniversary, and to our surprise it was fantastic.
# Sentence 181: The have over 100 different <aspect-term aspect="FOOD" polarity="positive">beers</aspect-term> to offer thier guest so that made my husband very happy and the <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> was delicious, if I must recommend a dish it must be the <aspect-term aspect="FOOD" polarity="positive">pumkin tortelini</aspect-term>.
# Sentence 182: The <aspect-term aspect="AMBIENCE" polarity="positive">entertainment</aspect-term> was great they have shows that go on through out the dinner.
# Sentence 183: Please take my advice, go and try this <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term>.
# Sentence 184: The <aspect-term aspect="FOOD" polarity="positive">bagel</aspect-term> was huge.
# Sentence 185: The workers there also absolutely load the <aspect-term aspect="FOOD" polarity="negative">bagel</aspect-term> with cream cheese (gets a little messy).
# Sentence 186: This was my frist time at Cafe St. Bart's and I must say how delicous the <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> and the <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> was.
# Sentence 187: I have to highly recommend the <aspect-term aspect="FOOD" polarity="positive">lobster roll</aspect-term> - not to much mayo; you can tell it was a fresh <aspect-term aspect="FOOD" polarity="positive">lobster</aspect-term>.
# Sentence 188: Other guests enjoyed <aspect-term aspect="FOOD" polarity="positive">pizza</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">santa fe chopped salad</aspect-term> and <aspect-term aspect="FOOD" polarity="positive">fish and chips</aspect-term>.
# Sentence 189: I highly recommend Cafe St. Bart's for their <aspect-term aspect="FOOD" polarity="positive">food</aspect-term>, the <aspect-term aspect="AMBIENCE" polarity="positive">ambience</aspect-term> and wonderful <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term>.
# Sentence 190: All the <aspect-term aspect="SERVICE" polarity="positive">staff</aspect-term> is absolutely professional!!
# Sentence 191: This <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">restaurant</aspect-term> was way overhyped.
# Sentence 192: My <aspect-term aspect="FOOD" polarity="negative">chow fun and chow see</aspect-term> was really bland and oily.
# Sentence 193: The <aspect-term aspect="FOOD" polarity="neutral">scallion pancakes</aspect-term> and <aspect-term aspect="FOOD" polarity="neutral">fried dumplings</aspect-term> were nothing out of the ordinary.
# Sentence 194: The <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> was the only thing good about this <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">restaurant</aspect-term>.
# Sentence 195: It's boring on the inside, and our <aspect-term aspect="FOOD" polarity="negative">sushi</aspect-term> was pretty below average... the <aspect-term aspect="FOOD" polarity="negative">tuna</aspect-term> was soggy and the other <aspect-term aspect="FOOD" polarity="negative">rolls</aspect-term> had no flavor.
# Sentence 196: Their <aspect-term aspect="FOOD" polarity="positive">pad penang</aspect-term> is delicious and everything else is fantastic.
# Sentence 197: The price is reasonable although the <aspect-term aspect="SERVICE" polarity="negative">service</aspect-term> is poor.
# Sentence 198: <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">fresh restaurant</aspect-term> was amazing........ <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> was delicious and of course fresh.
# Sentence 199: Hats off to the <aspect-term aspect="FOOD" polarity="positive">chef</aspect-term>.
# Sentence 200: the <aspect-term aspect="FOOD" polarity="positive">salads</aspect-term> are delicious, both refreshing and very spicy.
# Sentence 201: We had <aspect-term aspect="FOOD" polarity="positive">Pam's special fried fish</aspect-term> and it was amazing.
# Sentence 202: Great <aspect-term aspect="AMBIENCE" polarity="positive">vibe</aspect-term>, lots of people.
# Sentence 203: I didn't complain, I liked the <aspect-term aspect="AMBIENCE" polarity="positive">atmosphere</aspect-term> so much.
# Sentence 204: <aspect-term aspect="AMBIENCE" polarity="positive">Ambience</aspect-term> is so cute and quaint, good for business although we were there on vacation.
# Sentence 205: <aspect-term aspect="FOOD" polarity="positive">Salads</aspect-term> were fantastic.
# Sentence 206: Although we were looking for regular lettuce and some walnuts the <aspect-term aspect="FOOD" polarity="positive">salads</aspect-term> we got were great.
# Sentence 207: <aspect-term aspect="FOOD" polarity="positive">Ingredients</aspect-term> are organic which is a real plus for me.
# Sentence 208: This is some really good, inexpensive <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">sushi</aspect-term></aspect-term>.
# Sentence 209: The <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">spicy Tuna roll</aspect-term></aspect-term></aspect-term> is huge and probably the best that I've had at this price range.
# Sentence 210: The <aspect-term aspect="FOOD" polarity="positive">Yellowtail</aspect-term> was particularly good as well.
# Sentence 211: I have reservations about the <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative">all you can eat deal</aspect-term></aspect-term>, however -- the choices are fairly limited and you can probably order more food than you can eat for less than $18 by just going off the menu.
# Sentence 212: In any event, this is a <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term> I'll be sure to stop by again when I'm in this part of town.
# Sentence 213: <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Big Wong</aspect-term> gets big Ups for a fine establishment.
# Sentence 214: They have it all -- great price, <aspect-term aspect="FOOD" polarity="positive">food</aspect-term>, and <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term>.
# Sentence 215: The <aspect-term aspect="AMBIENCE" polarity="negative">atmosphere</aspect-term> is noisy and the <aspect-term aspect="SERVICE" polarity="positive">waiters</aspect-term> are literally walking around doing things as fast as they can.
# Sentence 216: And it all comes at a very reasonable price (<aspect-term aspect="FOOD" polarity="positive">congee</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">noodles</aspect-term>, and <aspect-term aspect="FOOD" polarity="positive">rice dishes</aspect-term> are no more than $3-6 each).
# Sentence 217: The <aspect-term aspect="SERVICE" polarity="positive">takeout</aspect-term> is great too since they give high quality tupperware as well.
# Sentence 218: This <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term> is always very crowded and popular.
# Sentence 219: Enjoyed a very nice <aspect-term aspect="FOOD" polarity="positive">Caesar Salad</aspect-term> while my wife had <aspect-term aspect="FOOD" polarity="positive">arugula and goat cheese</aspect-term>....both very tasty.
# Sentence 220: We both opted for a <aspect-term aspect="FOOD" polarity="positive">pasta dish</aspect-term> and they were served timely and fresh.
# Sentence 221: We concluded with <aspect-term aspect="FOOD" polarity="positive">tiramisu chocolate cake</aspect-term>, both were delicious.
# Sentence 222: I recently went to this <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">restaurant</aspect-term> with some co-workers for lunch and had an amazing time.
# Sentence 223: The <aspect-term aspect="SERVICE" polarity="positive">staff</aspect-term> was accomodating, the <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> was absolutely delicious and the <aspect-term aspect="AMBIENCE" polarity="positive">place</aspect-term> is lovely.
# Sentence 224: We even had a visit from the <aspect-term aspect="SERVICE" polarity="positive">Manager</aspect-term> who wanted to make sure we were enjoying ourselves.
# Sentence 225: sometimes i get good <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> and ok <aspect-term aspect="SERVICE" polarity="neutral">service</aspect-term>.
# Sentence 226: sometimes i get bad <aspect-term aspect="FOOD" polarity="negative">food</aspect-term> and bad <aspect-term aspect="SERVICE" polarity="negative">service</aspect-term>, sometimes i get good <aspect-term aspect="FOOD" polarity="positive">good</aspect-term> and bad <aspect-term aspect="SERVICE" polarity="negative">service</aspect-term>.
# Sentence 227: The place is a BISTRO which means: simple <aspect-term aspect="FOOD" polarity="positive">dishes</aspect-term> and <aspect-term aspect="FOOD" polarity="positive">wine</aspect-term> served efficiently in a bustling <aspect-term aspect="AMBIENCE" polarity="positive">atmosphere</aspect-term>.
# Sentence 228: And where does <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Patis</aspect-term> go wrong; no where.
# Sentence 229: And evaluated on those terms <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Pastis</aspect-term> is simply wonderful.
# Sentence 230: Right off the L in Brooklyn this is a nice cozy <aspect-term aspect="AMBIENCE" polarity="positive">place</aspect-term> with good <aspect-term aspect="FOOD" polarity="positive">pizza</aspect-term>.
# Sentence 231: Mine was a little burnt but still delicious with goat cheese and panchetta (<aspect-term aspect="FOOD" polarity="negative">raddichio</aspect-term> was kind of bitter though).
# Sentence 232: My friend got the <aspect-term aspect="FOOD" polarity="positive">mushroom pizza</aspect-term> which tasted better.
# Sentence 233: The <aspect-term aspect="FOOD" polarity="positive">sangria</aspect-term> was pretty tasty and good on a hot muggy day.
# Sentence 234: Kind of a small <aspect-term aspect="GENERAL-IMPRESSION" polarity="neutral">place</aspect-term> but I guess if they are not too busy might be able to fit a group or kids.
# Sentence 235: I started out with a <aspect-term aspect="FOOD" polarity="positive">Bombay beer</aspect-term> which was big enough for two.
# Sentence 236: <aspect-term aspect="SERVICE" polarity="negative">Service</aspect-term> was slow, but the <aspect-term aspect="SERVICE" polarity="positive">people</aspect-term> were friendly.
# Sentence 237: It's a nice <aspect-term aspect="AMBIENCE" polarity="positive">place</aspect-term> to relax and have conversation.
# Sentence 238: The <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> is authentic Italian - delicious!
# Sentence 239: <aspect-term aspect="FOOD" polarity="positive">Pizza</aspect-term> is terrific, as is <aspect-term aspect="FOOD" polarity="positive">homemade pasta</aspect-term>.
# Sentence 240: <aspect-term aspect="AMBIENCE" polarity="positive">Ambience</aspect-term> is delightful, <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> impeccable.
# Sentence 241: I'm still mad that i had to pay for lousy <aspect-term aspect="FOOD" polarity="negative">food</aspect-term>.
# Sentence 242: The <aspect-term aspect="FOOD" polarity="negative">hanger steak</aspect-term> was like rubber and the <aspect-term aspect="FOOD" polarity="negative">tuna</aspect-term> was flavorless not to mention it tasted like it had just been thawed.
# Sentence 243: <aspect-term aspect="SERVICE" polarity="negative">Service</aspect-term> was also horrible and the <aspect-term aspect="AMBIENCE" polarity="negative">ambience</aspect-term> is not that great.
# Sentence 244: I go and eat out at many different restaurants and this is one <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term> you have go and try.
# Sentence 245: This is my first time writing a review for a restaurant because the <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> and <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> was excellent.
# Sentence 246: The <aspect-term aspect="FOOD" polarity="positive">filet mignon dish</aspect-term> was superb!
# Sentence 247: It's a small cute <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">restaurant</aspect-term>.
# Sentence 248: I absolutely love this <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term>!!!
# Sentence 249: I like the <aspect-term aspect="AMBIENCE" polarity="positive">ambience</aspect-term>, it's very dark and original.
# Sentence 250: The <aspect-term aspect="FOOD" polarity="positive">sushi</aspect-term> is amazing!!!
# Sentence 251: Very affordable and excellent <aspect-term aspect="AMBIENCE" polarity="positive">ambient</aspect-term>!
# Sentence 252: We ordered some <aspect-term aspect="FOOD" polarity="negative">beef and noodle soup dishes</aspect-term> from the Thai section of the menu but nothing we got was Thai.
# Sentence 253: We won't go to this place again for a good <aspect-term aspect="FOOD" polarity="negative">meal</aspect-term>.
# Sentence 254: However, I think this <aspect-term aspect="AMBIENCE" polarity="positive">place</aspect-term> is a good hang out spot.
# Sentence 255: My Girlfriend and I stumbled onto this hopping <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term> the other night and had a great time!
# Sentence 256: THe <aspect-term aspect="FOOD" polarity="positive">Pizza</aspect-term> and <aspect-term aspect="FOOD" polarity="positive">wine</aspect-term> were excellent-the <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> too--but what really MADE this place was the <aspect-term aspect="AMBIENCE" polarity="positive">backyard dining area</aspect-term>.
# Sentence 257: It is one the nicest <aspect-term aspect="AMBIENCE" polarity="positive">outdoor restaurants</aspect-term> I have ever seen in NY--I am from Italy and this place rivals the ones in my country.
# Sentence 258: Check this <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term> out!
# Sentence 259: First of all, this <aspect-term aspect="AMBIENCE" polarity="negative">place</aspect-term> is *not* romantic, as claimed by Citysearch's editorial review.
# ...
# Sentence 754: <aspect-term aspect="FOOD" polarity="positive">Beef noodle soup</aspect-term> is good as well.
# Sentence 755: The <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> is good and the <aspect-term aspect="AMBIENCE" polarity="positive">resturant</aspect-term> is clean.
# Sentence 756: Best <aspect-term aspect="FOOD" polarity="positive">Taiwanese food</aspect-term> in NY!
# Sentence 757: I have been to <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Rao's</aspect-term> probably 15 times the past 3 years and it keeps getting better.
# Sentence 758: Rao's has the best <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> and <aspect-term aspect="AMBIENCE" polarity="positive">atmosphere</aspect-term> in NYC.
# Sentence 759: My roommate and I LOVE this <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term>.
# Sentence 760: We recently decided to try this location, and to our delight, they have <aspect-term aspect="AMBIENCE" polarity="positive">outdoor seating</aspect-term>, perfect since I had my yorkie with me.
# Sentence 761: <aspect-term aspect="AMBIENCE" polarity="positive">Indoor</aspect-term> was very cozy and cute.
# Sentence 762: The <aspect-term aspect="FOOD" polarity="positive">portion sizes</aspect-term> here are huge, and the <aspect-term aspect="FOOD" polarity="positive">sushi</aspect-term> is good.
# Sentence 763: <aspect-term aspect="SERVICE" polarity="positive">Staff</aspect-term> is very accomodating.
# Sentence 764: Excellent <aspect-term aspect="FOOD" polarity="positive">dumplings</aspect-term> served amid clean, chic <aspect-term aspect="AMBIENCE" polarity="positive">decor</aspect-term>.
# Sentence 765: I got the <aspect-term aspect="FOOD" polarity="positive">$10 10-piece dim sum combo</aspect-term>, every bite of which was great.
# Sentence 766: The <aspect-term aspect="AMBIENCE" polarity="positive">decor</aspect-term> is very simple but comfortable.
# Sentence 767: The <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="positive">food</aspect-term></aspect-term> was delicious but do not come here on a empty stomach.
# Sentence 768: The <aspect-term aspect="FOOD" polarity="negative">portions</aspect-term> are small but being that the <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> was so good makes up for that.
# Sentence 769: You must have the <aspect-term aspect="FOOD" polarity="positive">crabmeat lasagna</aspect-term> which is out of this world and the <aspect-term aspect="FOOD" polarity="positive">chocolate bread pudding</aspect-term> for dessert.
# Sentence 770: The <aspect-term aspect="SERVICE" polarity="positive">staff</aspect-term> there is very attentive and down to earth.
# Sentence 771: Great <aspect-term aspect="FOOD" polarity="positive">Indian food</aspect-term> and the <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> is incredible.
# Sentence 772: The <aspect-term aspect="SERVICE" polarity="positive">owner</aspect-term> truly caters to all your needs.
# Sentence 773: Great <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> and the prices are very reasonable.
# Sentence 774: The <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> here does a great service to the name (Cantonese that is...).
# Sentence 775: I fell in love with the <aspect-term aspect="FOOD" polarity="positive">egg noodles in the beef broth with shrimp dumplings and slices of BBQ roast pork</aspect-term>.
# Sentence 776: This <aspect-term aspect="FOOD" polarity="positive">dish</aspect-term> is my favorite and I always get it when I go there and never get tired of it.
# Sentence 777: Try the <aspect-term aspect="FOOD" polarity="positive">congee</aspect-term> and the donut like deep fried dough they call <aspect-term aspect="FOOD" polarity="positive">Ow Ley Soh</aspect-term>, a delicious and sweet tasting bread.
# Sentence 778: Simply some good tasting <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Chinese food</aspect-term></aspect-term> at incredible prices...
# Sentence 779: <aspect-term aspect="SERVICE" polarity="negative">Service</aspect-term> is not what you are coming here for...
# Sentence 780: <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Big Wong</aspect-term> is a great place to eat and fill your stomach.
# Sentence 781: whoever the <aspect-term aspect="AMBIENCE" polarity="positive">jazz duo</aspect-term> was, they were on POINT.
# Sentence 782: good <aspect-term aspect="AMBIENCE" polarity="positive">music</aspect-term>, great <aspect-term aspect="FOOD" polarity="positive">food</aspect-term>, speedy <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> affordable prices.
# Sentence 783: even the <aspect-term aspect="FOOD" polarity="positive">wine by the glass</aspect-term> was good.
# Sentence 784: Consistently good <aspect-term aspect="FOOD" polarity="positive">Japanese Tapas</aspect-term>.
# Sentence 785: Always good <aspect-term aspect="FOOD" polarity="positive">drinks</aspect-term> and <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> is pretty good;
# Sentence 786: <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphere</aspect-term> is nice and relaxed too...
# Sentence 787: A great <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term> to meet up for some food and drinks...
# Sentence 788: <aspect-term aspect="FOOD" polarity="positive">Yakitori (bbq meats)</aspect-term> is tasty too.
# Sentence 789: If you don't mind pre-sliced low quality <aspect-term aspect="FOOD" polarity="negative">fish</aspect-term>, unfriendly <aspect-term aspect="SERVICE" polarity="negative">staff</aspect-term> and a <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">sushi chef</aspect-term> that looks like he is miserable then this is your place.
# Sentence 790: Price and quality of <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative">fish</aspect-term></aspect-term> alone will keep us from making a return visit.
# Sentence 791: Wasn't going to share but I feel obligated...while sitting at the sushi bar dining we watched the <aspect-term aspect="FOOD" polarity="negative">chef</aspect-term> accidentally drop a piece of Unagi on the floor and upon retrieving it from the floor proceed to use the piece in the delivery order he was preparing.
# Sentence 792: This <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term>, which is only a few months old, is perhaps Queens' biggest secret!
# Sentence 793: Fabulous <aspect-term aspect="AMBIENCE" polarity="positive">decor</aspect-term> - makes you feel like you're in a trendy Manhattan restaurant, very very good <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">food</aspect-term></aspect-term>, cheaply-priced, generally friendly <aspect-term aspect="SERVICE" polarity="positive">staff</aspect-term>, and if you're a Manhattanite, or spend most of your time in Manhattan, <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive"><aspect-term aspect="AMBIENCE" polarity="positive"><aspect-term aspect="AMBIENCE" polarity="positive">Rice Avenue</aspect-term></aspect-term></aspect-term> will make you feel at home.....very Soho/Village/Upper West Side minus the expensive prices and pretentious clientele.....all on Roosevelt Avenue!
# Sentence 794: We were seated outside and the <aspect-term aspect="SERVICE" polarity="negative">waiter</aspect-term> spilled red wine and hot tea on myself and my date.
# Sentence 795: One would think we'd get an apology or complimentary drinks - instead, we got a snobby <aspect-term aspect="SERVICE" polarity="negative">waiter</aspect-term> wouldn't even take our order for 15 minutes and gave us lip when we asked him to do so.
# Sentence 796: With so many good restaurants on the UWS, I don't need overpriced <aspect-term aspect="FOOD" polarity="negative">food</aspect-term>, absurdly arrogant <aspect-term aspect="SERVICE" polarity="negative">wait-staff</aspect-term> who don't recognize they work at a glorified diner, clumsy <aspect-term aspect="SERVICE" polarity="negative">service</aspect-term>, and <aspect-term aspect="SERVICE" polarity="negative">management</aspect-term> that doesn't care.
# Sentence 797: I am relatively new to the area and tried Pick a bgel on 2nd and was disappointed with the <aspect-term aspect="SERVICE" polarity="negative">service</aspect-term> and I thought the <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative">food</aspect-term></aspect-term> was overated and on the pricey side.
# Sentence 798: The <aspect-term aspect="FOOD" polarity="neutral">food</aspect-term> is okay and the prices here are mediocre.
# Sentence 799: <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Baluchi's</aspect-term> has solid <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> and a nice <aspect-term aspect="AMBIENCE" polarity="positive">decor</aspect-term> at reasonable prices.
# Sentence 800: The only problem is that the <aspect-term aspect="SERVICE" polarity="negative">manager</aspect-term> is a complete incompetent.
# Sentence 801: He offers subpar <aspect-term aspect="SERVICE" polarity="negative">service</aspect-term> and has no personality.
# Sentence 802: There is no excuse for such lousy <aspect-term aspect="SERVICE" polarity="negative">service</aspect-term>!
# Sentence 803: I have never before eaten 40 pieces of relatively good <aspect-term aspect="FOOD" polarity="neutral">nigiri</aspect-term>.
# Sentence 804: $20 for <aspect-term aspect="FOOD" polarity="positive">all you can eat sushi</aspect-term> cannot be beaten.
# Sentence 805: I went to <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Areo</aspect-term> on a Sunday afternoon with four of my girlfriends, and spent three enjoyable hours there.
# Sentence 806: Most of the <aspect-term aspect="SERVICE" polarity="positive">servers</aspect-term> are very attentive, friendly and quite attractive.
# Sentence 807: The <aspect-term aspect="AMBIENCE" polarity="positive">vibe</aspect-term> is very relaxed and cozy, <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> was great and the <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> was excellent!
# Sentence 808: <aspect-term aspect="FOOD" polarity="positive">Food</aspect-term> was good and the <aspect-term aspect="AMBIENCE" polarity="positive">view of the new york city skiline</aspect-term> was terrific even on a foggy rainy day like that of when I went.
# Sentence 809: I would highly recommand requesting a <aspect-term aspect="AMBIENCE" polarity="positive">table by the window</aspect-term>.
# Sentence 810: Although they do the typical what kind of water would you like questions the <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> was good and overall very relaxing to <aspect-term aspect="AMBIENCE" polarity="positive">place</aspect-term> to eat.
# Sentence 811: The <aspect-term aspect="FOOD" polarity="positive">food</aspect-term> is great.
# Sentence 812: <aspect-term aspect="FOOD" polarity="positive">Personal pans</aspect-term> are the perfect size for those hungry nights.
# Sentence 813: There is a downside if you're ordering in -- the <aspect-term aspect="SERVICE" polarity="negative">delivery guys</aspect-term> have MAJOR attitude.
# Sentence 814: Never have I had such dramatic <aspect-term aspect="SERVICE" polarity="negative">delivery guys</aspect-term> (a lot of huffing and panting and muttering under breath b/c I live in a walkup) who always seem disappointed with their tips.
# Sentence 815: Love the <aspect-term aspect="AMBIENCE" polarity="positive">scene</aspect-term> first off- the <aspect-term aspect="AMBIENCE" polarity="positive">place</aspect-term> has a character and nice light to it..very fortunate, <aspect-term aspect="AMBIENCE" polarity="positive">location</aspect-term> wise.
# Sentence 816: The <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">pizza</aspect-term></aspect-term> was pretty good and huge.
# Sentence 817: We were 4 and got the family size <aspect-term aspect="FOOD" polarity="positive">penne a la vodka</aspect-term> which was tremendously gigantic portion...a bucket of food literally.
# Sentence 818: The <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative">pasta penne</aspect-term></aspect-term> was pretty extra buttery, creamy which means a big task to diggest.. tasty at first but i would say that i was full with a slice of pizza and 7 to count, penne...got a little moody afterwards cause was stuffed...lol
# Sentence 819: <aspect-term aspect="FOOD" polarity="positive">La Rosa</aspect-term> waltzes in, and I think they are doing it the best.
# Sentence 820: Interesting <aspect-term aspect="FOOD" polarity="positive">selection</aspect-term>, good <aspect-term aspect="FOOD" polarity="positive">wines</aspect-term>, <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> fine, fun <aspect-term aspect="AMBIENCE" polarity="positive">decor</aspect-term>.
# Sentence 821: I found it on a cold night, the perfect <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">spot</aspect-term> to warm up.
# Sentence 822: I recieved prompt <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> with a smile.
# Sentence 823: This <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">place</aspect-term> blew me away...by far my new favorite restaurant on the uppereast side.
# Sentence 824: The <aspect-term aspect="FOOD" polarity="positive">wine list</aspect-term> is extensive and impressive.
# Sentence 825: LOVE the <aspect-term aspect="AMBIENCE" polarity="positive">atmosphere</aspect-term> - felt like I was in Paris.
# Sentence 826: The <aspect-term aspect="FOOD" polarity="positive">mussels</aspect-term> were fantastic and so was the <aspect-term aspect="FOOD" polarity="positive">dessert</aspect-term>...definitely going to be back very soon.
# Sentence 827: I have been coming here for years and have nothing but good things to say about the <aspect-term aspect="SERVICE" polarity="positive">service</aspect-term> and the great <aspect-term aspect="SERVICE" polarity="positive">staff</aspect-term> at La Lanterna.
# Sentence 828: Over the years the <aspect-term aspect="SERVICE" polarity="positive">host</aspect-term>, Vittorio, and his <aspect-term aspect="SERVICE" polarity="positive">crew</aspect-term>, have always treated me as family--although with all the business this not-so-little gem does, it amazing he's even able to remember a consistent but not-so-frequent visitor.
# Sentence 829: I've also been amazed at all the new additions in the past few years: A new <aspect-term aspect="AMBIENCE" polarity="positive">Jazz Bar</aspect-term>, the most fantastic <aspect-term aspect="AMBIENCE" polarity="positive">Dining Garden</aspect-term>, the Best <aspect-term aspect="FOOD" polarity="positive">Thin Crust Pizzas</aspect-term>, and now a <aspect-term aspect="FOOD" polarity="positive">Lasagna Menu</aspect-term> which is to die for (these are not your average lasagnas)!
# Sentence 830: I lOVE THIS <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">PLACE</aspect-term>!
# Sentence 831: I have to say I have never had a disapointing <aspect-term aspect="FOOD" polarity="positive">meal</aspect-term> here.
# Sentence 832: We could have made a meal of the yummy <aspect-term aspect="FOOD" polarity="positive">dumplings</aspect-term> from the dumpling menu.
# Sentence 833: Luckily we saved room for the <aspect-term aspect="FOOD" polarity="positive">BBQ Salmon</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">Sea Bass</aspect-term> and <aspect-term aspect="FOOD" polarity="positive">Crispy Duck</aspect-term>.

# %%
# validated translated sentences
validated_sent = []


for idx, match in enumerate(matches, start=1):

    tags = re.findall(r"<.*?>", match)
    modified_text = re.sub(r"<.*?>", "|", match)
    number_tags = len(tags)

    # Retry counter
    counter = 0

    while(True):

        

        #Translation here
        response: ChatResponse = chat(model='llama3.2', messages=[
            {
        'role': 'user',
        'content': f"Translate the following sentence into german: {modified_text}. Return only the translated string. Keep the '|' symbol in the translation",
            },
        ])

        translated = response.message.content

        counter += 1
        print(f"Retry count {counter}")
        
        if counter == 10:
            break

        # check if Pipe symbol
        if translated.count('|') == number_tags:
            print(f"Review {idx} ---- checked")
            break
    
    for tag in tags:
        translated = translated.replace("|", tag, 1)

    print(translated)
    validated_sent.append(translated)

    # for tag in tags:
    #     translated = translated.replace("|", tag)

    # print(translated)

    # if re.search(pattern, translated):
    #     print(True)
    #     validated_sent.append(translated)
    # else:
    #     print(False)
    #     print(match)
# Out:
# Retry count 1
# Review 1 ---- checked
# Die Meinung, die man von vorherigen Beiträgen ableitet, ist das hier früher ein gutes <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">Ort</aspect-term>, aber nicht mehr so.
# Retry count 1
# Review 2 ---- checked
# Wir, dort waren vier von uns, kamen um Mittag an – das Ort war leer – und die <aspect-term aspect="SERVICE" polarity="negative">Personal</aspect-term> verharr wie wir sie belasteten und sie waren sehr unhöflich.
# Retry count 1
# Review 3 ---- checked
# Die <aspect-term aspect="FOOD" polarity="negative">Nahrung</aspect-term> war schlecht - zu süß oder zu salzig und die <aspect-term aspect="FOOD" polarity="negative">Portionen</aspect-term> waren klein..
# Retry count 1
# Review 4 ---- checked
# Vermeiden Sie diesen <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">Ort</aspect-term>.
# Retry count 1
# Review 5 ---- checked
# Ich habe mehrmals zu Saul gegessen, das <aspect-term aspect="FOOD" polarity="positive"> Essen </aspect-term> ist immer wieder verblüffend gut.
# Retry count 1
# Review 6 ---- checked
# <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Maurizius</aspect-term> ist der beste Restaurant auf Smith Street und in Brooklyn..
# Retry count 1
# Review 7 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Entenbrühe</aspect-term> ist immer beeindruckend und die <aspect-term aspect="FOOD" polarity="positive">Fois Gras-Terrine mit Fichten</aspect-term> war aus diesem Welt
# Retry count 1
# Retry count 2
# Review 8 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Weinliste</aspect-term></aspect-term> ist interessant und hat viele gute Werte.
# Retry count 1
# Review 9 ---- checked
# Ich war sehr enttäuscht mit diesem <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">Restaurant</aspect-term>.
# Retry count 1
# Review 10 ---- checked
# Ich habe einen <aspect-term aspect="SERVICE" polarity="negative">Einkäufer im Warenhaus</aspect-term> um eine Lotusblatt gewickelte Reisart gefragt und sie erwiderte mit "Reis" und ging nur weg.
# Retry count 1
# Review 11 ---- checked
# <aspect-term aspect="FOOD" polarity="neutral">Leute</aspect-term> waren okay, nichts Besonderes..
# Retry count 1
# Retry count 2
# Review 12 ---- checked
# <aspect-term aspect="FOOD" polarity="negative">Chow fun</aspect-term> war trocken; <aspect-term aspect="FOOD" polarity="negative">Schweinebällchen</aspect-term> waren überraschend fett und mussten an einem Tisch mit lautem und rauen Familienmitglied sitzen.
# Retry count 1
# Retry count 2
# Retry count 3
# Retry count 4
# Review 13 ---- checked
# Ich/Wir werden dieses <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">Ort</aspect-term> niemals wieder besuchen.
# Retry count 1
# Review 14 ---- checked
# Gegangen bin auf einen 3-Tage-Osterschlemmer, mit <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Fisch</aspect-term> brachte den Abschluss, und ich bin so glücklich, dass dies war der Ort, auf den ich diese Reise beendete, weil es so großartig gewesen ist!
# Retry count 1
# Review 15 ---- checked
# <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> war göttlich, <aspect-term aspect="FOOD" polarity="positive">Oysters</aspect-term> sind so sinnlich wie möglich und der Preis kann nicht übertroffen werden!!!.
# Retry count 1
# Review 16 ---- checked
# Jedes Mal, wenn ich mich in New York finde, besuche ich immer <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Restaurant Saul</aspect-term> auf der Smith Street..
# Retry count 1
# Review 17 ---- checked
# Alles ist immer perfekt zubereitet, der <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term> ist auszeichnet, der <aspect-term aspect="AMBIENCE" polarity="positive">Decor</aspect-term> ist cool und unterhaltsam.
# Retry count 1
# Review 18 ---- checked
# Ich hatte das <aspect-term aspect="FOOD" polarity="positive">Tafelspitz-Spezial</aspect-term> auf meinem letzten Besuch und es war unglaublich.
# Retry count 1
# Review 19 ---- checked
# Die <aspect-term aspect="FOOD" polarity="negative">Nahrung</aspect-term> ist sehr mittelmäßig...die <aspect-term aspect="FOOD" polarity="negative">thaifusionartige Speisen</aspect-term> sind ein wenig zu süß, alles sie hier servieren ist zu süß...
# Retry count 1
# Review 20 ---- checked
# Das einzige, was ich nur mittelmäßig genossen habe, war ihr <aspect-term aspect="FOOD" polarity="positive">Gegrilltes Hähnchen Special mit Edamamerüese</aspect-term>.
# Retry count 1
# Review 21 ---- checked
# Ich hatte <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Edamame puré</aspect-term></aspect-term> noch nie zuvor, aber ich fand es innovativ und lecker (dazu hätte man ein bisschen mehr Salz gebraucht).
# Retry count 1
# Review 22 ---- checked
# Die <aspect-term aspect="AMBIENCE" polarity="positive">Zimmerdekoration</aspect-term> ist Nacht though...aber sie brauchen REALLY zu reinigen die <aspect-term aspect="AMBIENCE" polarity="negative">Lüftung</aspect-term> im Dach...es ist wirklich unappetitlich und tötet euren Versuch, dieses <aspect-term aspect="AMBIENCE" polarity="negative">Ort</aspect-term> zu einem sauberen und modernen aussehen zu bringen.
# Retry count 1
# Review 23 ---- checked
# Ihr <aspect-term aspect="FOOD" polarity="positive">Sakeliste</aspect-term> war umfangreich, aber wir suchten nach Purple Haze, das nicht aufgeführt war, sondern uns auf Anfrage erstellt wurde!
# Retry count 1
# Review 24 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Scharfe Thunfisch-Roll</aspect-term> war ungewöhnlich gut und die <aspect-term aspect="FOOD" polarity="positive">Rockschrimptemperatur</aspect-term> war beeindruckend, großartiges Appetisier zum Teilen!
# Retry count 1
# Review 25 ---- checked
# Wir gingen um 09:30 Uhr am Freitag und es war dann schon ein bisschen abgeklungen, so dass der <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term> großartig war!
# Retry count 1
# Review 26 ---- checked
# Wir lieben die <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">rosa Pferd </aspect-term>..
# Retry count 1
# Review 27 ---- checked
# Die perfekte <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Stelle</aspect-term>.
# Retry count 1
# Retry count 2
# Review 28 ---- checked
# <aspect-term aspect="FOOD" polarity="positive">Lebensmittel</aspect-term>-awesom...
# Retry count 1
# Review 29 ---- checked
# <aspect-term aspect="SERVICE" polarity="positive">Dienstleistungsfreundlich und aufmerksam</aspect-term>
# Retry count 1
# Review 30 ---- checked
# <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term>- entspannt und stilvoll
# Retry count 1
# Review 31 ---- checked
# Entschuldigt sich vorab: Diese Situation ist nicht zu diskutieren <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term>. Sie muss einfach ausprobiert werden, um zu glauben. Es handelt sich hier um ein Zuhause für diejenigen mit einem liebsten Buch im Herzen.
# Retry count 1
# Review 32 ---- checked
# Die <aspect-term aspect="FOOD" polarity="neutral">Nahrung</aspect-term> ist zufriedenstellend.
# Retry count 1
# Review 33 ---- checked
# Es sind jedoch der <aspect-term aspect="SERVICE" polarity="negative">Dienst</aspect-term>, der mir einen schlechten Geschmack im Mund lässt.
# Retry count 1
# Review 34 ---- checked
# Ich habe zufällig eine Politik, die sich mit einem Hauch von Selbstachtung verbindet, die darin besteht, nicht zu lassen, dass ein <aspect-term aspect="SERVICE" polarity="negative">Kellner</aspect-term> mich einschüchtert, d.h. mich schlecht fühlt, wenn ich nach Nischen wie Wasser oder das Rechnungsaufzeichnen fragen.
# Retry count 1
# Retry count 2
# Retry count 3
# Review 35 ---- checked
# Dieser <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term> muss unbedingt das beste japanische Restaurant in der neuen yorkart Area sein.
# Retry count 1
# Review 36 ---- checked
# <aspect-term aspect="FOOD" polarity="positive">Lebensmittel</aspect-term> ist großartig..
# Retry count 1
# Review 37 ---- checked
# <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> ist Spitzenklasse..
# Retry count 1
# Review 38 ---- checked
# Ich neige dazu, ein Sushi-Restaurant zu beurteilen, mit seinem <aspect-term aspect="FOOD" polarity="positive">Seegurke</aspect-term>, der himmlisch war bei Sushi Rose.
# Retry count 1
# Retry count 2
# Review 39 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Sushi</aspect-term></aspect-term> schien ziemlich frisch und war ausreichend proportioniert.
# Retry count 1
# Review 40 ---- checked
# Der <aspect-term aspect="FOOD" polarity="positive">Reis zu Fisch-Verhältnis</aspect-term> war auch gut—sie haben nicht versucht, den Reis überzuladen..
# Retry count 1
# Retry count 2
# Retry count 3
# Review 41 ---- checked
# Wir nahmen den Vorteil aus der <aspect-term aspect="FOOD" polarity="positive">halbfreien Sushi-Angebot</aspect-term> am Samstag also war es wert.
# Retry count 1
# Retry count 2
# Review 42 ---- checked
# In der Nacht zog dieses Ort eine gut angemessene Kleidung mit sich, NY <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Crowd</aspect-term>.
# Retry count 1
# Review 43 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Leckerei</aspect-term> war gut zubereitet und das <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> war perfekt.
# Retry count 1
# Review 44 ---- checked
# Der <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Prix Fixe Menü</aspect-term></aspect-term></aspect-term> ist wertvoll und man erhält mehr als genug (sowohl in Menge als auch in Qualität).
# Retry count 1
# Retry count 2
# Retry count 3
# Review 45 ---- checked
# $6 und es gibt viel leckeres <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Food</aspect-term></aspect-term></aspect-term>, alles davon frisch und ständig nachgefüllt.
# Retry count 1
# Review 46 ---- checked
# Ich bin nicht ein Vegetarier aber fast alle <aspect-term aspect="FOOD" polarity="positive">Gänge</aspect-term> waren großartig.
# Retry count 1
# Review 47 ---- checked
# Das <aspect-term aspect="FOOD" polarity="positive">Essen</aspect-term> hier ist recht gut, aber nur wenn du darauf wartest..
# Retry count 1
# Review 48 ---- checked
# Ich mag die <aspect-term aspect="FOOD" polarity="positive">Somosas</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">Chai</aspect-term> und das <aspect-term aspect="FOOD" polarity="positive">Chole</aspect-term>, aber <aspect-term aspect="FOOD" polarity="negative">Dhosas</aspect-term> und <aspect-term aspect="FOOD" polarity="negative">Dhal</aspect-term> waren ein bisschen enttäuschend.
# Retry count 1
# Review 49 ---- checked
# Die <aspect-term aspect="SERVICE" polarity="negative">Dienste</aspect-term> wechseln sich täglich ab - manchmal sind sie sehr nett, und manchmal auch nicht so.
# Retry count 1
# Retry count 2
# Review 50 ---- checked
# Das <aspect-term aspect="SERVICE" polarity="negative">Küchen</aspect-term> ist jedoch fast immer langsam.
# Retry count 1
# Review 51 ---- checked
# Auch, spezifizieren Sie, ob Sie Ihr <aspect-term aspect="FOOD" polarity="negative">Leckerei</aspect-term> scharf mögen - es ist ziemlich matt, wenn Sie es nicht sind..
# Retry count 1
# Review 52 ---- checked
# Der <aspect-term aspect="AMBIENCE" polarity="positive">Ambiente</aspect-term> ist schön und gut für das Gespräch, also wäre ein entspannter Mittagessen hier wahrscheinlich der beste.
# Retry count 1
# Retry count 2
# Retry count 3
# Retry count 4
# Retry count 5
# Retry count 6
# Review 53 ---- checked
# Wenn du jemals entlang des Flusses in Weehawken warst, hast du eine Vorstellung davon, was die Spitze der <aspect-term aspect="AMBIENCE" polarity="positive">Ansichtskarte</aspect-term> im Chart House zu bieten hat.
# Retry count 1
# Review 54 ---- checked
# Füge zu dem großartigen <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> und großartigem <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Essen</aspect-term></aspect-term> bei einem vernünftigen Preis und du hast dir selbst die Anfänge eines großen Abends gesichert.
# Retry count 1
# Review 55 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Vulkaacake- Dessert</aspect-term> war unglaublich und ich empfehle es sehr!
# Retry count 1
# Review 56 ---- checked
# Sobald du in <aspect-term aspect="AMBIENCE" polarity="positive">Cosette</aspect-term> trittst, bist du wunderbar in einem kleinen, abgelegenen Pariser Bistro verwiesen..
# Retry count 1
# Review 57 ---- checked
# Dieses kleine <aspect-term aspect="AMBIENCE" polarity="positive">Restaurant</aspect-term> ist so gemütlich wie es geht, mit diesem bestimmten Pariser Charme.
# Retry count 1
# Review 58 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Leckerei</aspect-term> war mittelmäßig bis überdurchschnittlich; die <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="negative">Französische Eintopfsoße</aspect-term></aspect-term>füllung war jedoch nicht besonders beeindruckend, und die <aspect-term aspect="FOOD" polarity="negative">Desserts</aspect-term> waren in keiner Weise brillant..
# Retry count 1
# Review 59 ---- checked
# Denke daran, gehe für die <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term>, und überlege dir das <aspect-term aspect="FOOD" polarity="neutral">Essen</aspect-term> nur als Begleiter für einen Trip um die Welt!
# Retry count 1
# Review 60 ---- checked
# Die <aspect-term aspect="FOOD" polarity="negative">Pizza</aspect-term> wurde kalt geliefert und das <aspect-term aspect="FOOD" polarity="negative">Käse</aspect-term> war nicht einmal voll gesmolzen!
# Retry count 1
# Review 61 ---- checked
# Die <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative">Pizze</aspect-term></aspect-term> ist überpreisst und nass.
# Retry count 1
# Retry count 2
# Review 62 ---- checked
# Ja, sie verwenden leckere <aspect-term aspect="FOOD" polarity="positive">Zutaten</aspect-term>, aber selbst leckere Zutaten machen keinen guten <aspect-term aspect="FOOD" polarity="negative">Pizza</aspect-term> zu, wenn jemand weiß, wie man die <aspect-term aspect="FOOD" polarity="negative">Teig</aspect-term> richtig bekommt..
# Retry count 1
# Review 63 ---- checked
# Ich denke, ich habe einige der besten <aspect-term aspect="FOOD" polarity="positive">gerichte</aspect-term> meines Lebens bei Minnow gegessen.
# Retry count 1
# Review 64 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Fisch- und Meeresfrüchte</aspect-term> sind unglaublich, es gibt eine gute <aspect-term aspect="FOOD" polarity="positive">Weinliste</aspect-term>, und das ständig wechselnde <aspect-term aspect="FOOD" polarity="positive">Menü</aspect-term> bietet immer wieder tolle Überraschungen..
# Retry count 1
# Review 65 ---- checked
# Die Kombination von super-frischen <aspect-term aspect="FOOD" polarity="positive">Zutaten</aspect-term> in den Gerichten ist ungewöhnlich aber wirklich lecker.
# Retry count 1
# Retry count 2
# Review 66 ---- checked
# Beste <aspect-term aspect="FOOD" polarity="positive">Pastrami-</aspect-term> habe ich je und groß <aspect-term aspect="FOOD" polarity="positive">Portion</aspect-term>-ohne lächerlich zu sein...
# Retry count 1
# Retry count 2
# Retry count 3
# Retry count 4
# Retry count 5
# Retry count 6
# Retry count 7
# Retry count 8
# Retry count 9
# Retry count 10
# Meine Frau hatte die <aspect-term aspect="FOOD" polarity="positive">gebratenen Hummer<aspect-term aspect="FOOD" polarity="positive">, die riesig sind und liebte es.
# Retry count 1
# Review 68 ---- checked
# Als japanischer Native habe ich in der Tristate-Gegend über 8 Jahre lang gelebt, aber ich war einfach nur so beeindruckt von diesem <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term>.
# Retry count 1
# Retry count 2
# Retry count 3
# Retry count 4
# Retry count 5
# Retry count 6
# Retry count 7
# Retry count 8
# Retry count 9
# Retry count 10
# Dieser Ort ist das japanischste es jemals sein kann..
# Retry count 1
# Review 70 ---- checked
# Die <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Zeichen</aspect-term>, die <aspect-term aspect="FOOD" polarity="positive">Spezialmenüs</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">Lebensmittel</aspect-term> und sogar alle <aspect-term aspect="SERVICE" polarity="positive">Kellner</aspect-term> sind ALLE GANZ und GANZ TOTAL japanisch.
# Retry count 1
# Review 71 ---- checked
# Dieser Ort <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">lokal</aspect-term> lohnt sich nicht für eine eine Stunde Fahrt.
# Retry count 1
# Review 72 ---- checked
# <aspect-term aspect="AMBIENCE" polarity="positive"><aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Lionel</aspect-term></aspect-term> ist ein Schmuckstück des Ostviertels: locker aber hip, mit gut vorbereitetem Grundkosten- <aspect-term aspect="FOOD" polarity="positive">Französischer Bistro-Lieferumgang</aspect-term>, guten <aspect-term aspect="FOOD" polarity="positive">Spezialangeboten</aspect-term>, einer warmen und lebhaften <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term>..
# Retry count 1
# Review 73 ---- checked
# Meine Frau und ich genießen immer die jungen, nicht immer gut geschulte aber dennoch freundlichen <aspect-term aspect="SERVICE" polarity="positive">Staff</aspect-term>, von denen jeder eine Geschichte hat.
# Retry count 1
# Retry count 2
# Review 74 ---- checked
# Zuent <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="neutral"> Wein </aspect-term></aspect-term> zu vernünftigen Preisen..
# Retry count 1
# Review 75 ---- checked
# Jedoch jedenmal, wenn ich mich entscheide, noch einen Ort auf der UES auszuprobieren, werde ich empört sein, dass ich nicht nur zu <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Zucchero Pomodori</aspect-term> gegangen bin..
# Retry count 1
# Review 76 ---- checked
# Dies ist weit entfernt meine Lieblings- <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">platz</aspect-term> im Viertel..
# Retry count 1
# Review 77 ---- checked
# Die <aspect-term aspect="SERVICE" polarity="positive">Leistung</aspect-term> ist ausgezeichnet, die <aspect-term aspect="AMBIENCE" polarity="positive">Zeremonie</aspect-term> ist großartig und die <aspect-term aspect="FOOD" polarity="positive">Speisen</aspect-term> sind lecker und kommen in großen <aspect-term aspect="FOOD" polarity="positive">Portionen</aspect-term>.
# Retry count 1
# Review 78 ---- checked
# Ich bin für den <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Gnocchi</aspect-term>...
# Retry count 1
# Review 79 ---- checked
# Dieser <aspect-term aspect="AMBIENCE" polarity="negative">Ort</aspect-term> ist unglaublich klein..
# Retry count 1
# Review 80 ---- checked
# Die <aspect-term aspect="SERVICE" polarity="negative">Mädchen der Gastgeberin</aspect-term> ist grob bis unangemessen gegenüber.
# Retry count 1
# Review 81 ---- checked
# Die <aspect-term aspect="FOOD" polarity="negative">Nahrung</aspect-term> war matt und fettig..
# Retry count 1
# Retry count 2
# Review 82 ---- checked
# Wir sind hier viele Mal gewesen und haben immer großartiges <aspect-term aspect="FOOD" polarity="positive"> Essen </aspect-term>, <aspect-term aspect="FOOD" polarity="positive"> Wein </aspect-term> und <aspect-term aspect="SERVICE" polarity="positive"> Service </aspect-term> gehabt.
# Retry count 1
# Review 83 ---- checked
# Wir waren besorgt, dass wir Schwierigkeiten haben würde, hereinzukommen, aber irgendwie konnte man einen kurzen <aspect-term aspect="SERVICE" polarity="positive">Warten</aspect-term>-Zeitpunkt haben.
# Retry count 1
# Retry count 2
# Review 84 ---- checked
# Wir hatten immer einen großartigen <aspect-term aspect="FOOD" polarity="positive">Wein</aspect-term>, während wir warteten..
# Retry count 1
# Retry count 2
# Review 85 ---- checked
# Wenn wir saßen, erhielten wir groß und schnell <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term>.
# Retry count 1
# Review 86 ---- checked
# Die <aspect-term aspect="SERVICE" polarity="positive">Personen</aspect-term>, die dort arbeiten, sind immer so freundlich, dass man manchmal vergisst, dass man in New York ist..
# Retry count 1
# Review 87 ---- checked
# Achtest du dich darauf, diesen <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term> so oft wie möglich zu probieren...
# Retry count 1
# Review 88 ---- checked
# Dies ist eine lustige <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Restaurant</aspect-term> zum Besuch...
# Retry count 1
# Review 89 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Pizza</aspect-term> ist lecker und ich mag die <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term>.
# Retry count 1
# Review 90 ---- checked
# Aber das <aspect-term aspect="FOOD" polarity="negative">Pizza</aspect-term> ist zu teuer..
# Retry count 1
# Review 91 ---- checked
# Ich bin dort zum <aspect-term aspect="FOOD" polarity="negative">Frühstück</aspect-term> gegangen und es war nicht so gut wie ich von den Bewertungen erwartet hatte.
# Retry count 1
# Review 92 ---- checked
# <aspect-term aspect="FOOD" polarity="negative">Mürge</aspect-term> war flüssig und die <aspect-term aspect="FOOD" polarity="negative">Leckerei</aspect-term> hatte nicht viel Geschmack..
# Retry count 1
# Retry count 2
# Retry count 3
# Retry count 4
# Retry count 5
# Retry count 6
# Retry count 7
# Retry count 8
# Retry count 9
# Review 93 ---- checked
# Dieser Ort <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">ist</aspect-term> groß..
# Retry count 1
# Review 94 ---- checked
# Die <aspect-term aspect="SERVICE" polarity="positive">Kellnerin</aspect-term> war sehr geduldig mit uns und die <aspect-term aspect="FOOD" polarity="positive">Leckerei</aspect-term> ist phänomenal!
# Retry count 1
# Review 95 ---- checked
# <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> war pünktlich, freundlich und großartig.
# Retry count 1
# Review 96 ---- checked
# Großartige <aspect-term aspect="FOOD" polarity="positive">Pizzä</aspect-term> und fantastische <aspect-term aspect="SERVICE" polarity="positive">Servic</aspect-term>
# Retry count 1
# Review 97 ---- checked
# Es gab einen kleinen <aspect-term aspect="SERVICE" polarity="positive">Wartezeit</aspect-term>, aber kürzer als ich erwartet hatte..
# Retry count 1
# Review 98 ---- checked
# Dies ist das beste <aspect-term aspect="FOOD" polarity="positive">Sushi</aspect-term> in New York City - ohne Widerspruch.
# Retry count 1
# Review 99 ---- checked
# Die <aspect-term aspect="AMBIENCE" polarity="negative">Stelle</aspect-term> ist klein und eng, aber die <aspect-term aspect="FOOD" polarity="positive">Leckerei</aspect-term> ist fantastisch.
# Retry count 1
# Retry count 2
# Retry count 3
# Review 100 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Thunauge des Garis</aspect-term>... Rückgabung nur den übersetzten String.
# Retry count 1
# Review 101 ---- checked
# <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Planet Thailand</aspect-term> hat mich immer wieder gut bewegt , ich gehe dort normalerweise für die <aspect-term aspect="FOOD" polarity="positive">sushi</aspect-term> , was großartig ist , das <aspect-term aspect="FOOD" polarity="positive">thailändische Essen</aspect-term> ist auch top .
# Retry count 1
# Review 102 ---- checked
# Mit der großen Vielfalt auf dem <aspect-term aspect="FOOD" polarity="positive">Menü</aspect-term> , esse ich hier oft und habe nie Langeweile ..
# Retry count 1
# Review 103 ---- checked
# Die <aspect-term aspect="AMBIENCE" polarity="negative">Atmosphäre</aspect-term> ist nicht das größte , aber ich denke , das ist so , wie sie die Preise herunterhalten ..
# Retry count 1
# Review 104 ---- checked
# Es geht alles um das <aspect-term aspect="FOOD" polarity="positive">Essen</aspect-term>.
# Retry count 1
# Review 105 ---- checked
# Es dauerte uns eine lange Zeit, bis wir den <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative"> Ort </aspect-term> gefunden hatten.
# Retry count 1
# Review 106 ---- checked
# Aber wenn wir das <aspect-term aspect="FOOD" polarity="negative">Menü</aspect-term> ansahen, gab es nicht viele Optionen, die meisten davon waren Nudeln im Startgerichtsabschnitt.
# Retry count 1
# Retry count 2
# Review 107 ---- checked
# Diejenigen <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="neutral">Rollen</aspect-term></aspect-term> waren groß, aber nicht gut und <aspect-term aspect="FOOD" polarity="negative">Sashimi</aspect-term> war nicht frisch.
# Retry count 1
# Review 108 ---- checked
# Probieren Sie den <aspect-term aspect="FOOD" polarity="positive">kratzigen Tuna</aspect-term>, es ist zu sterben wert..
# Retry count 1
# Review 109 ---- checked
# Erst ging hier <aspect-term aspect="AMBIENCE" polarity="positive">Garten-Terrasse</aspect-term>, nur zurückkehren.
# Retry count 1
# Review 110 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Leckerei</aspect-term> war beeindruckend, und die <aspect-term aspect="SERVICE" polarity="positive">Dienstleistung</aspect-term> war pünktlich und hilfsbereit, aber nicht übermäßig oder eilehaft.
# Retry count 1
# Review 111 ---- checked
# Der <aspect-term aspect="FOOD" polarity="positive">Steak Tartare</aspect-term> ist ein großartiger Wettkandidat, sie fixieren es für Sie am Tisch.
# Retry count 1
# Review 112 ---- checked
# Ehrlich gesagt waren einige Nächte im <aspect-term aspect="AMBIENCE" polarity="negative">Restaurant</aspect-term> ziemlich warm, aber das <aspect-term aspect="AMBIENCE" polarity="positive">Offene Küche</aspect-term> ist Teil der Vorzüge.
# Retry count 1
# Review 113 ---- checked
# Große <aspect-term aspect="FOOD" polarity="positive">Wein Auswahl</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">Gigondas</aspect-term> ist das Geld wert, und die <aspect-term aspect="FOOD" polarity="positive">Haus Champagner</aspect-term> ist eine gute Value.
# Retry count 1
# Retry count 2
# Retry count 3
# Review 114 ---- checked
# Es kann ein bisschen überfüllt sein am Wochenende, aber die <aspect-term aspect="AMBIENCE" polarity="positive">Vibe</aspect-term> ist gut und es ist das beste <aspect-term aspect="FOOD" polarity="positive">französische Essen</aspect-term> Sie in der Gegend finden werden.
# Retry count 1
# Review 115 ---- checked
# Hat man den <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term> empfohlen, immer eine gute Antwort erhält.
# Retry count 1
# Retry count 2
# Review 116 ---- checked
# Pizza - die einzige <aspect-term aspect="FOOD" polarity="positive">Pizza</aspect-term> in NYC, die keine zusätzlichen Toppings haben sollte - das <aspect-term aspect="FOOD" polarity="positive">Haupt</aspect-term> Geschmack ist wie der beste, frisch gebackene Brot!.
# Retry count 1
# Retry count 2
# Review 117 ---- checked
# Ich nehme alle meine Gäste aus NYC zu <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">VT</aspect-term> zurück.
# Retry count 1
# Review 118 ---- checked
# Ich bin nicht sicher, wo der vorherige Rezensent, lonk, sich gegessen hat, aber Saul befindet sich in einer großartigen <aspect-term aspect="AMBIENCE" polarity="positive">Nachbarschaft</aspect-term> und hat großartiges <aspect-term aspect="FOOD" polarity="positive">Leckeres Essen</aspect-term>!.
# Retry count 1
# Review 119 ---- checked
# Ich würde es sehr empfehlen für eine besondere Gelegenheit – es bietet ein intimes <aspect-term aspect="AMBIENCE" polarity="positive">Umgebung</aspect-term> und nettes <aspect-term aspect="SERVICE" polarity="positive">Dienstleistung</aspect-term>.
# Retry count 1
# Review 120 ---- checked
# Ich bin mir nicht sicher, wo die anderen Rezensionen gegessen haben, aber es scheint, als hätten wir zwei verschiedene Restaurants besucht, denn meine Freunde und ich lieben <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Mizu</aspect-term> sehr, sehr gern ...und wir sind wiederholt Kunden.
# Retry count 1
# Review 121 ---- checked
# Stelle sicher, dass du die <aspect-term aspect="FOOD" polarity="positive">Spicy Scallop Roll</aspect-term>... ... Rückgabenummer nur.
# Retry count 1
# Review 122 ---- checked
# <aspect-term aspect="FOOD" polarity="positive">Moules</aspect-term> waren großartig, <aspect-term aspect="FOOD" polarity="negative">Lobster Ravioli</aspect-term> war extrem salzig!
# Retry count 1
# Review 123 ---- checked
# Ich habe meine Mama für Muttertag genommen und der <aspect-term aspect="SERVICE" polarity="negative">Maitre d' </aspect-term> war ziemlich lächerlich.
# Retry count 1
# Retry count 2
# Retry count 3
# Review 124 ---- checked
# Tiny <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative">Schlüsselgericht</aspect-term></aspect-term></aspect-term> kostet 8,00 €... ist für mich einfach überpreisst für das, was es ist.
# Retry count 1
# Review 125 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Getränke</aspect-term> sind immer gut gemacht und der <aspect-term aspect="FOOD" polarity="positive">Wein Auswahl</aspect-term> ist günstig.
# Retry count 1
# Retry count 2
# Review 126 ---- checked
# Versuchen Sie <aspect-term aspect="FOOD" polarity="positive">Chef-Spezialitäten</aspect-term> -- sie sind zu sterben wert.
# Retry count 1
# Review 127 ---- checked
# <aspect-term aspect="SERVICE" polarity="neutral">Dienst</aspect-term> ist nicht genau fünf Sterne, aber das ist für mich kein großes Problem..
# Retry count 1
# Retry count 2
# Review 128 ---- checked
# <aspect-term aspect="AMBIENCE" polarity="positive">Kellerraum</aspect-term> ist immer eine gute Anziehung.
# Retry count 1
# Review 129 ---- checked
# <aspect-term aspect="AMBIENCE" polarity="positive">Rägas</aspect-term> ist eine romantische, gemütliche Küche.
# Retry count 1
# Retry count 2
# Review 130 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">exotische<aspect-term aspect="FOOD" polarity="positive"> Lebensmittel- </aspect-term>Kombinationen</aspect-term> sind hervorragend präsentiert und eine Freude in leckeren Kombinationen.
# Retry count 1
# Review 131 ---- checked
# Der <aspect-term aspect="SERVICE" polarity="positive">Stab</aspect-term> ist unglaublich hilfsbereit und aufmerksam.
# Retry count 1
# Review 132 ---- checked
# Der <aspect-term aspect="FOOD" polarity="positive">Balkontisch</aspect-term> ist sehr gut mit interessanten <aspect-term aspect="FOOD" polarity="positive">Biern</aspect-term> und gut preisgünstigen <aspect-term aspect="FOOD" polarity="positive">Weinen</aspect-term> ausgestattet..
# Retry count 1
# Review 133 ---- checked
# Als wir auf <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">Leon</aspect-term> stürzten, dachten wir, dass wir ein wunderschönes Schatz gefunden hätten, aber wir waren ohne Zweifel falsch.
# Retry count 1
# Review 134 ---- checked
# Die <aspect-term aspect="SERVICE" polarity="negative">Waiterin</aspect-term> hat unsere Tischstelle fast in die Toilette bewegt und als wir um Stornierung unseres Abendessens gebeten haben, weil wir nicht essen wollten, wie auf dem Toilettensitz zu sitzen, bekamen wir die Antwort "nein"...
# Retry count 1
# Review 135 ---- checked
# Rüde <aspect-term aspect="SERVICE" polarity="negative">Service</aspect-term>, mediokre <aspect-term aspect="FOOD" polarity="neutral">Leistung</aspect-term>...Es gibt eine Menge Restaurants in NY...bleib damit ab...
# Retry count 1
# Review 136 ---- checked
# Ich hatte einen großartigen Zeit bei <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Jekyll und Hyde</aspect-term>.
# Retry count 1
# Review 137 ---- checked
# Ich liebte alles daran - insbesondere die <aspect-term aspect="AMBIENCE" polarity="positive">Shows</aspect-term> und <aspect-term aspect="AMBIENCE" polarity="positive">Akteure</aspect-term>.
# Retry count 1
# Review 138 ---- checked
# Unser <aspect-term aspect="SERVICE" polarity="positive">Server</aspect-term> war sehr hilfreich und freundlich.
# Retry count 1
# Review 139 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Leckerei</aspect-term> war auch gut..
# Retry count 1
# Review 140 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Thun</aspect-term> und <aspect-term aspect="FOOD" polarity="positive">Wasabie Kartoffeln</aspect-term> sind ausgezeichnet..
# Retry count 1
# Review 141 ---- checked
# Die <aspect-term aspect="AMBIENCE" polarity="positive">außere Atmosphäre</aspect-term> von Sitzen auf der Gehwegwand, die die Welt passieren sehen, 50 Fuß weit entfernt auf der 6. Avenue am kühlen Abend war wunderbar..
# Retry count 1
# Review 142 ---- checked
# <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> war sofortig und höflich..
# Retry count 1
# Retry count 2
# Review 143 ---- checked
# Sehr gut <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term>, sehr gut <aspect-term aspect="FOOD" polarity="positive">Lebensmittel</aspect-term>.
# Retry count 1
# Review 144 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Pizza</aspect-term> ist lecker - sie verwenden <aspect-term aspect="FOOD" polarity="positive">frisches Mozzarella</aspect-term> stattdessen von dem billigen, gefrorenen, gerieben Käse, den die meisten Pizzerias teilen.
# Retry count 1
# Review 145 ---- checked
# Zwei Beschwerden - ihr <aspect-term aspect="FOOD" polarity="negative">Aussagewahl</aspect-term> stinkt, es wäre schön, wenn manche Mozzarella-Sticks auf die Speisekarte setzen würde..
# Retry count 1
# Review 146 ---- checked
# <aspect-term aspect="SERVICE" polarity="negative">Wartungspersonal</aspect-term> ist offensichtlich unappreciervoll gegenüber Ihrem Geschäft, aber es ist das beste <aspect-term aspect="FOOD" polarity="positive">Torte</aspect-term> auf dem UWS!
# Retry count 1
# Review 147 ---- checked
# Durchschnittlich das beste <aspect-term aspect="FOOD" polarity="positive">Salat</aspect-term>, das ich in einem Fast-Food-Restaurant bekommen habe..
# Retry count 1
# Retry count 2
# Review 148 ---- checked
# Feine <aspect-term aspect="FOOD" polarity="positive"> kulinarische </aspect-term> Restaurantqualität
# Retry count 1
# Review 149 ---- checked
# Am aktuellen Sonntag Nachmittag stießen wir zufällig auf einen großartigen <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Restaurant</aspect-term> auf unserem Weg zum Pulitzer-Preis gewonnenen Theaterstück DOUBT.
# Retry count 1
# Review 150 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Hähnchen-Pfannkuchen-</aspect-term> ist ausgenommen, die <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Käseburger</aspect-term></aspect-term> sind riesig und lecker, und der <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> ist professionell und warm..
# Retry count 1
# Review 151 ---- checked
# Die <aspect-term aspect="SERVICE" polarity="positive">Stoß</aspect-term> hat keine Nerven.
# Retry count 1
# Review 152 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Nahrungsoptionen</aspect-term> regeln..
# Retry count 1
# Review 153 ---- checked
# Wenn ich im Uppercase für eine Weile lebte, würde ich die<aspect-term aspect="FOOD" polarity="positive">Bagel-Bäckerei</aspect-term>kauft und sie würden immer noch besser sein als jeder andere.
# Retry count 1
# Review 154 ---- checked
# Worth visiting den <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">1. Ave Spot</aspect-term> weil es der Originalladen ist.
# Retry count 1
# Retry count 2
# Review 155 ---- checked
# Er brachte mir eine <aspect-term aspect="FOOD" polarity="positive"> Uni-Handroll </aspect-term>, die ich noch nie hatte, und lass mich dir sagen... ES WAR HIMMEL!
# Retry count 1
# Review 156 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Sake-Menüliste</aspect-term> sollte nicht übersehen werden!
# Retry count 1
# Review 157 ---- checked
# Versuchen Sie den <aspect-term aspect="FOOD" polarity="positive">Lobster Teriyaki</aspect-term> und den <aspect-term aspect="FOOD" polarity="positive">Rosenspezialroll</aspect-term>.
# Retry count 1
# Review 158 ---- checked
# <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> war sehr gut - pünktlich, aufmerksam und nicht störend.
# Retry count 1
# Review 159 ---- checked
# <aspect-term aspect="FOOD" polarity="positive">Leckere Lebensmittel</aspect-term> waren auch sehr gut, wenn man bedenkt, dass wir die Preise- Auswahl ausprobieren wollten (obwohl ich das <aspect-term aspect="FOOD" polarity="negative">Schweinebrust</aspect-term>, das ich bestellt hatte, ein bisschen länger gebraten gewesen wäre, so dass das Fett eine angenehmere MELT-in-dein-Mund-Erfahrung abgeben würde)..
# Retry count 1
# Review 160 ---- checked
# <aspect-term aspect="FOOD" polarity="positive">Weinlistenauswahl</aspect-term> ist gut und <aspect-term aspect="FOOD" polarity="positive">Wein-zu-Koppelpreis</aspect-term> wurde reichlich bis zum Rand gefüllt..
# Retry count 1
# Review 161 ---- checked
# <aspect-term aspect="AMBIENCE" polarity="positive">Traditioneller französischer Dekor</aspect-term> war angenehm, obwohl der <aspect-term aspect="AMBIENCE" polarity="negative">Halle</aspect-term> ziemlich laut war - das Restaurant war voll und wir mussten unsere Stimmen erhöhen, um eine Konversation halten zu können..
# Retry count 1
# Review 162 ---- checked
# Ich bin wahrscheinlich zum <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Kafé Spice</aspect-term> ungefähr 5-8 Mal gewesen und es ist wahrscheinlich immer noch das beste indische Restaurant um Union Square.
# Retry count 1
# Review 163 ---- checked
# Um es zusammenzufassen: <aspect-term aspect="SERVICE" polarity="neutral">Der Service</aspect-term> variiert von gut bis mittelmäßig, je nachdem welchen Waiter man bekommt; allgemein ist er nur durchschnittlich OK..
# Retry count 1
# Review 164 ---- checked
# <aspect-term aspect="SERVICE" polarity="positive">Sitzgelegenheit</aspect-term> ist immer pünktlich, obwohl das Restaurant am Abend voll wird.
# Retry count 1
# Review 165 ---- checked
# <aspect-term aspect="FOOD" polarity="positive">Lebensmittel</aspect-term> ist normalerweise sehr gut, obwohl ich manchmal über die Frischheit von <aspect-term aspect="FOOD" polarity="negative">roher Gemüse in den Beilagen</aspect-term> nachgedacht habe.
# Retry count 1
# Review 166 ---- checked
# Die <aspect-term aspect="AMBIENCE" polarity="positive">Zierde</aspect-term> ist lebendig und sehenswert mit mehreren <aspect-term aspect="AMBIENCE" polarity="positive">halbprivaten Börsen</aspect-term> auf der rechten Seite des Esszimmers, die großartig für eine Dating-Gelegenheit sind..
# Retry count 1
# Review 167 ---- checked
# Ich habe NICHT im <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Roten Auge</aspect-term> enttäuscht worden.
# Retry count 1
# Review 168 ---- checked
# Die erste Zeit, in der ich war, und vollkommen von dem <aspect-term aspect="AMBIENCE" polarity="positive">Live Jazzband</aspect-term> und <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term> beeinflusst wurde, bestellte ich die Lachs-Cobb-Salat..
# Retry count 1
# Review 169 ---- checked
# Es ist einfach das beste <aspect-term aspect="FOOD" polarity="positive">essen</aspect-term> in NYC..
# Retry count 1
# Review 170 ---- checked
# Sie können sich nicht irren im <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Red Eye Grill</aspect-term>.
# Retry count 1
# Review 171 ---- checked
# Wenn wir uns von der Upper East Side bewegen würden, würden wir die <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Restaurant</aspect-term> unglaublich vermissen.
# Retry count 1
# Review 172 ---- checked
# Der <aspect-term aspect="GENERAL-IMPRESSION" polarity="neutral">Restaurant</aspect-term> ist süß, aber nicht höflich.
# Retry count 1
# Review 173 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Nahrung</aspect-term> ist ein Diamant im Rost – die Nahrung ist lecker und zu Hause zubereitet mit dem perfekten <aspect-term aspect="FOOD" polarity="positive">Gleichgewicht von Kräutern und Tomaten</aspect-term>.
# Retry count 1
# Review 174 ---- checked
# Wir hatten eine großartige Zeit im <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Jekyll und Hyde Pub</aspect-term> gestern Nacht.
# Retry count 1
# Review 175 ---- checked
# Nachdem wir uns wirklich gut am <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Bar</aspect-term> amüsiert hatten, setzten wir uns an einen Tisch und hatten Abendessen.
# Retry count 1
# Review 176 ---- checked
# Der <aspect-term aspect="SERVICE" polarity="positive">Server</aspect-term> war wirklich kühn und brachte uns unser Essen und Getränke mit einem Lächeln.
# Retry count 1
# Review 177 ---- checked
# Der Ort<aspect-term aspect="AMBIENCE" polarity="positive">'s </aspect-term>Zur Dekoration und <aspect-term aspect="AMBIENCE" polarity="positive">versteckten Badezimmern</aspect-term> führte zu einem guten Lachen.
# Retry count 1
# Review 178 ---- checked
# Ich empfehle stark, dieses <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Restaurant</aspect-term> zu besuchen und Abendessen und Getränke zu genießen!
# Retry count 1
# Retry count 2
# Review 179 ---- checked
# Wenn du die Art von Mensch bist, der sich Sorgen macht und unterhalten möchte, ist dies eine großartige <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term> zum Besuch und zu essen.
# Retry count 1
# Review 180 ---- checked
# Mein Mann und ich dachten, es würde großartig sein, zum <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Jekyll and Hyde Pub</aspect-term> zu gehen, um unser Jahrestag zu feiern, und unsere Überraschung war es, dass es fantastisch war..
# Retry count 1
# Retry count 2
# Review 181 ---- checked
# Die haben über 100 verschiedene <aspect-term aspect="FOOD" polarity="positive">Biersorten</aspect-term> zu bieten, um ihre Gäste zu begrüßen, sodass es meinem Mann sehr glücklich machte und das <aspect-term aspect="FOOD" polarity="positive">Futter</aspect-term> war lecker, wenn ich eine Empfehlung geben muss, so muss es die <aspect-term aspect="FOOD" polarity="positive">Pumpkin Tortellini</aspect-term> sein.
# Retry count 1
# Review 182 ---- checked
# Die <aspect-term aspect="AMBIENCE" polarity="positive">Unterhaltung</aspect-term> war groß sie haben Shows, die ganze Zeit während des Essens laufen.
# Retry count 1
# Review 183 ---- checked
# Bitte nehme meine Empfehlung an, gehe und probiere diesen <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term>.
# Retry count 1
# Review 184 ---- checked
# Der <aspect-term aspect="FOOD" polarity="positive">Bagel</aspect-term> war riesig.
# Retry count 1
# Review 185 ---- checked
# Die Arbeiter dort laden die <aspect-term aspect="FOOD" polarity="negative">Tasche</aspect-term> auch absolute mit Käsecreme voll (kriegt ein wenig knitterig). Rückgabe nur der übersetzte String.
# Retry count 1
# Retry count 2
# Review 186 ---- checked
# Dies war mein erstes Mal im Cafe St. Barts und ich muss sagen, wie lecker das <aspect-term aspect="FOOD" polarity="positive"> Essen </aspect-term> und die <aspect-term aspect="SERVICE" polarity="positive"> Bedienung </aspect-term> war.
# Retry count 1
# Review 187 ---- checked
# Ich muss sehr empfehlen den <aspect-term aspect="FOOD" polarity="positive">Lobster Roll</aspect-term> - nicht zu viel Mayo; Sie können erzählen, dass es ein frischer <aspect-term aspect="FOOD" polarity="positive">Lobster</aspect-term> war.
# Retry count 1
# Review 188 ---- checked
# Andere Gäste genossen <aspect-term aspect="FOOD" polarity="positive">Pizze</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">Santa Fe Chopped Salad</aspect-term> und <aspect-term aspect="FOOD" polarity="positive">Fisch & Chips</aspect-term>.
# Retry count 1
# Review 189 ---- checked
# Ich empfehle sehr stark Café St. Bart's für ihre <aspect-term aspect="FOOD" polarity="positive">Leckereien</aspect-term>, die <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term> und wunderbare <aspect-term aspect="SERVICE" polarity="positive">Bedienung</aspect-term>.
# Retry count 1
# Review 190 ---- checked
# Alle <aspect-term aspect="SERVICE" polarity="positive">Personal</aspect-term> sind absolut professionell!!
# Retry count 1
# Review 191 ---- checked
# Dieser <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">Restaurant</aspect-term> war weit überhypesiert..
# Retry count 1
# Retry count 2
# Retry count 3
# Retry count 4
# Retry count 5
# Retry count 6
# Retry count 7
# Retry count 8
# Retry count 9
# Retry count 10
# Meine Chow Fun und Chow See war wirklich einschmeckend und eitel..
# Retry count 1
# Review 193 ---- checked
# Die <aspect-term aspect="FOOD" polarity="neutral">Zwiebelpfannkuchen</aspect-term> und <aspect-term aspect="FOOD" polarity="neutral">geschnittene Maultaschen</aspect-term> waren nichts Außergewöhnliches.
# Retry count 1
# Review 194 ---- checked
# Der <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> war die einzige gute Sache über diesem <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">Restaurant</aspect-term>.
# Retry count 1
# Review 195 ---- checked
# Es ist langweilig im Innern und unsere <aspect-term aspect="FOOD" polarity="negative">Sushi</aspect-term> war ziemlich unterdurchschnittlich... der <aspect-term aspect="FOOD" polarity="negative">Tuna</aspect-term> war nass und die anderen <aspect-term aspect="FOOD" polarity="negative">Rollen</aspect-term> hatten keinen Geschmack.
# Retry count 1
# Review 196 ---- checked
# Ihr <aspect-term aspect="FOOD" polarity="positive">Pensil Penang</aspect-term> ist lecker und alles andere ist phantastisch..
# Retry count 1
# Review 197 ---- checked
# Der Preis ist vernünftig, obwohl der <aspect-term aspect="SERVICE" polarity="negative">Service</aspect-term> schlecht ist.
# Retry count 1
# Review 198 ---- checked
# <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Leckeres Restaurant</aspect-term> war unglaublich....... <aspect-term aspect="FOOD" polarity="positive">Food</aspect-term> war lecker und natürlich frisch..
# Retry count 1
# Review 199 ---- checked
# Hats off zum <aspect-term aspect="FOOD" polarity="positive">Chef</aspect-term>.
# Retry count 1
# Review 200 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Salate</aspect-term> sind lecker, sowohl erfrischend als auch sehr scharf..
# Retry count 1
# Review 201 ---- checked
# Wir hatten <aspect-term aspect="FOOD" polarity="positive">Pams spezielles gebratenes Fisch</aspect-term> und es war unglaublich.
# Retry count 1
# Review 202 ---- checked
# Große <aspect-term aspect="AMBIENCE" polarity="positive">Vibe</aspect-term>, viele Menschen.
# Retry count 1
# Review 203 ---- checked
# Ich habe nicht geklagt, ich mochte die <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term> so sehr...
# Retry count 1
# Review 204 ---- checked
# <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term> ist so süß und charmant, gut für das Geschäft, obwohl wir dort auf Urlaub waren.
# Retry count 1
# Retry count 2
# Review 205 ---- checked
# <aspect-term aspect="FOOD" polarity="positive">Salate</aspect-term> waren fantastisch.
# Retry count 1
# Review 206 ---- checked
# Obwohl wir nach normaler Salat und ein paar Walnüsse gesucht haben, die <aspect-term aspect="FOOD" polarity="positive">Salate</aspect-term>, die wir erhielten, waren großartig.
# Retry count 1
# Retry count 2
# Retry count 3
# Review 207 ---- checked
# <aspect-term aspect="FOOD" polarity="positive">Zutaten</aspect-term> sind biologisch, das ist ein echter Plus für mich.
# Retry count 1
# Retry count 2
# Retry count 3
# Retry count 4
# Retry count 5
# Retry count 6
# Retry count 7
# Retry count 8
# Review 208 ---- checked
# Dies sind einige <aspect-term aspect="FOOD" polarity="positive">gute<aspect-term aspect="FOOD" polarity="positive"> sehr gute, günstige </aspect-term>Sushi</aspect-term>.
# Retry count 1
# Retry count 2
# Review 209 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">schüsselige Tuna-Rolle</aspect-term></aspect-term></aspect-term> ist riesig und wahrscheinlich das beste, was ich bisher bei diesem Preisbereich hatte.
# Retry count 1
# Review 210 ---- checked
# ...
# Retry count 1
# Review 772 ---- checked
# Der <aspect-term aspect="SERVICE" polarity="positive">Eigentümer</aspect-term> trifft wirklich alle Ihre Bedürfnisse..
# Retry count 1
# Review 773 ---- checked
# Gute <aspect-term aspect="FOOD" polarity="positive">Nahrung</aspect-term> und die Preise sind sehr vernünftig.
# Retry count 1
# Review 774 ---- checked
# Das <aspect-term aspect="FOOD" polarity="positive">Nahrung hier</aspect-term> tut großartigen Dienst für den Namen (Cantonese ist das...)..
# Retry count 1
# Retry count 2
# Retry count 3
# Review 775 ---- checked
# Ich fiel in den Hafen für die <aspect-term aspect="FOOD" polarity="positive">Ei-Nudeln im Rindbratenbrühe mit Garnelen-Gurmeln und Slices von BBQ-Roast-Pork</aspect-term>.
# Retry count 1
# Review 776 ---- checked
# Dieses <aspect-term aspect="FOOD" polarity="positive">Gericht</aspect-term> ist mein Lieblingsgericht und ich bekomme es immer, wenn ich dorthin gehe und nie müde davon werde.
# Retry count 1
# Retry count 2
# Retry count 3
# Review 777 ---- checked
# Versuche das <aspect-term aspect="FOOD" polarity="positive">Congee</aspect-term> und das Donut wie <aspect-term aspect="FOOD" polarity="positive">Ow Ley Soh</aspect-term>, ein leckeres und süßes Geschmackserlebnis.
# Retry count 1
# Retry count 2
# Retry count 3
# Retry count 4
# Retry count 5
# Retry count 6
# Retry count 7
# Retry count 8
# Review 778 ---- checked
# Einfach einige leckere <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">chinesische Küche</aspect-term></aspect-term> zu unvergleichlichen Preisen....
# Retry count 1
# Review 779 ---- checked
# <aspect-term aspect="SERVICE" polarity="negative">Dienst</aspect-term> ist nicht, was Sie hier für... Rückkehren nur dann, wenn...
# Retry count 1
# Review 780 ---- checked
# <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Groß Wong</aspect-term> ist ein großartiges Restaurant, wo man sich satt essen kann..
# Retry count 1
# Review 781 ---- checked
# Wer immer der <aspect-term aspect="AMBIENCE" polarity="positive">Jazz-Duo</aspect-term> war, waren sie auf Punkt..
# Retry count 1
# Review 782 ---- checked
# Gute <aspect-term aspect="AMBIENCE" polarity="positive">Musik</aspect-term>, großartiges <aspect-term aspect="FOOD" polarity="positive"> Essen </aspect-term>, schnelle <aspect-term aspect="SERVICE" polarity="positive">Dienstleistung </aspect-term> günstige Preise
# Retry count 1
# Review 783 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Wein aus dem Glas</aspect-term> war auch gut..
# Retry count 1
# Review 784 ---- checked
# Beständig gut <aspect-term aspect="FOOD" polarity="positive"> japanische Tapas </aspect-term>..
# Retry count 1
# Review 785 ---- checked
# Bis jetzt gute <aspect-term aspect="FOOD" polarity="positive">Trinken</aspect-term> und <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term> ist ziemlich gut.
# Retry count 1
# Retry count 2
# Review 786 ---- checked
# <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term> ist angenehm und entspannt auch....
# Retry count 1
# Review 787 ---- checked
# Ein großes <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term>, um sich zu treffen und ein paar Getränke und Essen...
# Retry count 1
# Retry count 2
# Review 788 ---- checked
# <aspect-term aspect="FOOD" polarity="positive">Yakitori (Grill Fleisch)</aspect-term> ist lecker auch..
# Retry count 1
# Review 789 ---- checked
# Wenn Sie sich nicht schlagen um das vorschnitzelte, niedrige Qualität <aspect-term aspect="FOOD" polarity="negative">Fisch</aspect-term>, unfreundlich <aspect-term aspect="SERVICE" polarity="negative">Personal</aspect-term> und einen <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">Sushi Chef</aspect-term>, der wie er ist, sehr unglücklich zu sehen scheint dann ist dieses hier Ihr Ort. Rückernten Sie nur die von hier.
# Retry count 1
# Review 790 ---- checked
# Preis und Qualität von <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative">Fisch</aspect-term></aspect-term> allein werden uns davon abhalten, eine Rückbesuchsvisite zu machen.
# Retry count 1
# Review 791 ---- checked
# Es war nicht vorhaben, es zu teilen, aber ich fühle mich verpflichtet...während wir am Sushi-Bar saßen und aß, haben wir den <aspect-term aspect="FOOD" polarity="negative">Koch</aspect-term> zufällig im Esszimmer fallen lassen, als er ein Stück Unagi vom Boden aufnahm und dann in das Lieferbestellungsordner einbezielte.
# Retry count 1
# Review 792 ---- checked
# Dieses <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term>, der nur wenige Monate alt ist, ist vielleicht Queens größter Geheimnis!
# Retry count 1
# Retry count 2
# Retry count 3
# Retry count 4
# Retry count 5
# Retry count 6
# Retry count 7
# Retry count 8
# Review 793 ---- checked
# Fabulös <aspect-term aspect="AMBIENCE" polarity="positive"> Deko </aspect-term> - macht dich auf die Tatsache hin, als ob du in einem trendsichem Manhattan-Restaurant bist, sehr sehr gut <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive"> Essen </aspect-term></aspect-term>, billigpreisig, allgemein freundlich <aspect-term aspect="SERVICE" polarity="positive">Personal</aspect-term>, und wenn du ein New Yorker bist oder den ganzen Tag in Manhattan verbringst, <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive"><aspect-term aspect="AMBIENCE" polarity="positive"><aspect-term aspect="AMBIENCE" polarity="positive">Rice Avenue</aspect-term></aspect-term></aspect-term> wird dich wie zu Hause fühlen......sehr Soho/Village/Upper West Side minus der teuren Preise und dem arroganten Publikum.....all auf Roosevelt Avenue!.
# Retry count 1
# Review 794 ---- checked
# Wir wurden außerhalb gesetzt und der <aspect-term aspect="SERVICE" polarity="negative">Warter</aspect-term> spritzte roten Wein und heißen Tee auf mich und meine Date.
# Retry count 1
# Review 795 ---- checked
# Einem würde man denken, wir würden eine Entschuldigung oder einen kostenlosen Drink bekommen - stattdessen bekamen wir einen spöttischen <aspect-term aspect="SERVICE" polarity="negative">Wartenden</aspect-term>, der uns nicht einmal unser Essen bestellen ließ für 15 Minuten und gab uns Lippenbecken, wenn wir ihn bitten wollten.
# Retry count 1
# Review 796 ---- checked
# Mit so vielen guten Restaurants auf dem UWS brauche ich keine überpreisste <aspect-term aspect="FOOD" polarity="negative">Gastronomie</aspect-term>, absurde, arrogant <aspect-term aspect="SERVICE" polarity="negative">Bedienung</aspect-term>, die nicht erkennen, dass sie an einem glorifizierten Diner arbeiten, unhöfliche <aspect-term aspect="SERVICE" polarity="negative">Dienstleistungen</aspect-term> und eine <aspect-term aspect="SERVICE" polarity="negative">Verwaltung</aspect-term>, die es nicht zu schätzen weiß.
# Retry count 1
# Review 797 ---- checked
# Ich bin relativ neu im Gebiet und habe ein Pick abgegeben auf der 2. Ecke und war enttäuscht mit dem <aspect-term aspect="SERVICE" polarity="negative">Service</aspect-term> und dachte, das <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative">Food</aspect-term></aspect-term> sei überhöht und auf der teursten Seite..
# Retry count 1
# Review 798 ---- checked
# Die <aspect-term aspect="FOOD" polarity="neutral">Leckerei</aspect-term> ist okay und die Preise hier sind mittelmäßig..
# Retry count 1
# Review 799 ---- checked
# <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Bukharis</aspect-term> hat feste <aspect-term aspect="FOOD" polarity="positive">Leckerei</aspect-term> und eine schöne <aspect-term aspect="AMBIENCE" polarity="positive">Zutat</aspect-term> zu vernünftigen Preisen..
# Retry count 1
# Review 800 ---- checked
# Der einzige Problem ist, dass der <aspect-term aspect="SERVICE" polarity="negative">Manager</aspect-term> ein vollkommener Inkompetent ist.
# Retry count 1
# Review 801 ---- checked
# Er bietet schlassig <aspect-term aspect="SERVICE" polarity="negative">Service</aspect-term> und hat keine Persönlichkeit.
# Retry count 1
# Review 802 ---- checked
# Es gibt keine Entschuldigung für solche schlechte <aspect-term aspect="SERVICE" polarity="negative">Dienst</aspect-term>!
# Retry count 1
# Review 803 ---- checked
# Ich habe nie zuvor 40 Stücke von relativ gutes <aspect-term aspect="FOOD" polarity="neutral">Nigiri</aspect-term> gegessen.
# Retry count 1
# Review 804 ---- checked
# $20 für <aspect-term aspect="FOOD" polarity="positive">alleyoucaneatsushi</aspect-term> kann nicht besiegt werden..
# Retry count 1
# Review 805 ---- checked
# Ich ging am Sonntagvormittag zum <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Areo</aspect-term> mit vier meiner Freundinnen und verbrachte drei angenehme Stunden dort.
# Retry count 1
# Retry count 2
# Review 806 ---- checked
# Die meisten der <aspect-term aspect="SERVICE" polarity="positive">Server</aspect-term> sind sehr aufmerksam, freundlich und ziemlich attraktiv.
# Retry count 1
# Review 807 ---- checked
# Die <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term> ist sehr entspannt und gemütlich, <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> war großartig und die <aspect-term aspect="FOOD" polarity="positive">Leistung</aspect-term> war herausragend!
# Retry count 1
# Review 808 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Leckerei</aspect-term> war gut und die <aspect-term aspect="AMBIENCE" polarity="positive">Ansicht der neuen New York City Linie</aspect-term> war super auch auf einem nebligen regnerischen Tag wie den ich war..
# Retry count 1
# Review 809 ---- checked
# Ich würde sehr empfehlen, ein <aspect-term aspect="AMBIENCE" polarity="positive">Tisch</aspect-term> am Fenster zu bitten..
# Retry count 1
# Retry count 2
# Retry count 3
# Review 810 ---- checked
# Obwohl sie das typische, welches Art von Wasser Sie mögen Fragen stellen, <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> war gut und insgesamt sehr entspannend zum <aspect-term aspect="AMBIENCE" polarity="positive">Ort</aspect-term> zum Essen..
# Retry count 1
# Review 811 ---- checked
# Der <aspect-term aspect="FOOD" polarity="positive">Speise</aspect-term> ist großartig.
# Retry count 1
# Review 812 ---- checked
# <aspect-term aspect="FOOD" polarity="positive">Persönliche Pfannen</aspect-term> sind die perfekte Größe für solche hungrigen Abende.
# Retry count 1
# Review 813 ---- checked
# Es gibt einen Nachteil, wenn du bestellst - die <aspect-term aspect="SERVICE" polarity="negative">Lieferfahrer</aspect-term> haben eine MAJOR Attitüde..
# Retry count 1
# Review 814 ---- checked
# Ich habe solche dramatische Lieferanten noch nie gehabt <aspect-term aspect="SERVICE" polarity="negative"> (keine Sorge, es ist einfach so, dass ich im Stockwerk wohne, die Leute sind immer enttäuscht von ihren Tipps)</aspect-term>
# Retry count 1
# Review 815 ---- checked
# Liebe die <aspect-term aspect="AMBIENCE" polarity="positive"> Szene </aspect-term> zuerst - der <aspect-term aspect="AMBIENCE" polarity="positive"> Ort </aspect-term> hat eine Charakter und ein schönes Licht zu ihm.. sehr glücklich, <aspect-term aspect="AMBIENCE" polarity="positive"> Lage </aspect-term> Weis.
# Retry count 1
# Retry count 2
# Retry count 3
# Retry count 4
# Review 816 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Pizze</aspect-term></aspect-term> war ziemlich gut und riesig.
# Retry count 1
# Review 817 ---- checked
# Wir waren 4 und kamen zur Familie-Größe <aspect-term aspect="FOOD" polarity="positive">Penne à la Vodka</aspect-term>, das war unglaublich riesige Portion ... ein Korb mit Essen wirklich
# Retry count 1
# Review 818 ---- checked
# Die <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative">pasta penne</aspect-term></aspect-term> war ziemlich extraButterig cremig, was bedeutet ein großer Aufwand zum Verdauen. Geschmacklich erst aber ich würde sagen, dass ich nach einer Scheibe Pizza und sieben Stücken, penne...ein bisschen launisch wurde, da vollgestopft war...lol.
# Retry count 1
# Review 819 ---- checked
# <aspect-term aspect="FOOD" polarity="positive">Rosabella waltzt herein, und ich denke, sie tun es am besten.</aspect-term>
# Retry count 1
# Retry count 2
# Review 820 ---- checked
# Faszinierende <aspect-term aspect="FOOD" polarity="positive"> Auswahl </aspect-term>, gute <aspect-term aspect="FOOD" polarity="positive"> Weine </aspect-term>, <aspect-term aspect="SERVICE" polarity="positive"> Service </aspect-term> fein, lustige <aspect-term aspect="AMBIENCE" polarity="positive"> Dekoration </aspect-term>.
# Retry count 1
# Review 821 ---- checked
# Ich fand es auf einer kalten Nacht, dem perfekten <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Spot</aspect-term> zum Wärmen.
# Retry count 1
# Review 822 ---- checked
# Ich erhielt einen <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term> mit einem Lächeln.
# Retry count 1
# Retry count 2
# Retry count 3
# Retry count 4
# Retry count 5
# Retry count 6
# Retry count 7
# Review 823 ---- checked
# Dieser Ort <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">bließ mich </aspect-term>herbei....durch weit entfernt ist es von meinem neuen Lieblingsrestaurant auf der Oberschweizer Seite.
# Retry count 1
# Review 824 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Weinliste</aspect-term> ist umfangreich und beeindruckend.
# Retry count 1
# Retry count 2
# Retry count 3
# Retry count 4
# Retry count 5
# Retry count 6
# Review 825 ---- checked
# LIEBE die <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term> - fühlte sich so an wie ich in Paris war..
# Retry count 1
# Review 826 ---- checked
# Die <aspect-term aspect="FOOD" polarity="positive">Muscheln</aspect-term> waren großartig und auch das <aspect-term aspect="FOOD" polarity="positive">Dessert</aspect-term>...definitiv werde ich wieder sehr bald zurückkehren..
# Retry count 1
# Review 827 ---- checked
# Ich bin hier schon Jahre lang gewesen und habe nichts als gute Dinge zu sagen über den <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> und das großartige <aspect-term aspect="SERVICE" polarity="positive">Personal</aspect-term> bei La Lanterna.
# Retry count 1
# Review 828 ---- checked
# Die Jahre haben Vittorio, den <aspect-term aspect="SERVICE" polarity="positive">Veranstaltern</aspect-term>, und seine <aspect-term aspect="SERVICE" polarity="positive">Mannschaft</aspect-term> immer mich als Familie behandelt -- obwohl mit all der Geschäftigkeit, die dieses nicht so kleine Juwel macht, ist es wirklich beeindruckend, dass er überhaupt noch auf einen einheitlichen, aber nicht zu häufigen Besucher hinweist..
# Retry count 1
# Review 829 ---- checked
# Ich habe auch großartig überrascht an allen neuen Zugängen im letzten Jahrzehnt: Eine neue <aspect-term aspect="AMBIENCE" polarity="positive">Jazz Bar</aspect-term>, die fantastischste <aspect-term aspect="AMBIENCE" polarity="positive">Garten zum Essen</aspect-term>, die besten <aspect-term aspect="FOOD" polarity="positive">Dünner Teigtaschentorte</aspect-term> und jetzt ein <aspect-term aspect="FOOD" polarity="positive">Lasagna-Menü</aspect-term> das zum Sterben ist (diese sind nicht wie andere Lasagnas)!.
# Retry count 1
# Review 830 ---- checked
# Ich Liebe DAS <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">PLATZ</aspect-term>.
# Retry count 1
# Retry count 2
# Review 831 ---- checked
# Ich muss sagen, ich habe noch nie eine enttäuschende <aspect-term aspect="FOOD" polarity="positive"> Mahlzeit </aspect-term> hier gehabt.
# Retry count 1
# Review 832 ---- checked
# Wir könnten uns ein Mahl aus den leckeren <aspect-term aspect="FOOD" polarity="positive">Dumplings</aspect-term> vom Dumplingsmenü gemacht haben.
# Retry count 1
# Review 833 ---- checked
# Glücklich haben wir Raum für den <aspect-term aspect="FOOD" polarity="positive">BBQ Hühnchen</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">Meeresbarsch</aspect-term> und <aspect-term aspect="FOOD" polarity="positive">Knuspriger Ente</aspect-term>.

# %%
def sentence_xml_tagging(tasd_sentence: str) -> str:
    sentence_tag_start = '<sentence>'
    sentence_tag_end = '</sentence>'
    concat = sentence_tag_start + tasd_sentence + sentence_tag_end
    return concat

# %%
for sent in validated_sent:
    print(sent)
# Out:
# Die Meinung, die man von vorherigen Beiträgen ableitet, ist das hier früher ein gutes <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">Ort</aspect-term>, aber nicht mehr so.
# Wir, dort waren vier von uns, kamen um Mittag an – das Ort war leer – und die <aspect-term aspect="SERVICE" polarity="negative">Personal</aspect-term> verharr wie wir sie belasteten und sie waren sehr unhöflich.
# Die <aspect-term aspect="FOOD" polarity="negative">Nahrung</aspect-term> war schlecht - zu süß oder zu salzig und die <aspect-term aspect="FOOD" polarity="negative">Portionen</aspect-term> waren klein..
# Vermeiden Sie diesen <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">Ort</aspect-term>.
# Ich habe mehrmals zu Saul gegessen, das <aspect-term aspect="FOOD" polarity="positive"> Essen </aspect-term> ist immer wieder verblüffend gut.
# <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Maurizius</aspect-term> ist der beste Restaurant auf Smith Street und in Brooklyn..
# Die <aspect-term aspect="FOOD" polarity="positive">Entenbrühe</aspect-term> ist immer beeindruckend und die <aspect-term aspect="FOOD" polarity="positive">Fois Gras-Terrine mit Fichten</aspect-term> war aus diesem Welt
# Die <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Weinliste</aspect-term></aspect-term> ist interessant und hat viele gute Werte.
# Ich war sehr enttäuscht mit diesem <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">Restaurant</aspect-term>.
# Ich habe einen <aspect-term aspect="SERVICE" polarity="negative">Einkäufer im Warenhaus</aspect-term> um eine Lotusblatt gewickelte Reisart gefragt und sie erwiderte mit "Reis" und ging nur weg.
# <aspect-term aspect="FOOD" polarity="neutral">Leute</aspect-term> waren okay, nichts Besonderes..
# <aspect-term aspect="FOOD" polarity="negative">Chow fun</aspect-term> war trocken; <aspect-term aspect="FOOD" polarity="negative">Schweinebällchen</aspect-term> waren überraschend fett und mussten an einem Tisch mit lautem und rauen Familienmitglied sitzen.
# Ich/Wir werden dieses <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">Ort</aspect-term> niemals wieder besuchen.
# Gegangen bin auf einen 3-Tage-Osterschlemmer, mit <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Fisch</aspect-term> brachte den Abschluss, und ich bin so glücklich, dass dies war der Ort, auf den ich diese Reise beendete, weil es so großartig gewesen ist!
# <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> war göttlich, <aspect-term aspect="FOOD" polarity="positive">Oysters</aspect-term> sind so sinnlich wie möglich und der Preis kann nicht übertroffen werden!!!.
# Jedes Mal, wenn ich mich in New York finde, besuche ich immer <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Restaurant Saul</aspect-term> auf der Smith Street..
# Alles ist immer perfekt zubereitet, der <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term> ist auszeichnet, der <aspect-term aspect="AMBIENCE" polarity="positive">Decor</aspect-term> ist cool und unterhaltsam.
# Ich hatte das <aspect-term aspect="FOOD" polarity="positive">Tafelspitz-Spezial</aspect-term> auf meinem letzten Besuch und es war unglaublich.
# Die <aspect-term aspect="FOOD" polarity="negative">Nahrung</aspect-term> ist sehr mittelmäßig...die <aspect-term aspect="FOOD" polarity="negative">thaifusionartige Speisen</aspect-term> sind ein wenig zu süß, alles sie hier servieren ist zu süß...
# Das einzige, was ich nur mittelmäßig genossen habe, war ihr <aspect-term aspect="FOOD" polarity="positive">Gegrilltes Hähnchen Special mit Edamamerüese</aspect-term>.
# Ich hatte <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Edamame puré</aspect-term></aspect-term> noch nie zuvor, aber ich fand es innovativ und lecker (dazu hätte man ein bisschen mehr Salz gebraucht).
# Die <aspect-term aspect="AMBIENCE" polarity="positive">Zimmerdekoration</aspect-term> ist Nacht though...aber sie brauchen REALLY zu reinigen die <aspect-term aspect="AMBIENCE" polarity="negative">Lüftung</aspect-term> im Dach...es ist wirklich unappetitlich und tötet euren Versuch, dieses <aspect-term aspect="AMBIENCE" polarity="negative">Ort</aspect-term> zu einem sauberen und modernen aussehen zu bringen.
# Ihr <aspect-term aspect="FOOD" polarity="positive">Sakeliste</aspect-term> war umfangreich, aber wir suchten nach Purple Haze, das nicht aufgeführt war, sondern uns auf Anfrage erstellt wurde!
# Die <aspect-term aspect="FOOD" polarity="positive">Scharfe Thunfisch-Roll</aspect-term> war ungewöhnlich gut und die <aspect-term aspect="FOOD" polarity="positive">Rockschrimptemperatur</aspect-term> war beeindruckend, großartiges Appetisier zum Teilen!
# Wir gingen um 09:30 Uhr am Freitag und es war dann schon ein bisschen abgeklungen, so dass der <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term> großartig war!
# Wir lieben die <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">rosa Pferd </aspect-term>..
# Die perfekte <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Stelle</aspect-term>.
# <aspect-term aspect="FOOD" polarity="positive">Lebensmittel</aspect-term>-awesom...
# <aspect-term aspect="SERVICE" polarity="positive">Dienstleistungsfreundlich und aufmerksam</aspect-term>
# <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term>- entspannt und stilvoll
# Entschuldigt sich vorab: Diese Situation ist nicht zu diskutieren <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term>. Sie muss einfach ausprobiert werden, um zu glauben. Es handelt sich hier um ein Zuhause für diejenigen mit einem liebsten Buch im Herzen.
# Die <aspect-term aspect="FOOD" polarity="neutral">Nahrung</aspect-term> ist zufriedenstellend.
# Es sind jedoch der <aspect-term aspect="SERVICE" polarity="negative">Dienst</aspect-term>, der mir einen schlechten Geschmack im Mund lässt.
# Ich habe zufällig eine Politik, die sich mit einem Hauch von Selbstachtung verbindet, die darin besteht, nicht zu lassen, dass ein <aspect-term aspect="SERVICE" polarity="negative">Kellner</aspect-term> mich einschüchtert, d.h. mich schlecht fühlt, wenn ich nach Nischen wie Wasser oder das Rechnungsaufzeichnen fragen.
# Dieser <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term> muss unbedingt das beste japanische Restaurant in der neuen yorkart Area sein.
# <aspect-term aspect="FOOD" polarity="positive">Lebensmittel</aspect-term> ist großartig..
# <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> ist Spitzenklasse..
# Ich neige dazu, ein Sushi-Restaurant zu beurteilen, mit seinem <aspect-term aspect="FOOD" polarity="positive">Seegurke</aspect-term>, der himmlisch war bei Sushi Rose.
# Die <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Sushi</aspect-term></aspect-term> schien ziemlich frisch und war ausreichend proportioniert.
# Der <aspect-term aspect="FOOD" polarity="positive">Reis zu Fisch-Verhältnis</aspect-term> war auch gut—sie haben nicht versucht, den Reis überzuladen..
# Wir nahmen den Vorteil aus der <aspect-term aspect="FOOD" polarity="positive">halbfreien Sushi-Angebot</aspect-term> am Samstag also war es wert.
# In der Nacht zog dieses Ort eine gut angemessene Kleidung mit sich, NY <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Crowd</aspect-term>.
# Die <aspect-term aspect="FOOD" polarity="positive">Leckerei</aspect-term> war gut zubereitet und das <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> war perfekt.
# Der <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Prix Fixe Menü</aspect-term></aspect-term></aspect-term> ist wertvoll und man erhält mehr als genug (sowohl in Menge als auch in Qualität).
# $6 und es gibt viel leckeres <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Food</aspect-term></aspect-term></aspect-term>, alles davon frisch und ständig nachgefüllt.
# Ich bin nicht ein Vegetarier aber fast alle <aspect-term aspect="FOOD" polarity="positive">Gänge</aspect-term> waren großartig.
# Das <aspect-term aspect="FOOD" polarity="positive">Essen</aspect-term> hier ist recht gut, aber nur wenn du darauf wartest..
# Ich mag die <aspect-term aspect="FOOD" polarity="positive">Somosas</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">Chai</aspect-term> und das <aspect-term aspect="FOOD" polarity="positive">Chole</aspect-term>, aber <aspect-term aspect="FOOD" polarity="negative">Dhosas</aspect-term> und <aspect-term aspect="FOOD" polarity="negative">Dhal</aspect-term> waren ein bisschen enttäuschend.
# Die <aspect-term aspect="SERVICE" polarity="negative">Dienste</aspect-term> wechseln sich täglich ab - manchmal sind sie sehr nett, und manchmal auch nicht so.
# Das <aspect-term aspect="SERVICE" polarity="negative">Küchen</aspect-term> ist jedoch fast immer langsam.
# Auch, spezifizieren Sie, ob Sie Ihr <aspect-term aspect="FOOD" polarity="negative">Leckerei</aspect-term> scharf mögen - es ist ziemlich matt, wenn Sie es nicht sind..
# Der <aspect-term aspect="AMBIENCE" polarity="positive">Ambiente</aspect-term> ist schön und gut für das Gespräch, also wäre ein entspannter Mittagessen hier wahrscheinlich der beste.
# Wenn du jemals entlang des Flusses in Weehawken warst, hast du eine Vorstellung davon, was die Spitze der <aspect-term aspect="AMBIENCE" polarity="positive">Ansichtskarte</aspect-term> im Chart House zu bieten hat.
# Füge zu dem großartigen <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> und großartigem <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Essen</aspect-term></aspect-term> bei einem vernünftigen Preis und du hast dir selbst die Anfänge eines großen Abends gesichert.
# Die <aspect-term aspect="FOOD" polarity="positive">Vulkaacake- Dessert</aspect-term> war unglaublich und ich empfehle es sehr!
# Sobald du in <aspect-term aspect="AMBIENCE" polarity="positive">Cosette</aspect-term> trittst, bist du wunderbar in einem kleinen, abgelegenen Pariser Bistro verwiesen..
# Dieses kleine <aspect-term aspect="AMBIENCE" polarity="positive">Restaurant</aspect-term> ist so gemütlich wie es geht, mit diesem bestimmten Pariser Charme.
# Die <aspect-term aspect="FOOD" polarity="positive">Leckerei</aspect-term> war mittelmäßig bis überdurchschnittlich; die <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="negative">Französische Eintopfsoße</aspect-term></aspect-term>füllung war jedoch nicht besonders beeindruckend, und die <aspect-term aspect="FOOD" polarity="negative">Desserts</aspect-term> waren in keiner Weise brillant..
# Denke daran, gehe für die <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term>, und überlege dir das <aspect-term aspect="FOOD" polarity="neutral">Essen</aspect-term> nur als Begleiter für einen Trip um die Welt!
# Die <aspect-term aspect="FOOD" polarity="negative">Pizza</aspect-term> wurde kalt geliefert und das <aspect-term aspect="FOOD" polarity="negative">Käse</aspect-term> war nicht einmal voll gesmolzen!
# Die <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative">Pizze</aspect-term></aspect-term> ist überpreisst und nass.
# Ja, sie verwenden leckere <aspect-term aspect="FOOD" polarity="positive">Zutaten</aspect-term>, aber selbst leckere Zutaten machen keinen guten <aspect-term aspect="FOOD" polarity="negative">Pizza</aspect-term> zu, wenn jemand weiß, wie man die <aspect-term aspect="FOOD" polarity="negative">Teig</aspect-term> richtig bekommt..
# Ich denke, ich habe einige der besten <aspect-term aspect="FOOD" polarity="positive">gerichte</aspect-term> meines Lebens bei Minnow gegessen.
# Die <aspect-term aspect="FOOD" polarity="positive">Fisch- und Meeresfrüchte</aspect-term> sind unglaublich, es gibt eine gute <aspect-term aspect="FOOD" polarity="positive">Weinliste</aspect-term>, und das ständig wechselnde <aspect-term aspect="FOOD" polarity="positive">Menü</aspect-term> bietet immer wieder tolle Überraschungen..
# Die Kombination von super-frischen <aspect-term aspect="FOOD" polarity="positive">Zutaten</aspect-term> in den Gerichten ist ungewöhnlich aber wirklich lecker.
# Beste <aspect-term aspect="FOOD" polarity="positive">Pastrami-</aspect-term> habe ich je und groß <aspect-term aspect="FOOD" polarity="positive">Portion</aspect-term>-ohne lächerlich zu sein...
# Meine Frau hatte die <aspect-term aspect="FOOD" polarity="positive">gebratenen Hummer<aspect-term aspect="FOOD" polarity="positive">, die riesig sind und liebte es.
# Als japanischer Native habe ich in der Tristate-Gegend über 8 Jahre lang gelebt, aber ich war einfach nur so beeindruckt von diesem <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term>.
# Dieser Ort ist das japanischste es jemals sein kann..
# Die <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Zeichen</aspect-term>, die <aspect-term aspect="FOOD" polarity="positive">Spezialmenüs</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">Lebensmittel</aspect-term> und sogar alle <aspect-term aspect="SERVICE" polarity="positive">Kellner</aspect-term> sind ALLE GANZ und GANZ TOTAL japanisch.
# Dieser Ort <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">lokal</aspect-term> lohnt sich nicht für eine eine Stunde Fahrt.
# <aspect-term aspect="AMBIENCE" polarity="positive"><aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Lionel</aspect-term></aspect-term> ist ein Schmuckstück des Ostviertels: locker aber hip, mit gut vorbereitetem Grundkosten- <aspect-term aspect="FOOD" polarity="positive">Französischer Bistro-Lieferumgang</aspect-term>, guten <aspect-term aspect="FOOD" polarity="positive">Spezialangeboten</aspect-term>, einer warmen und lebhaften <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term>..
# Meine Frau und ich genießen immer die jungen, nicht immer gut geschulte aber dennoch freundlichen <aspect-term aspect="SERVICE" polarity="positive">Staff</aspect-term>, von denen jeder eine Geschichte hat.
# Zuent <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="neutral"> Wein </aspect-term></aspect-term> zu vernünftigen Preisen..
# Jedoch jedenmal, wenn ich mich entscheide, noch einen Ort auf der UES auszuprobieren, werde ich empört sein, dass ich nicht nur zu <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Zucchero Pomodori</aspect-term> gegangen bin..
# Dies ist weit entfernt meine Lieblings- <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">platz</aspect-term> im Viertel..
# Die <aspect-term aspect="SERVICE" polarity="positive">Leistung</aspect-term> ist ausgezeichnet, die <aspect-term aspect="AMBIENCE" polarity="positive">Zeremonie</aspect-term> ist großartig und die <aspect-term aspect="FOOD" polarity="positive">Speisen</aspect-term> sind lecker und kommen in großen <aspect-term aspect="FOOD" polarity="positive">Portionen</aspect-term>.
# Ich bin für den <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Gnocchi</aspect-term>...
# Dieser <aspect-term aspect="AMBIENCE" polarity="negative">Ort</aspect-term> ist unglaublich klein..
# Die <aspect-term aspect="SERVICE" polarity="negative">Mädchen der Gastgeberin</aspect-term> ist grob bis unangemessen gegenüber.
# Die <aspect-term aspect="FOOD" polarity="negative">Nahrung</aspect-term> war matt und fettig..
# Wir sind hier viele Mal gewesen und haben immer großartiges <aspect-term aspect="FOOD" polarity="positive"> Essen </aspect-term>, <aspect-term aspect="FOOD" polarity="positive"> Wein </aspect-term> und <aspect-term aspect="SERVICE" polarity="positive"> Service </aspect-term> gehabt.
# Wir waren besorgt, dass wir Schwierigkeiten haben würde, hereinzukommen, aber irgendwie konnte man einen kurzen <aspect-term aspect="SERVICE" polarity="positive">Warten</aspect-term>-Zeitpunkt haben.
# Wir hatten immer einen großartigen <aspect-term aspect="FOOD" polarity="positive">Wein</aspect-term>, während wir warteten..
# Wenn wir saßen, erhielten wir groß und schnell <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term>.
# Die <aspect-term aspect="SERVICE" polarity="positive">Personen</aspect-term>, die dort arbeiten, sind immer so freundlich, dass man manchmal vergisst, dass man in New York ist..
# Achtest du dich darauf, diesen <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term> so oft wie möglich zu probieren...
# Dies ist eine lustige <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Restaurant</aspect-term> zum Besuch...
# Die <aspect-term aspect="FOOD" polarity="positive">Pizza</aspect-term> ist lecker und ich mag die <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term>.
# Aber das <aspect-term aspect="FOOD" polarity="negative">Pizza</aspect-term> ist zu teuer..
# Ich bin dort zum <aspect-term aspect="FOOD" polarity="negative">Frühstück</aspect-term> gegangen und es war nicht so gut wie ich von den Bewertungen erwartet hatte.
# <aspect-term aspect="FOOD" polarity="negative">Mürge</aspect-term> war flüssig und die <aspect-term aspect="FOOD" polarity="negative">Leckerei</aspect-term> hatte nicht viel Geschmack..
# Dieser Ort <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">ist</aspect-term> groß..
# Die <aspect-term aspect="SERVICE" polarity="positive">Kellnerin</aspect-term> war sehr geduldig mit uns und die <aspect-term aspect="FOOD" polarity="positive">Leckerei</aspect-term> ist phänomenal!
# <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> war pünktlich, freundlich und großartig.
# Großartige <aspect-term aspect="FOOD" polarity="positive">Pizzä</aspect-term> und fantastische <aspect-term aspect="SERVICE" polarity="positive">Servic</aspect-term>
# Es gab einen kleinen <aspect-term aspect="SERVICE" polarity="positive">Wartezeit</aspect-term>, aber kürzer als ich erwartet hatte..
# Dies ist das beste <aspect-term aspect="FOOD" polarity="positive">Sushi</aspect-term> in New York City - ohne Widerspruch.
# Die <aspect-term aspect="AMBIENCE" polarity="negative">Stelle</aspect-term> ist klein und eng, aber die <aspect-term aspect="FOOD" polarity="positive">Leckerei</aspect-term> ist fantastisch.
# Die <aspect-term aspect="FOOD" polarity="positive">Thunauge des Garis</aspect-term>... Rückgabung nur den übersetzten String.
# <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Planet Thailand</aspect-term> hat mich immer wieder gut bewegt , ich gehe dort normalerweise für die <aspect-term aspect="FOOD" polarity="positive">sushi</aspect-term> , was großartig ist , das <aspect-term aspect="FOOD" polarity="positive">thailändische Essen</aspect-term> ist auch top .
# Mit der großen Vielfalt auf dem <aspect-term aspect="FOOD" polarity="positive">Menü</aspect-term> , esse ich hier oft und habe nie Langeweile ..
# Die <aspect-term aspect="AMBIENCE" polarity="negative">Atmosphäre</aspect-term> ist nicht das größte , aber ich denke , das ist so , wie sie die Preise herunterhalten ..
# Es geht alles um das <aspect-term aspect="FOOD" polarity="positive">Essen</aspect-term>.
# Es dauerte uns eine lange Zeit, bis wir den <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative"> Ort </aspect-term> gefunden hatten.
# Aber wenn wir das <aspect-term aspect="FOOD" polarity="negative">Menü</aspect-term> ansahen, gab es nicht viele Optionen, die meisten davon waren Nudeln im Startgerichtsabschnitt.
# Diejenigen <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="neutral">Rollen</aspect-term></aspect-term> waren groß, aber nicht gut und <aspect-term aspect="FOOD" polarity="negative">Sashimi</aspect-term> war nicht frisch.
# Probieren Sie den <aspect-term aspect="FOOD" polarity="positive">kratzigen Tuna</aspect-term>, es ist zu sterben wert..
# Erst ging hier <aspect-term aspect="AMBIENCE" polarity="positive">Garten-Terrasse</aspect-term>, nur zurückkehren.
# Die <aspect-term aspect="FOOD" polarity="positive">Leckerei</aspect-term> war beeindruckend, und die <aspect-term aspect="SERVICE" polarity="positive">Dienstleistung</aspect-term> war pünktlich und hilfsbereit, aber nicht übermäßig oder eilehaft.
# Der <aspect-term aspect="FOOD" polarity="positive">Steak Tartare</aspect-term> ist ein großartiger Wettkandidat, sie fixieren es für Sie am Tisch.
# Ehrlich gesagt waren einige Nächte im <aspect-term aspect="AMBIENCE" polarity="negative">Restaurant</aspect-term> ziemlich warm, aber das <aspect-term aspect="AMBIENCE" polarity="positive">Offene Küche</aspect-term> ist Teil der Vorzüge.
# Große <aspect-term aspect="FOOD" polarity="positive">Wein Auswahl</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">Gigondas</aspect-term> ist das Geld wert, und die <aspect-term aspect="FOOD" polarity="positive">Haus Champagner</aspect-term> ist eine gute Value.
# Es kann ein bisschen überfüllt sein am Wochenende, aber die <aspect-term aspect="AMBIENCE" polarity="positive">Vibe</aspect-term> ist gut und es ist das beste <aspect-term aspect="FOOD" polarity="positive">französische Essen</aspect-term> Sie in der Gegend finden werden.
# Hat man den <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term> empfohlen, immer eine gute Antwort erhält.
# Pizza - die einzige <aspect-term aspect="FOOD" polarity="positive">Pizza</aspect-term> in NYC, die keine zusätzlichen Toppings haben sollte - das <aspect-term aspect="FOOD" polarity="positive">Haupt</aspect-term> Geschmack ist wie der beste, frisch gebackene Brot!.
# Ich nehme alle meine Gäste aus NYC zu <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">VT</aspect-term> zurück.
# Ich bin nicht sicher, wo der vorherige Rezensent, lonk, sich gegessen hat, aber Saul befindet sich in einer großartigen <aspect-term aspect="AMBIENCE" polarity="positive">Nachbarschaft</aspect-term> und hat großartiges <aspect-term aspect="FOOD" polarity="positive">Leckeres Essen</aspect-term>!.
# Ich würde es sehr empfehlen für eine besondere Gelegenheit – es bietet ein intimes <aspect-term aspect="AMBIENCE" polarity="positive">Umgebung</aspect-term> und nettes <aspect-term aspect="SERVICE" polarity="positive">Dienstleistung</aspect-term>.
# Ich bin mir nicht sicher, wo die anderen Rezensionen gegessen haben, aber es scheint, als hätten wir zwei verschiedene Restaurants besucht, denn meine Freunde und ich lieben <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Mizu</aspect-term> sehr, sehr gern ...und wir sind wiederholt Kunden.
# Stelle sicher, dass du die <aspect-term aspect="FOOD" polarity="positive">Spicy Scallop Roll</aspect-term>... ... Rückgabenummer nur.
# <aspect-term aspect="FOOD" polarity="positive">Moules</aspect-term> waren großartig, <aspect-term aspect="FOOD" polarity="negative">Lobster Ravioli</aspect-term> war extrem salzig!
# Ich habe meine Mama für Muttertag genommen und der <aspect-term aspect="SERVICE" polarity="negative">Maitre d' </aspect-term> war ziemlich lächerlich.
# Tiny <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative">Schlüsselgericht</aspect-term></aspect-term></aspect-term> kostet 8,00 €... ist für mich einfach überpreisst für das, was es ist.
# Die <aspect-term aspect="FOOD" polarity="positive">Getränke</aspect-term> sind immer gut gemacht und der <aspect-term aspect="FOOD" polarity="positive">Wein Auswahl</aspect-term> ist günstig.
# Versuchen Sie <aspect-term aspect="FOOD" polarity="positive">Chef-Spezialitäten</aspect-term> -- sie sind zu sterben wert.
# <aspect-term aspect="SERVICE" polarity="neutral">Dienst</aspect-term> ist nicht genau fünf Sterne, aber das ist für mich kein großes Problem..
# <aspect-term aspect="AMBIENCE" polarity="positive">Kellerraum</aspect-term> ist immer eine gute Anziehung.
# <aspect-term aspect="AMBIENCE" polarity="positive">Rägas</aspect-term> ist eine romantische, gemütliche Küche.
# Die <aspect-term aspect="FOOD" polarity="positive">exotische<aspect-term aspect="FOOD" polarity="positive"> Lebensmittel- </aspect-term>Kombinationen</aspect-term> sind hervorragend präsentiert und eine Freude in leckeren Kombinationen.
# Der <aspect-term aspect="SERVICE" polarity="positive">Stab</aspect-term> ist unglaublich hilfsbereit und aufmerksam.
# Der <aspect-term aspect="FOOD" polarity="positive">Balkontisch</aspect-term> ist sehr gut mit interessanten <aspect-term aspect="FOOD" polarity="positive">Biern</aspect-term> und gut preisgünstigen <aspect-term aspect="FOOD" polarity="positive">Weinen</aspect-term> ausgestattet..
# Als wir auf <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">Leon</aspect-term> stürzten, dachten wir, dass wir ein wunderschönes Schatz gefunden hätten, aber wir waren ohne Zweifel falsch.
# Die <aspect-term aspect="SERVICE" polarity="negative">Waiterin</aspect-term> hat unsere Tischstelle fast in die Toilette bewegt und als wir um Stornierung unseres Abendessens gebeten haben, weil wir nicht essen wollten, wie auf dem Toilettensitz zu sitzen, bekamen wir die Antwort "nein"...
# Rüde <aspect-term aspect="SERVICE" polarity="negative">Service</aspect-term>, mediokre <aspect-term aspect="FOOD" polarity="neutral">Leistung</aspect-term>...Es gibt eine Menge Restaurants in NY...bleib damit ab...
# Ich hatte einen großartigen Zeit bei <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Jekyll und Hyde</aspect-term>.
# Ich liebte alles daran - insbesondere die <aspect-term aspect="AMBIENCE" polarity="positive">Shows</aspect-term> und <aspect-term aspect="AMBIENCE" polarity="positive">Akteure</aspect-term>.
# Unser <aspect-term aspect="SERVICE" polarity="positive">Server</aspect-term> war sehr hilfreich und freundlich.
# Die <aspect-term aspect="FOOD" polarity="positive">Leckerei</aspect-term> war auch gut..
# Die <aspect-term aspect="FOOD" polarity="positive">Thun</aspect-term> und <aspect-term aspect="FOOD" polarity="positive">Wasabie Kartoffeln</aspect-term> sind ausgezeichnet..
# Die <aspect-term aspect="AMBIENCE" polarity="positive">außere Atmosphäre</aspect-term> von Sitzen auf der Gehwegwand, die die Welt passieren sehen, 50 Fuß weit entfernt auf der 6. Avenue am kühlen Abend war wunderbar..
# <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> war sofortig und höflich..
# Sehr gut <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term>, sehr gut <aspect-term aspect="FOOD" polarity="positive">Lebensmittel</aspect-term>.
# Die <aspect-term aspect="FOOD" polarity="positive">Pizza</aspect-term> ist lecker - sie verwenden <aspect-term aspect="FOOD" polarity="positive">frisches Mozzarella</aspect-term> stattdessen von dem billigen, gefrorenen, gerieben Käse, den die meisten Pizzerias teilen.
# Zwei Beschwerden - ihr <aspect-term aspect="FOOD" polarity="negative">Aussagewahl</aspect-term> stinkt, es wäre schön, wenn manche Mozzarella-Sticks auf die Speisekarte setzen würde..
# <aspect-term aspect="SERVICE" polarity="negative">Wartungspersonal</aspect-term> ist offensichtlich unappreciervoll gegenüber Ihrem Geschäft, aber es ist das beste <aspect-term aspect="FOOD" polarity="positive">Torte</aspect-term> auf dem UWS!
# Durchschnittlich das beste <aspect-term aspect="FOOD" polarity="positive">Salat</aspect-term>, das ich in einem Fast-Food-Restaurant bekommen habe..
# Feine <aspect-term aspect="FOOD" polarity="positive"> kulinarische </aspect-term> Restaurantqualität
# Am aktuellen Sonntag Nachmittag stießen wir zufällig auf einen großartigen <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Restaurant</aspect-term> auf unserem Weg zum Pulitzer-Preis gewonnenen Theaterstück DOUBT.
# Die <aspect-term aspect="FOOD" polarity="positive">Hähnchen-Pfannkuchen-</aspect-term> ist ausgenommen, die <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Käseburger</aspect-term></aspect-term> sind riesig und lecker, und der <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> ist professionell und warm..
# Die <aspect-term aspect="SERVICE" polarity="positive">Stoß</aspect-term> hat keine Nerven.
# Die <aspect-term aspect="FOOD" polarity="positive">Nahrungsoptionen</aspect-term> regeln..
# Wenn ich im Uppercase für eine Weile lebte, würde ich die<aspect-term aspect="FOOD" polarity="positive">Bagel-Bäckerei</aspect-term>kauft und sie würden immer noch besser sein als jeder andere.
# Worth visiting den <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">1. Ave Spot</aspect-term> weil es der Originalladen ist.
# Er brachte mir eine <aspect-term aspect="FOOD" polarity="positive"> Uni-Handroll </aspect-term>, die ich noch nie hatte, und lass mich dir sagen... ES WAR HIMMEL!
# Die <aspect-term aspect="FOOD" polarity="positive">Sake-Menüliste</aspect-term> sollte nicht übersehen werden!
# Versuchen Sie den <aspect-term aspect="FOOD" polarity="positive">Lobster Teriyaki</aspect-term> und den <aspect-term aspect="FOOD" polarity="positive">Rosenspezialroll</aspect-term>.
# <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> war sehr gut - pünktlich, aufmerksam und nicht störend.
# <aspect-term aspect="FOOD" polarity="positive">Leckere Lebensmittel</aspect-term> waren auch sehr gut, wenn man bedenkt, dass wir die Preise- Auswahl ausprobieren wollten (obwohl ich das <aspect-term aspect="FOOD" polarity="negative">Schweinebrust</aspect-term>, das ich bestellt hatte, ein bisschen länger gebraten gewesen wäre, so dass das Fett eine angenehmere MELT-in-dein-Mund-Erfahrung abgeben würde)..
# <aspect-term aspect="FOOD" polarity="positive">Weinlistenauswahl</aspect-term> ist gut und <aspect-term aspect="FOOD" polarity="positive">Wein-zu-Koppelpreis</aspect-term> wurde reichlich bis zum Rand gefüllt..
# <aspect-term aspect="AMBIENCE" polarity="positive">Traditioneller französischer Dekor</aspect-term> war angenehm, obwohl der <aspect-term aspect="AMBIENCE" polarity="negative">Halle</aspect-term> ziemlich laut war - das Restaurant war voll und wir mussten unsere Stimmen erhöhen, um eine Konversation halten zu können..
# Ich bin wahrscheinlich zum <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Kafé Spice</aspect-term> ungefähr 5-8 Mal gewesen und es ist wahrscheinlich immer noch das beste indische Restaurant um Union Square.
# Um es zusammenzufassen: <aspect-term aspect="SERVICE" polarity="neutral">Der Service</aspect-term> variiert von gut bis mittelmäßig, je nachdem welchen Waiter man bekommt; allgemein ist er nur durchschnittlich OK..
# <aspect-term aspect="SERVICE" polarity="positive">Sitzgelegenheit</aspect-term> ist immer pünktlich, obwohl das Restaurant am Abend voll wird.
# <aspect-term aspect="FOOD" polarity="positive">Lebensmittel</aspect-term> ist normalerweise sehr gut, obwohl ich manchmal über die Frischheit von <aspect-term aspect="FOOD" polarity="negative">roher Gemüse in den Beilagen</aspect-term> nachgedacht habe.
# Die <aspect-term aspect="AMBIENCE" polarity="positive">Zierde</aspect-term> ist lebendig und sehenswert mit mehreren <aspect-term aspect="AMBIENCE" polarity="positive">halbprivaten Börsen</aspect-term> auf der rechten Seite des Esszimmers, die großartig für eine Dating-Gelegenheit sind..
# Ich habe NICHT im <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Roten Auge</aspect-term> enttäuscht worden.
# Die erste Zeit, in der ich war, und vollkommen von dem <aspect-term aspect="AMBIENCE" polarity="positive">Live Jazzband</aspect-term> und <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term> beeinflusst wurde, bestellte ich die Lachs-Cobb-Salat..
# Es ist einfach das beste <aspect-term aspect="FOOD" polarity="positive">essen</aspect-term> in NYC..
# Sie können sich nicht irren im <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Red Eye Grill</aspect-term>.
# Wenn wir uns von der Upper East Side bewegen würden, würden wir die <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Restaurant</aspect-term> unglaublich vermissen.
# Der <aspect-term aspect="GENERAL-IMPRESSION" polarity="neutral">Restaurant</aspect-term> ist süß, aber nicht höflich.
# Die <aspect-term aspect="FOOD" polarity="positive">Nahrung</aspect-term> ist ein Diamant im Rost – die Nahrung ist lecker und zu Hause zubereitet mit dem perfekten <aspect-term aspect="FOOD" polarity="positive">Gleichgewicht von Kräutern und Tomaten</aspect-term>.
# Wir hatten eine großartige Zeit im <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Jekyll und Hyde Pub</aspect-term> gestern Nacht.
# Nachdem wir uns wirklich gut am <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Bar</aspect-term> amüsiert hatten, setzten wir uns an einen Tisch und hatten Abendessen.
# Der <aspect-term aspect="SERVICE" polarity="positive">Server</aspect-term> war wirklich kühn und brachte uns unser Essen und Getränke mit einem Lächeln.
# Der Ort<aspect-term aspect="AMBIENCE" polarity="positive">'s </aspect-term>Zur Dekoration und <aspect-term aspect="AMBIENCE" polarity="positive">versteckten Badezimmern</aspect-term> führte zu einem guten Lachen.
# Ich empfehle stark, dieses <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Restaurant</aspect-term> zu besuchen und Abendessen und Getränke zu genießen!
# Wenn du die Art von Mensch bist, der sich Sorgen macht und unterhalten möchte, ist dies eine großartige <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term> zum Besuch und zu essen.
# Mein Mann und ich dachten, es würde großartig sein, zum <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Jekyll and Hyde Pub</aspect-term> zu gehen, um unser Jahrestag zu feiern, und unsere Überraschung war es, dass es fantastisch war..
# Die haben über 100 verschiedene <aspect-term aspect="FOOD" polarity="positive">Biersorten</aspect-term> zu bieten, um ihre Gäste zu begrüßen, sodass es meinem Mann sehr glücklich machte und das <aspect-term aspect="FOOD" polarity="positive">Futter</aspect-term> war lecker, wenn ich eine Empfehlung geben muss, so muss es die <aspect-term aspect="FOOD" polarity="positive">Pumpkin Tortellini</aspect-term> sein.
# Die <aspect-term aspect="AMBIENCE" polarity="positive">Unterhaltung</aspect-term> war groß sie haben Shows, die ganze Zeit während des Essens laufen.
# Bitte nehme meine Empfehlung an, gehe und probiere diesen <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term>.
# Der <aspect-term aspect="FOOD" polarity="positive">Bagel</aspect-term> war riesig.
# Die Arbeiter dort laden die <aspect-term aspect="FOOD" polarity="negative">Tasche</aspect-term> auch absolute mit Käsecreme voll (kriegt ein wenig knitterig). Rückgabe nur der übersetzte String.
# Dies war mein erstes Mal im Cafe St. Barts und ich muss sagen, wie lecker das <aspect-term aspect="FOOD" polarity="positive"> Essen </aspect-term> und die <aspect-term aspect="SERVICE" polarity="positive"> Bedienung </aspect-term> war.
# Ich muss sehr empfehlen den <aspect-term aspect="FOOD" polarity="positive">Lobster Roll</aspect-term> - nicht zu viel Mayo; Sie können erzählen, dass es ein frischer <aspect-term aspect="FOOD" polarity="positive">Lobster</aspect-term> war.
# Andere Gäste genossen <aspect-term aspect="FOOD" polarity="positive">Pizze</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">Santa Fe Chopped Salad</aspect-term> und <aspect-term aspect="FOOD" polarity="positive">Fisch & Chips</aspect-term>.
# Ich empfehle sehr stark Café St. Bart's für ihre <aspect-term aspect="FOOD" polarity="positive">Leckereien</aspect-term>, die <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term> und wunderbare <aspect-term aspect="SERVICE" polarity="positive">Bedienung</aspect-term>.
# Alle <aspect-term aspect="SERVICE" polarity="positive">Personal</aspect-term> sind absolut professionell!!
# Dieser <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">Restaurant</aspect-term> war weit überhypesiert..
# Meine Chow Fun und Chow See war wirklich einschmeckend und eitel..
# Die <aspect-term aspect="FOOD" polarity="neutral">Zwiebelpfannkuchen</aspect-term> und <aspect-term aspect="FOOD" polarity="neutral">geschnittene Maultaschen</aspect-term> waren nichts Außergewöhnliches.
# Der <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> war die einzige gute Sache über diesem <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">Restaurant</aspect-term>.
# Es ist langweilig im Innern und unsere <aspect-term aspect="FOOD" polarity="negative">Sushi</aspect-term> war ziemlich unterdurchschnittlich... der <aspect-term aspect="FOOD" polarity="negative">Tuna</aspect-term> war nass und die anderen <aspect-term aspect="FOOD" polarity="negative">Rollen</aspect-term> hatten keinen Geschmack.
# Ihr <aspect-term aspect="FOOD" polarity="positive">Pensil Penang</aspect-term> ist lecker und alles andere ist phantastisch..
# Der Preis ist vernünftig, obwohl der <aspect-term aspect="SERVICE" polarity="negative">Service</aspect-term> schlecht ist.
# <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Leckeres Restaurant</aspect-term> war unglaublich....... <aspect-term aspect="FOOD" polarity="positive">Food</aspect-term> war lecker und natürlich frisch..
# Hats off zum <aspect-term aspect="FOOD" polarity="positive">Chef</aspect-term>.
# Die <aspect-term aspect="FOOD" polarity="positive">Salate</aspect-term> sind lecker, sowohl erfrischend als auch sehr scharf..
# Wir hatten <aspect-term aspect="FOOD" polarity="positive">Pams spezielles gebratenes Fisch</aspect-term> und es war unglaublich.
# Große <aspect-term aspect="AMBIENCE" polarity="positive">Vibe</aspect-term>, viele Menschen.
# Ich habe nicht geklagt, ich mochte die <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term> so sehr...
# <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term> ist so süß und charmant, gut für das Geschäft, obwohl wir dort auf Urlaub waren.
# <aspect-term aspect="FOOD" polarity="positive">Salate</aspect-term> waren fantastisch.
# Obwohl wir nach normaler Salat und ein paar Walnüsse gesucht haben, die <aspect-term aspect="FOOD" polarity="positive">Salate</aspect-term>, die wir erhielten, waren großartig.
# <aspect-term aspect="FOOD" polarity="positive">Zutaten</aspect-term> sind biologisch, das ist ein echter Plus für mich.
# Dies sind einige <aspect-term aspect="FOOD" polarity="positive">gute<aspect-term aspect="FOOD" polarity="positive"> sehr gute, günstige </aspect-term>Sushi</aspect-term>.
# Die <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">schüsselige Tuna-Rolle</aspect-term></aspect-term></aspect-term> ist riesig und wahrscheinlich das beste, was ich bisher bei diesem Preisbereich hatte.
# Die <aspect-term aspect="FOOD" polarity="positive">Gelb Tail</aspect-term> war besonders gut auch..
# Ich habe Bedenken im Hinblick auf den <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative">alle you can eat Deal</aspect-term></aspect-term>, jedoch -- die Auswahl ist relativ begrenzt und du kannst wahrscheinlich mehr Essen bestellen als du essen kannst für weniger als 18 US-Dollar nur indem du dich vom Menü entfernst..
# In jedem Fall ist dies ein Ort, den ich sicherlich wieder besuchen werde, wenn ich in dieser Gegend bin. <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term>.
# <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Groß Wong</aspect-term> erhält großes Lob für eine feine Einrichtung..
# Sie haben alles - großartigen Preis, <aspect-term aspect="FOOD" polarity="positive"> Essen </aspect-term>, und <aspect-term aspect="SERVICE" polarity="positive"> Service </aspect-term>..
# Die <aspect-term aspect="AMBIENCE" polarity="negative">Atmosphäre</aspect-term> ist laut und die <aspect-term aspect="SERVICE" polarity="positive">Kellner</aspect-term> sind wörtlich gesagt, auf dem Weg zu gehen und tun Dinge so schnell wie sie können..
# Und es kommt alles zu einem sehr geringen Preis (<aspect-term aspect="FOOD" polarity="positive">Congee</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">Nudeln</aspect-term> und <aspect-term aspect="FOOD" polarity="positive">Reisgerichte</aspect-term> kosten nicht mehr als 3-6 Dollar pro Stück)..
# Der <aspect-term aspect="SERVICE" polarity="positive">Takeout</aspect-term> ist großartig auch, da sie hochwertiges Tupperware ebenfalls geben.
# Dieser Ort <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive"> ist immer sehr überfüllt und beliebt </aspect-term>
# Genossen und Schwestern, ich habe ein sehr leckeres <aspect-term aspect="FOOD" polarity="positive">Kaiser-Salat</aspect-term> gegessen, während meine Frau ein sehr leckeres <aspect-term aspect="FOOD" polarity="positive">Rucola mit Hühnchenkäse</aspect-term> hatte....beide sehr lecker!
# Wir beide wählten einen <aspect-term aspect="FOOD" polarity="positive">Pasta-Gericht</aspect-term> und sie wurden pünktlich und frisch serviert.
# Wir endeten mit <aspect-term aspect="FOOD" polarity="positive">Tiramisu-Caak aus Schokolade</aspect-term>, beide waren lecker.
# Ich ging kürzlich zu diesem <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Restaurant</aspect-term> mit einigen Kollegen für Lunch und hatte eine unglaubliche Zeit..
# Die <aspect-term aspect="SERVICE" polarity="positive">Stäfe</aspect-term> waren nett, die <aspect-term aspect="FOOD" polarity="positive">Leckerei</aspect-term> war absolut lecker und der <aspect-term aspect="AMBIENCE" polarity="positive">Ort</aspect-term> ist schön.
# Wir hatten sogar einen Besuch von dem <aspect-term aspect="SERVICE" polarity="positive">Manager</aspect-term>, der sicherstellen wollte, dass wir uns gut amüsierten.
# Manchmal bekomme ich gute <aspect-term aspect="FOOD" polarity="positive">Nahrung</aspect-term> und okay <aspect-term aspect="SERVICE" polarity="neutral">Dienst</aspect-term>..
# Manchmal bekomme ich schlechten <aspect-term aspect="FOOD" polarity="negative">Essen</aspect-term> und schlechten <aspect-term aspect="SERVICE" polarity="negative">Dienst</aspect-term>, manchmal bekomme ich guten <aspect-term aspect="FOOD" polarity="positive">Guten</aspect-term> und schlechten <aspect-term aspect="SERVICE" polarity="negative">Dienst</aspect-term>.
# Das Ort ist ein Bistro, was bedeutet: einfache <aspect-term aspect="FOOD" polarity="positive">Gebäck</aspect-term> und <aspect-term aspect="FOOD" polarity="positive">Wein</aspect-term> serviert effizient in einer bunzelstarken <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term>.
# Und wo schlägt <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Patis</aspect-term> falsch, nirgendwo..
# Und bewertet auf jenen Begriffen <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Pastis</aspect-term> ist einfach wunderbar..
# Auf der L in Brooklyn ist das ein schönes gemütliches <aspect-term aspect="AMBIENCE" polarity="positive">Ort</aspect-term> mit gutem <aspect-term aspect="FOOD" polarity="positive">Pizza</aspect-term>.
# Meine war ein bisschen verbrannt, aber immer noch lecker mit Käse aus Ziege und Panchetta (<aspect-term aspect="FOOD" polarity="negative">Radicchio</aspect-term> war fast bitter..)
# Mein Freund bekam das <aspect-term aspect="FOOD" polarity="positive">Pizzagemüsluk</aspect-term>, das besser schmeckte..
# Die <aspect-term aspect="FOOD" polarity="positive">Sangria</aspect-term> war ziemlich lecker und gut für einen heißen, schmutzigen Tag..
# Ein kleines <aspect-term aspect="GENERAL-IMPRESSION" polarity="neutral">Ort</aspect-term> aber ich denke, wenn sie nicht zu sehr beschäftigt sind, könnten wir vielleicht eine Gruppe oder Kinder einfügen.
# Ich begann mit einer <aspect-term aspect="FOOD" polarity="positive">Bombe aus Bombay</aspect-term>, die groß genug war für zwei.
# <aspect-term aspect="SERVICE" polarity="negative">Dienst</aspect-term> war langsam, aber die <aspect-term aspect="SERVICE" polarity="positive">Leute</aspect-term> waren freundlich..
# Es ist ein <aspect-term aspect="AMBIENCE" polarity="positive">gutes Ort</aspect-term>, um sich zu entspannen und über das Gespräch zu plaudern.
# Die <aspect-term aspect="FOOD" polarity="positive">Nahrung</aspect-term> ist authentische italienisch - lecker!
# <aspect-term aspect="FOOD" polarity="positive">Pizza</aspect-term> ist großartig, wie auch <aspect-term aspect="FOOD" polarity="positive">Selbstgemachter Kuchen</aspect-term>.
# <aspect-term aspect="AMBIENCE" polarity="positive">Gemeinschaft</aspect-term> ist erfreulich, <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> unübertroffen
# Ich bin immer noch wütend, dass ich für den schlechten <aspect-term aspect="FOOD" polarity="negative">Essen</aspect-term> bezahlen musste.
# Der <aspect-term aspect="FOOD" polarity="negative">Hänger steak</aspect-term> war wie Gummi und der <aspect-term aspect="FOOD" polarity="negative">Tuna</aspect-term> war flach nicht zu erwähnen es schmeckte so, als ob er gerade gefroren wurde.
# <aspect-term aspect="SERVICE" polarity="negative">Dienst</aspect-term> war auch schrecklich und die <aspect-term aspect="AMBIENCE" polarity="negative">Atmosphäre</aspect-term> ist nicht so gut..
# Ich gehe und esse aus bei vielen verschiedenen Restaurants und das ist eines <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Plätze</aspect-term>, wo du gehen musst und probieren solltest.
# Dies ist meine erste Zeit, ein Restaurant zu bewerten, weil das <aspect-term aspect="FOOD" polarity="positive">Food</aspect-term> und <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term> exzellent war..
# Die <aspect-term aspect="FOOD" polarity="positive">Steak filet Mignon-Gemeinschaft</aspect-term> war superb!
# Es ist ein kleiner <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">schöner</aspect-term> Restaurant..
# Ich liebe absolut dieses <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term>!!!.
# Ich mag die <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term>, sie ist sehr dunkel und ursprünglich.
# Die <aspect-term aspect="FOOD" polarity="positive">Sushi</aspect-term> ist unglaublich!!!
# Sehr preisgünstig und ausgezeichnet <aspect-term aspect="AMBIENCE" polarity="positive">ambiant</aspect-term>.
# Wir bestellten einige <aspect-term aspect="FOOD" polarity="negative">Rindfleisch- und Nudelsuppe-Gerichte</aspect-term> aus dem thailändischen Teil des Menus, aber nichts, was wir bekamen, war tatsächlich thailändisch..
# Wir gehen nicht mehr zu diesem Ort wieder für ein gutes <aspect-term aspect="FOOD" polarity="negative">Geschenk</aspect-term>.
# Allerdings denke ich, dass dieses <aspect-term aspect="AMBIENCE" polarity="positive">Ort</aspect-term> ein gutes Treffpunkt ist.
# Meine Freundin und ich stießen zufällig auf dieses hektische <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term> die andere Nacht und hatten eine großartige Zeit!.
# Die <aspect-term aspect="FOOD" polarity="positive">Pizza</aspect-term> und <aspect-term aspect="FOOD" polarity="positive">Wein</aspect-term> waren ausgezeichnet - die <aspect-term aspect="SERVICE" polarity="positive">Dienstleistung</aspect-term> auch sehr gut - aber was wirklich DIE STÄTTE dieses Ortes war, war das <aspect-term aspect="AMBIENCE" polarity="positive">Hinterhof-Esszimmer</aspect-term>.
# Es ist ein <aspect-term aspect="AMBIENCE" polarity="positive">außenrestaurant</aspect-term>, das ich je in NYC gesehen habe – ich bin aus Italien und dieses Ort vergleicht sich mit denjenigen, die ich in meinem Land gesehen habe.
# Überprüfe diesen <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term>! Rückgabeschluss nur!
# Zuerst und vor allem ist dieses <aspect-term aspect="AMBIENCE" polarity="negative">Ort</aspect-term> nicht romantisch, wie von der redaktionellen Bewertung von Citysearch behauptet.
# ...
# <aspect-term aspect="FOOD" polarity="positive">Rinder-Eiweißsuppe ist auch gut.</aspect-term>
# Der <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term> ist gut und der <aspect-term aspect="AMBIENCE" polarity="positive">Restaurant</aspect-term> ist sauber.
# Best <aspect-term aspect="FOOD" polarity="positive"> taiwanesische Küche </aspect-term> in NY!
# Ich bin wahrscheinlich 15 Mal im <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Rao's</aspect-term> seit den letzten 3 Jahren gewesen und es wird immer besser.
# Rao's hat die besten <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> und <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term> in NYC..
# Meine Nachbarin und ich lieben diesen <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term>.
# Wir entschieden uns kürzlich, dieses Lokal auszuprobieren, und zu unserer Freude, sie haben hier <aspect-term aspect="AMBIENCE" polarity="positive">außeres Sitzeinrichtung</aspect-term>, perfekt für mich, da ich meinen Yorkie mitgebracht habe.
# <aspect-term aspect="AMBIENCE" polarity="positive">Innenhaus</aspect-term> war sehr gemütlich und süß.
# Die <aspect-term aspect="FOOD" polarity="positive">Portionsgrößen</aspect-term> hier sind riesig, und die <aspect-term aspect="FOOD" polarity="positive">Sushi</aspect-term> ist gut..
# <aspect-term aspect="SERVICE" polarity="positive">Personal</aspect-term> ist sehr akkommodierend..
# Sehr gut <aspect-term aspect="FOOD" polarity="positive">Nudeln</aspect-term> serviert im sauberen, chic <aspect-term aspect="AMBIENCE" polarity="positive"> Dekoration</aspect-term>.
# Ich habe das <aspect-term aspect="FOOD" polarity="positive">$10 10-Stück-Dim-Sum-Combo</aspect-term> bekommen, jeden Bissen davon war großartig.
# Die <aspect-term aspect="AMBIENCE" polarity="positive">Zuckerdecke</aspect-term> ist sehr einfach, aber gemütlich.
# Das <aspect-term aspect="FOOD" polarity="negative"> Essen <aspect-term aspect="FOOD" polarity="positive"> war lecker, aber lasst es hier </aspect-term> auf einen leeren Magen </aspect-term> sein, nur kehrt zurück, wenn du ernährt bist.
# Die <aspect-term aspect="FOOD" polarity="negative">Teile</aspect-term> sind klein, aber da das <aspect-term aspect="FOOD" polarity="positive"> Essen </aspect-term> so gut war, macht das aus.
# Du musst den <aspect-term aspect="FOOD" polarity="positive">Krabbmeatkäsespätzle</aspect-term> haben, der aus diesem Welt ist und den <aspect-term aspect="FOOD" polarity="positive">Choklatbrotpudding</aspect-term> zum Nachtisch.
# Der <aspect-term aspect="SERVICE" polarity="positive">Stab</aspect-term> dort ist sehr aufmerksam und von der Erde.
# Großartige <aspect-term aspect="FOOD" polarity="positive"> indische Küche </aspect-term> und das <aspect-term aspect="SERVICE" polarity="positive"> Service </aspect-term> ist unglaublich.
# Der <aspect-term aspect="SERVICE" polarity="positive">Eigentümer</aspect-term> trifft wirklich alle Ihre Bedürfnisse..
# Gute <aspect-term aspect="FOOD" polarity="positive">Nahrung</aspect-term> und die Preise sind sehr vernünftig.
# Das <aspect-term aspect="FOOD" polarity="positive">Nahrung hier</aspect-term> tut großartigen Dienst für den Namen (Cantonese ist das...)..
# Ich fiel in den Hafen für die <aspect-term aspect="FOOD" polarity="positive">Ei-Nudeln im Rindbratenbrühe mit Garnelen-Gurmeln und Slices von BBQ-Roast-Pork</aspect-term>.
# Dieses <aspect-term aspect="FOOD" polarity="positive">Gericht</aspect-term> ist mein Lieblingsgericht und ich bekomme es immer, wenn ich dorthin gehe und nie müde davon werde.
# Versuche das <aspect-term aspect="FOOD" polarity="positive">Congee</aspect-term> und das Donut wie <aspect-term aspect="FOOD" polarity="positive">Ow Ley Soh</aspect-term>, ein leckeres und süßes Geschmackserlebnis.
# Einfach einige leckere <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">chinesische Küche</aspect-term></aspect-term> zu unvergleichlichen Preisen....
# <aspect-term aspect="SERVICE" polarity="negative">Dienst</aspect-term> ist nicht, was Sie hier für... Rückkehren nur dann, wenn...
# <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Groß Wong</aspect-term> ist ein großartiges Restaurant, wo man sich satt essen kann..
# Wer immer der <aspect-term aspect="AMBIENCE" polarity="positive">Jazz-Duo</aspect-term> war, waren sie auf Punkt..
# Gute <aspect-term aspect="AMBIENCE" polarity="positive">Musik</aspect-term>, großartiges <aspect-term aspect="FOOD" polarity="positive"> Essen </aspect-term>, schnelle <aspect-term aspect="SERVICE" polarity="positive">Dienstleistung </aspect-term> günstige Preise
# Die <aspect-term aspect="FOOD" polarity="positive">Wein aus dem Glas</aspect-term> war auch gut..
# Beständig gut <aspect-term aspect="FOOD" polarity="positive"> japanische Tapas </aspect-term>..
# Bis jetzt gute <aspect-term aspect="FOOD" polarity="positive">Trinken</aspect-term> und <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term> ist ziemlich gut.
# <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term> ist angenehm und entspannt auch....
# Ein großes <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term>, um sich zu treffen und ein paar Getränke und Essen...
# <aspect-term aspect="FOOD" polarity="positive">Yakitori (Grill Fleisch)</aspect-term> ist lecker auch..
# Wenn Sie sich nicht schlagen um das vorschnitzelte, niedrige Qualität <aspect-term aspect="FOOD" polarity="negative">Fisch</aspect-term>, unfreundlich <aspect-term aspect="SERVICE" polarity="negative">Personal</aspect-term> und einen <aspect-term aspect="GENERAL-IMPRESSION" polarity="negative">Sushi Chef</aspect-term>, der wie er ist, sehr unglücklich zu sehen scheint dann ist dieses hier Ihr Ort. Rückernten Sie nur die von hier.
# Preis und Qualität von <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative">Fisch</aspect-term></aspect-term> allein werden uns davon abhalten, eine Rückbesuchsvisite zu machen.
# Es war nicht vorhaben, es zu teilen, aber ich fühle mich verpflichtet...während wir am Sushi-Bar saßen und aß, haben wir den <aspect-term aspect="FOOD" polarity="negative">Koch</aspect-term> zufällig im Esszimmer fallen lassen, als er ein Stück Unagi vom Boden aufnahm und dann in das Lieferbestellungsordner einbezielte.
# Dieses <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Ort</aspect-term>, der nur wenige Monate alt ist, ist vielleicht Queens größter Geheimnis!
# Fabulös <aspect-term aspect="AMBIENCE" polarity="positive"> Deko </aspect-term> - macht dich auf die Tatsache hin, als ob du in einem trendsichem Manhattan-Restaurant bist, sehr sehr gut <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive"> Essen </aspect-term></aspect-term>, billigpreisig, allgemein freundlich <aspect-term aspect="SERVICE" polarity="positive">Personal</aspect-term>, und wenn du ein New Yorker bist oder den ganzen Tag in Manhattan verbringst, <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive"><aspect-term aspect="AMBIENCE" polarity="positive"><aspect-term aspect="AMBIENCE" polarity="positive">Rice Avenue</aspect-term></aspect-term></aspect-term> wird dich wie zu Hause fühlen......sehr Soho/Village/Upper West Side minus der teuren Preise und dem arroganten Publikum.....all auf Roosevelt Avenue!.
# Wir wurden außerhalb gesetzt und der <aspect-term aspect="SERVICE" polarity="negative">Warter</aspect-term> spritzte roten Wein und heißen Tee auf mich und meine Date.
# Einem würde man denken, wir würden eine Entschuldigung oder einen kostenlosen Drink bekommen - stattdessen bekamen wir einen spöttischen <aspect-term aspect="SERVICE" polarity="negative">Wartenden</aspect-term>, der uns nicht einmal unser Essen bestellen ließ für 15 Minuten und gab uns Lippenbecken, wenn wir ihn bitten wollten.
# Mit so vielen guten Restaurants auf dem UWS brauche ich keine überpreisste <aspect-term aspect="FOOD" polarity="negative">Gastronomie</aspect-term>, absurde, arrogant <aspect-term aspect="SERVICE" polarity="negative">Bedienung</aspect-term>, die nicht erkennen, dass sie an einem glorifizierten Diner arbeiten, unhöfliche <aspect-term aspect="SERVICE" polarity="negative">Dienstleistungen</aspect-term> und eine <aspect-term aspect="SERVICE" polarity="negative">Verwaltung</aspect-term>, die es nicht zu schätzen weiß.
# Ich bin relativ neu im Gebiet und habe ein Pick abgegeben auf der 2. Ecke und war enttäuscht mit dem <aspect-term aspect="SERVICE" polarity="negative">Service</aspect-term> und dachte, das <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative">Food</aspect-term></aspect-term> sei überhöht und auf der teursten Seite..
# Die <aspect-term aspect="FOOD" polarity="neutral">Leckerei</aspect-term> ist okay und die Preise hier sind mittelmäßig..
# <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Bukharis</aspect-term> hat feste <aspect-term aspect="FOOD" polarity="positive">Leckerei</aspect-term> und eine schöne <aspect-term aspect="AMBIENCE" polarity="positive">Zutat</aspect-term> zu vernünftigen Preisen..
# Der einzige Problem ist, dass der <aspect-term aspect="SERVICE" polarity="negative">Manager</aspect-term> ein vollkommener Inkompetent ist.
# Er bietet schlassig <aspect-term aspect="SERVICE" polarity="negative">Service</aspect-term> und hat keine Persönlichkeit.
# Es gibt keine Entschuldigung für solche schlechte <aspect-term aspect="SERVICE" polarity="negative">Dienst</aspect-term>!
# Ich habe nie zuvor 40 Stücke von relativ gutes <aspect-term aspect="FOOD" polarity="neutral">Nigiri</aspect-term> gegessen.
# $20 für <aspect-term aspect="FOOD" polarity="positive">alleyoucaneatsushi</aspect-term> kann nicht besiegt werden..
# Ich ging am Sonntagvormittag zum <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Areo</aspect-term> mit vier meiner Freundinnen und verbrachte drei angenehme Stunden dort.
# Die meisten der <aspect-term aspect="SERVICE" polarity="positive">Server</aspect-term> sind sehr aufmerksam, freundlich und ziemlich attraktiv.
# Die <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term> ist sehr entspannt und gemütlich, <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> war großartig und die <aspect-term aspect="FOOD" polarity="positive">Leistung</aspect-term> war herausragend!
# Die <aspect-term aspect="FOOD" polarity="positive">Leckerei</aspect-term> war gut und die <aspect-term aspect="AMBIENCE" polarity="positive">Ansicht der neuen New York City Linie</aspect-term> war super auch auf einem nebligen regnerischen Tag wie den ich war..
# Ich würde sehr empfehlen, ein <aspect-term aspect="AMBIENCE" polarity="positive">Tisch</aspect-term> am Fenster zu bitten..
# Obwohl sie das typische, welches Art von Wasser Sie mögen Fragen stellen, <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> war gut und insgesamt sehr entspannend zum <aspect-term aspect="AMBIENCE" polarity="positive">Ort</aspect-term> zum Essen..
# Der <aspect-term aspect="FOOD" polarity="positive">Speise</aspect-term> ist großartig.
# <aspect-term aspect="FOOD" polarity="positive">Persönliche Pfannen</aspect-term> sind die perfekte Größe für solche hungrigen Abende.
# Es gibt einen Nachteil, wenn du bestellst - die <aspect-term aspect="SERVICE" polarity="negative">Lieferfahrer</aspect-term> haben eine MAJOR Attitüde..
# Ich habe solche dramatische Lieferanten noch nie gehabt <aspect-term aspect="SERVICE" polarity="negative"> (keine Sorge, es ist einfach so, dass ich im Stockwerk wohne, die Leute sind immer enttäuscht von ihren Tipps)</aspect-term>
# Liebe die <aspect-term aspect="AMBIENCE" polarity="positive"> Szene </aspect-term> zuerst - der <aspect-term aspect="AMBIENCE" polarity="positive"> Ort </aspect-term> hat eine Charakter und ein schönes Licht zu ihm.. sehr glücklich, <aspect-term aspect="AMBIENCE" polarity="positive"> Lage </aspect-term> Weis.
# Die <aspect-term aspect="FOOD" polarity="positive"><aspect-term aspect="FOOD" polarity="positive">Pizze</aspect-term></aspect-term> war ziemlich gut und riesig.
# Wir waren 4 und kamen zur Familie-Größe <aspect-term aspect="FOOD" polarity="positive">Penne à la Vodka</aspect-term>, das war unglaublich riesige Portion ... ein Korb mit Essen wirklich
# Die <aspect-term aspect="FOOD" polarity="negative"><aspect-term aspect="FOOD" polarity="negative">pasta penne</aspect-term></aspect-term> war ziemlich extraButterig cremig, was bedeutet ein großer Aufwand zum Verdauen. Geschmacklich erst aber ich würde sagen, dass ich nach einer Scheibe Pizza und sieben Stücken, penne...ein bisschen launisch wurde, da vollgestopft war...lol.
# <aspect-term aspect="FOOD" polarity="positive">Rosabella waltzt herein, und ich denke, sie tun es am besten.</aspect-term>
# Faszinierende <aspect-term aspect="FOOD" polarity="positive"> Auswahl </aspect-term>, gute <aspect-term aspect="FOOD" polarity="positive"> Weine </aspect-term>, <aspect-term aspect="SERVICE" polarity="positive"> Service </aspect-term> fein, lustige <aspect-term aspect="AMBIENCE" polarity="positive"> Dekoration </aspect-term>.
# Ich fand es auf einer kalten Nacht, dem perfekten <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">Spot</aspect-term> zum Wärmen.
# Ich erhielt einen <aspect-term aspect="SERVICE" polarity="positive">Service</aspect-term> mit einem Lächeln.
# Dieser Ort <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">bließ mich </aspect-term>herbei....durch weit entfernt ist es von meinem neuen Lieblingsrestaurant auf der Oberschweizer Seite.
# Die <aspect-term aspect="FOOD" polarity="positive">Weinliste</aspect-term> ist umfangreich und beeindruckend.
# LIEBE die <aspect-term aspect="AMBIENCE" polarity="positive">Atmosphäre</aspect-term> - fühlte sich so an wie ich in Paris war..
# Die <aspect-term aspect="FOOD" polarity="positive">Muscheln</aspect-term> waren großartig und auch das <aspect-term aspect="FOOD" polarity="positive">Dessert</aspect-term>...definitiv werde ich wieder sehr bald zurückkehren..
# Ich bin hier schon Jahre lang gewesen und habe nichts als gute Dinge zu sagen über den <aspect-term aspect="SERVICE" polarity="positive">Dienst</aspect-term> und das großartige <aspect-term aspect="SERVICE" polarity="positive">Personal</aspect-term> bei La Lanterna.
# Die Jahre haben Vittorio, den <aspect-term aspect="SERVICE" polarity="positive">Veranstaltern</aspect-term>, und seine <aspect-term aspect="SERVICE" polarity="positive">Mannschaft</aspect-term> immer mich als Familie behandelt -- obwohl mit all der Geschäftigkeit, die dieses nicht so kleine Juwel macht, ist es wirklich beeindruckend, dass er überhaupt noch auf einen einheitlichen, aber nicht zu häufigen Besucher hinweist..
# Ich habe auch großartig überrascht an allen neuen Zugängen im letzten Jahrzehnt: Eine neue <aspect-term aspect="AMBIENCE" polarity="positive">Jazz Bar</aspect-term>, die fantastischste <aspect-term aspect="AMBIENCE" polarity="positive">Garten zum Essen</aspect-term>, die besten <aspect-term aspect="FOOD" polarity="positive">Dünner Teigtaschentorte</aspect-term> und jetzt ein <aspect-term aspect="FOOD" polarity="positive">Lasagna-Menü</aspect-term> das zum Sterben ist (diese sind nicht wie andere Lasagnas)!.
# Ich Liebe DAS <aspect-term aspect="GENERAL-IMPRESSION" polarity="positive">PLATZ</aspect-term>.
# Ich muss sagen, ich habe noch nie eine enttäuschende <aspect-term aspect="FOOD" polarity="positive"> Mahlzeit </aspect-term> hier gehabt.
# Wir könnten uns ein Mahl aus den leckeren <aspect-term aspect="FOOD" polarity="positive">Dumplings</aspect-term> vom Dumplingsmenü gemacht haben.
# Glücklich haben wir Raum für den <aspect-term aspect="FOOD" polarity="positive">BBQ Hühnchen</aspect-term>, <aspect-term aspect="FOOD" polarity="positive">Meeresbarsch</aspect-term> und <aspect-term aspect="FOOD" polarity="positive">Knuspriger Ente</aspect-term>.

# %%
# write to txt-file
with open("rest15_tasd_llama_translated.txt", "w", encoding='utf-8') as file:
    for sent in validated_sent:
        file.write(sent + "\n")

# %%
# tag filtered TASD sentences
final_list = []
for sent in validated_sent:
    tagged = sentence_xml_tagging(sent)
    final_list.append(tagged)

xml_file_tasd = ''.join(final_list)

# %%
# add root
xml_file_tasd = "<?xml version='1.0' encoding='utf-8'?>" + "<Reviews>" + xml_file_tasd + "</Reviews>"

# %%
tree = ET.ElementTree(ET.fromstring(xml_file_tasd))

# %%
tree.write('rest16_tasd_llama_translated.xml', encoding='utf-8')
